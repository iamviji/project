# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Report/CNNAE_10x2_8_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise, BatchNormalization, Conv1D, Activation, Lambda, Flatten

from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 10
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 8
channel_size = 10 


NUM_OF_INPUT_MESSAGE = 1000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
def PowerNormLayer(x):
    nx =  x / tf.sqrt(tf.reduce_mean(tf.square(x)))
    return nx

# %%
snr_std = Snr2Sigma(7.0)
num_filters = 2**encoder_output_length
print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)

input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_1')(input_message_x)
enc = BatchNormalization(name='enc_2')(enc)
enc = Activation('elu', name='enc_3')(enc)

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_4')(enc)
enc = BatchNormalization(name='enc_5')(enc)
enc = Activation('elu', name='ecn_6')(enc)

enc = Conv1D(filters=2 * channel_size, strides=1, kernel_size=1, name='ch_1')(enc)
enc = BatchNormalization(name='ch_2')(enc)
enc = Activation('linear', name='ch_3')(enc)
enc = Flatten()(enc)
encoder_out = Lambda(PowerNormLayer, name='PowerNorm')(enc)

encoder = Model(input_message_x, encoder_out)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

encoded_input = Input(shape=(num_of_input_block*2*channel_size,))

reshaped_input = tf.reshape (encoded_input, (-1,num_of_input_block,2*channel_size))


dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_1')(reshaped_input)
dec = BatchNormalization(name='dec_2')(dec)
dec = Activation('elu', name='dec_3')(dec)

dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_4')(dec)
dec = BatchNormalization(name='dec_5')(dec)
dec = Activation('elu', name='dec_6')(dec)

model_output = Conv1D(filters=2 ** input_block_length, strides=1, kernel_size=1, name='d_10', activation='softmax')(dec)


decoder = Model(encoded_input, model_output)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 10
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 1024)]         0
# _________________________________________________________________
# enc_1 (Conv1D)               (None, 2, 256)            262400
# _________________________________________________________________
# enc_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# enc_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# enc_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# enc_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# ecn_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# ch_1 (Conv1D)                (None, 2, 20)             5140
# _________________________________________________________________
# ch_2 (BatchNormalization)    (None, 2, 20)             80
# _________________________________________________________________
# ch_3 (Activation)            (None, 2, 20)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 40)                0
# _________________________________________________________________
# PowerNorm (Lambda)           (None, 40)                0
# =================================================================
# Total params: 335,460
# Trainable params: 334,396
# Non-trainable params: 1,064
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 40)]              0
# _________________________________________________________________
# tf.reshape (TFOpLambda)      (None, 2, 20)             0
# _________________________________________________________________
# dec_1 (Conv1D)               (None, 2, 256)            5376
# _________________________________________________________________
# dec_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# dec_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# dec_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# d_10 (Conv1D)                (None, 2, 1024)           263168
# =================================================================
# Total params: 336,384
# Trainable params: 335,360
# Non-trainable params: 1,024
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 1024)]         0
# _________________________________________________________________
# model (Functional)           (None, 40)                335460
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 40)                0
# _________________________________________________________________
# model_1 (Functional)         (None, 2, 1024)           336384
# =================================================================
# Total params: 671,844
# Trainable params: 669,756
# Non-trainable params: 2,088
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
beginTime = time.clock()
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=500,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history
  
endTime = time.clock()
print('TotalTime: ' + str(endTime - beginTime) + ' s')
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 2/2 [==============================] - 3s 1s/step - loss: 7.0110 - sparse_categorical_accuracy: 0.0033 - val_loss: 6.7862 - val_sparse_categorical_accuracy: 0.0180
# Epoch 2/50
# 2/2 [==============================] - 1s 587ms/step - loss: 6.4710 - sparse_categorical_accuracy: 0.0270 - val_loss: 6.6223 - val_sparse_categorical_accuracy: 0.1175
# Epoch 3/50
# 2/2 [==============================] - 1s 599ms/step - loss: 6.0526 - sparse_categorical_accuracy: 0.1203 - val_loss: 6.4821 - val_sparse_categorical_accuracy: 0.2620
# Epoch 4/50
# 2/2 [==============================] - 1s 606ms/step - loss: 5.7124 - sparse_categorical_accuracy: 0.2393 - val_loss: 6.3666 - val_sparse_categorical_accuracy: 0.3435
# Epoch 5/50
# 2/2 [==============================] - 1s 596ms/step - loss: 5.4220 - sparse_categorical_accuracy: 0.3450 - val_loss: 6.2712 - val_sparse_categorical_accuracy: 0.3660
# Epoch 6/50
# 2/2 [==============================] - 1s 580ms/step - loss: 5.2165 - sparse_categorical_accuracy: 0.3707 - val_loss: 6.1898 - val_sparse_categorical_accuracy: 0.3765
# Epoch 7/50
# 2/2 [==============================] - 1s 590ms/step - loss: 5.0140 - sparse_categorical_accuracy: 0.3873 - val_loss: 6.1195 - val_sparse_categorical_accuracy: 0.3720
# Epoch 8/50
# 2/2 [==============================] - 1s 588ms/step - loss: 4.8286 - sparse_categorical_accuracy: 0.4180 - val_loss: 6.0582 - val_sparse_categorical_accuracy: 0.3580
# Epoch 9/50
# 2/2 [==============================] - 1s 596ms/step - loss: 4.6563 - sparse_categorical_accuracy: 0.4303 - val_loss: 6.0032 - val_sparse_categorical_accuracy: 0.3590
# Epoch 10/50
# 2/2 [==============================] - 1s 581ms/step - loss: 4.4994 - sparse_categorical_accuracy: 0.4330 - val_loss: 5.9526 - val_sparse_categorical_accuracy: 0.3465
# Epoch 11/50
# 2/2 [==============================] - 1s 600ms/step - loss: 4.3567 - sparse_categorical_accuracy: 0.4513 - val_loss: 5.9047 - val_sparse_categorical_accuracy: 0.3475
# Epoch 12/50
# 2/2 [==============================] - 1s 596ms/step - loss: 4.2365 - sparse_categorical_accuracy: 0.4397 - val_loss: 5.8583 - val_sparse_categorical_accuracy: 0.3380
# Epoch 13/50
# 2/2 [==============================] - 1s 595ms/step - loss: 4.1163 - sparse_categorical_accuracy: 0.4530 - val_loss: 5.8123 - val_sparse_categorical_accuracy: 0.3345
# Epoch 14/50
# 2/2 [==============================] - 1s 588ms/step - loss: 4.0021 - sparse_categorical_accuracy: 0.4657 - val_loss: 5.7655 - val_sparse_categorical_accuracy: 0.3340
# Epoch 15/50
# 2/2 [==============================] - 1s 606ms/step - loss: 3.8575 - sparse_categorical_accuracy: 0.4687 - val_loss: 5.7172 - val_sparse_categorical_accuracy: 0.3265
# Epoch 16/50
# 2/2 [==============================] - 1s 586ms/step - loss: 3.7538 - sparse_categorical_accuracy: 0.4863 - val_loss: 5.6671 - val_sparse_categorical_accuracy: 0.3455
# Epoch 17/50
# 2/2 [==============================] - 1s 583ms/step - loss: 3.6377 - sparse_categorical_accuracy: 0.4903 - val_loss: 5.6185 - val_sparse_categorical_accuracy: 0.3490
# Epoch 18/50
# 2/2 [==============================] - 1s 692ms/step - loss: 3.5568 - sparse_categorical_accuracy: 0.5027 - val_loss: 5.5702 - val_sparse_categorical_accuracy: 0.3565
# Epoch 19/50
# 2/2 [==============================] - 1s 582ms/step - loss: 3.4589 - sparse_categorical_accuracy: 0.5063 - val_loss: 5.5242 - val_sparse_categorical_accuracy: 0.3635
# Epoch 20/50
# 2/2 [==============================] - 1s 582ms/step - loss: 3.3648 - sparse_categorical_accuracy: 0.5177 - val_loss: 5.4794 - val_sparse_categorical_accuracy: 0.3630
# Epoch 21/50
# 2/2 [==============================] - 1s 585ms/step - loss: 3.2602 - sparse_categorical_accuracy: 0.5370 - val_loss: 5.4346 - val_sparse_categorical_accuracy: 0.3660
# Epoch 22/50
# 2/2 [==============================] - 1s 581ms/step - loss: 3.1723 - sparse_categorical_accuracy: 0.5447 - val_loss: 5.3882 - val_sparse_categorical_accuracy: 0.3735
# Epoch 23/50
# 2/2 [==============================] - 1s 582ms/step - loss: 3.1014 - sparse_categorical_accuracy: 0.5617 - val_loss: 5.3460 - val_sparse_categorical_accuracy: 0.3740
# Epoch 24/50
# 2/2 [==============================] - 1s 580ms/step - loss: 3.0246 - sparse_categorical_accuracy: 0.5647 - val_loss: 5.3051 - val_sparse_categorical_accuracy: 0.3720
# Epoch 25/50
# 2/2 [==============================] - 1s 588ms/step - loss: 2.9683 - sparse_categorical_accuracy: 0.5730 - val_loss: 5.2640 - val_sparse_categorical_accuracy: 0.3825
# Epoch 26/50
# 2/2 [==============================] - 1s 590ms/step - loss: 2.9046 - sparse_categorical_accuracy: 0.5777 - val_loss: 5.2261 - val_sparse_categorical_accuracy: 0.3800
# Epoch 27/50
# 2/2 [==============================] - 1s 589ms/step - loss: 2.8131 - sparse_categorical_accuracy: 0.5880 - val_loss: 5.1900 - val_sparse_categorical_accuracy: 0.3840
# Epoch 28/50
# 2/2 [==============================] - 1s 584ms/step - loss: 2.7679 - sparse_categorical_accuracy: 0.5947 - val_loss: 5.1536 - val_sparse_categorical_accuracy: 0.3860
# Epoch 29/50
# 2/2 [==============================] - 1s 589ms/step - loss: 2.7199 - sparse_categorical_accuracy: 0.6073 - val_loss: 5.1174 - val_sparse_categorical_accuracy: 0.3910
# Epoch 30/50
# 2/2 [==============================] - 1s 586ms/step - loss: 2.6291 - sparse_categorical_accuracy: 0.6167 - val_loss: 5.0833 - val_sparse_categorical_accuracy: 0.3860
# Epoch 31/50
# 2/2 [==============================] - 1s 598ms/step - loss: 2.6168 - sparse_categorical_accuracy: 0.5987 - val_loss: 5.0481 - val_sparse_categorical_accuracy: 0.3910
# Epoch 32/50
# 2/2 [==============================] - 1s 608ms/step - loss: 2.5562 - sparse_categorical_accuracy: 0.6243 - val_loss: 5.0111 - val_sparse_categorical_accuracy: 0.3965
# Epoch 33/50
# 2/2 [==============================] - 1s 596ms/step - loss: 2.4910 - sparse_categorical_accuracy: 0.6333 - val_loss: 4.9735 - val_sparse_categorical_accuracy: 0.3915
# Epoch 34/50
# 2/2 [==============================] - 1s 586ms/step - loss: 2.4624 - sparse_categorical_accuracy: 0.6327 - val_loss: 4.9343 - val_sparse_categorical_accuracy: 0.3895
# Epoch 35/50
# 2/2 [==============================] - 1s 583ms/step - loss: 2.4323 - sparse_categorical_accuracy: 0.6367 - val_loss: 4.8964 - val_sparse_categorical_accuracy: 0.3870
# Epoch 36/50
# 2/2 [==============================] - 1s 594ms/step - loss: 2.3387 - sparse_categorical_accuracy: 0.6430 - val_loss: 4.8578 - val_sparse_categorical_accuracy: 0.3870
# Epoch 37/50
# 2/2 [==============================] - 1s 588ms/step - loss: 2.2989 - sparse_categorical_accuracy: 0.6537 - val_loss: 4.8165 - val_sparse_categorical_accuracy: 0.3935
# Epoch 38/50
# 2/2 [==============================] - 1s 592ms/step - loss: 2.2667 - sparse_categorical_accuracy: 0.6570 - val_loss: 4.7747 - val_sparse_categorical_accuracy: 0.3955
# Epoch 39/50
# 2/2 [==============================] - 1s 611ms/step - loss: 2.2504 - sparse_categorical_accuracy: 0.6577 - val_loss: 4.7335 - val_sparse_categorical_accuracy: 0.4015
# Epoch 40/50
# 2/2 [==============================] - 1s 591ms/step - loss: 2.1636 - sparse_categorical_accuracy: 0.6793 - val_loss: 4.6911 - val_sparse_categorical_accuracy: 0.4120
# Epoch 41/50
# 2/2 [==============================] - 1s 595ms/step - loss: 2.1622 - sparse_categorical_accuracy: 0.6590 - val_loss: 4.6487 - val_sparse_categorical_accuracy: 0.4165
# Epoch 42/50
# 2/2 [==============================] - 1s 592ms/step - loss: 2.1152 - sparse_categorical_accuracy: 0.6807 - val_loss: 4.6082 - val_sparse_categorical_accuracy: 0.4155
# Epoch 43/50
# 2/2 [==============================] - 1s 587ms/step - loss: 2.0815 - sparse_categorical_accuracy: 0.6697 - val_loss: 4.5648 - val_sparse_categorical_accuracy: 0.4255
# Epoch 44/50
# 2/2 [==============================] - 1s 588ms/step - loss: 2.0807 - sparse_categorical_accuracy: 0.6750 - val_loss: 4.5202 - val_sparse_categorical_accuracy: 0.4395
# Epoch 45/50
# 2/2 [==============================] - 1s 580ms/step - loss: 2.0272 - sparse_categorical_accuracy: 0.6793 - val_loss: 4.4700 - val_sparse_categorical_accuracy: 0.4450
# Epoch 46/50
# 2/2 [==============================] - 1s 599ms/step - loss: 1.9933 - sparse_categorical_accuracy: 0.6750 - val_loss: 4.4168 - val_sparse_categorical_accuracy: 0.4515
# Epoch 47/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.9363 - sparse_categorical_accuracy: 0.7063 - val_loss: 4.3648 - val_sparse_categorical_accuracy: 0.4615
# Epoch 48/50
# 2/2 [==============================] - 1s 612ms/step - loss: 1.9200 - sparse_categorical_accuracy: 0.7000 - val_loss: 4.3085 - val_sparse_categorical_accuracy: 0.4780
# Epoch 49/50
# 2/2 [==============================] - 1s 606ms/step - loss: 1.8776 - sparse_categorical_accuracy: 0.7093 - val_loss: 4.2610 - val_sparse_categorical_accuracy: 0.4760
# Epoch 50/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.8393 - sparse_categorical_accuracy: 0.6980 - val_loss: 4.2143 - val_sparse_categorical_accuracy: 0.4835
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 2/2 [==============================] - 1s 639ms/step - loss: 1.8582 - sparse_categorical_accuracy: 0.7010 - val_loss: 4.1667 - val_sparse_categorical_accuracy: 0.4890
# Epoch 2/50
# 2/2 [==============================] - 1s 612ms/step - loss: 1.8057 - sparse_categorical_accuracy: 0.7050 - val_loss: 4.1197 - val_sparse_categorical_accuracy: 0.4905
# Epoch 3/50
# 2/2 [==============================] - 1s 585ms/step - loss: 1.8159 - sparse_categorical_accuracy: 0.6950 - val_loss: 4.0705 - val_sparse_categorical_accuracy: 0.5020
# Epoch 4/50
# 2/2 [==============================] - 1s 594ms/step - loss: 1.7833 - sparse_categorical_accuracy: 0.6985 - val_loss: 4.0200 - val_sparse_categorical_accuracy: 0.5080
# Epoch 5/50
# 2/2 [==============================] - 1s 598ms/step - loss: 1.7544 - sparse_categorical_accuracy: 0.7005 - val_loss: 3.9718 - val_sparse_categorical_accuracy: 0.5165
# Epoch 6/50
# 2/2 [==============================] - 1s 588ms/step - loss: 1.7052 - sparse_categorical_accuracy: 0.7205 - val_loss: 3.9178 - val_sparse_categorical_accuracy: 0.5320
# Epoch 7/50
# 2/2 [==============================] - 1s 581ms/step - loss: 1.7071 - sparse_categorical_accuracy: 0.7010 - val_loss: 3.8630 - val_sparse_categorical_accuracy: 0.5420
# Epoch 8/50
# 2/2 [==============================] - 1s 588ms/step - loss: 1.6601 - sparse_categorical_accuracy: 0.7225 - val_loss: 3.8121 - val_sparse_categorical_accuracy: 0.5505
# Epoch 9/50
# 2/2 [==============================] - 1s 577ms/step - loss: 1.6731 - sparse_categorical_accuracy: 0.6940 - val_loss: 3.7644 - val_sparse_categorical_accuracy: 0.5695
# Epoch 10/50
# 2/2 [==============================] - 1s 604ms/step - loss: 1.6253 - sparse_categorical_accuracy: 0.7085 - val_loss: 3.7151 - val_sparse_categorical_accuracy: 0.5875
# Epoch 11/50
# 2/2 [==============================] - 1s 687ms/step - loss: 1.5722 - sparse_categorical_accuracy: 0.7270 - val_loss: 3.6649 - val_sparse_categorical_accuracy: 0.6010
# Epoch 12/50
# 2/2 [==============================] - 1s 597ms/step - loss: 1.5926 - sparse_categorical_accuracy: 0.7200 - val_loss: 3.6165 - val_sparse_categorical_accuracy: 0.6180
# Epoch 13/50
# 2/2 [==============================] - 1s 603ms/step - loss: 1.5650 - sparse_categorical_accuracy: 0.7180 - val_loss: 3.5678 - val_sparse_categorical_accuracy: 0.6290
# Epoch 14/50
# 2/2 [==============================] - 1s 605ms/step - loss: 1.5682 - sparse_categorical_accuracy: 0.7140 - val_loss: 3.5174 - val_sparse_categorical_accuracy: 0.6550
# Epoch 15/50
# 2/2 [==============================] - 1s 597ms/step - loss: 1.5181 - sparse_categorical_accuracy: 0.7210 - val_loss: 3.4607 - val_sparse_categorical_accuracy: 0.6705
# Epoch 16/50
# 2/2 [==============================] - 1s 606ms/step - loss: 1.4698 - sparse_categorical_accuracy: 0.7385 - val_loss: 3.4049 - val_sparse_categorical_accuracy: 0.6875
# Epoch 17/50
# 2/2 [==============================] - 1s 587ms/step - loss: 1.5115 - sparse_categorical_accuracy: 0.7150 - val_loss: 3.3495 - val_sparse_categorical_accuracy: 0.6995
# Epoch 18/50
# 2/2 [==============================] - 1s 592ms/step - loss: 1.4827 - sparse_categorical_accuracy: 0.7255 - val_loss: 3.2959 - val_sparse_categorical_accuracy: 0.7150
# Epoch 19/50
# 2/2 [==============================] - 1s 602ms/step - loss: 1.4905 - sparse_categorical_accuracy: 0.7235 - val_loss: 3.2482 - val_sparse_categorical_accuracy: 0.7155
# Epoch 20/50
# 2/2 [==============================] - 1s 593ms/step - loss: 1.4243 - sparse_categorical_accuracy: 0.7515 - val_loss: 3.2039 - val_sparse_categorical_accuracy: 0.7280
# Epoch 21/50
# 2/2 [==============================] - 1s 600ms/step - loss: 1.3850 - sparse_categorical_accuracy: 0.7525 - val_loss: 3.1636 - val_sparse_categorical_accuracy: 0.7465
# Epoch 22/50
# 2/2 [==============================] - 1s 594ms/step - loss: 1.4034 - sparse_categorical_accuracy: 0.7370 - val_loss: 3.1235 - val_sparse_categorical_accuracy: 0.7525
# Epoch 23/50
# 2/2 [==============================] - 1s 586ms/step - loss: 1.4017 - sparse_categorical_accuracy: 0.7385 - val_loss: 3.0743 - val_sparse_categorical_accuracy: 0.7610
# Epoch 24/50
# 2/2 [==============================] - 1s 582ms/step - loss: 1.4012 - sparse_categorical_accuracy: 0.7330 - val_loss: 3.0191 - val_sparse_categorical_accuracy: 0.7680
# Epoch 25/50
# 2/2 [==============================] - 1s 587ms/step - loss: 1.3426 - sparse_categorical_accuracy: 0.7410 - val_loss: 2.9679 - val_sparse_categorical_accuracy: 0.7740
# Epoch 26/50
# 2/2 [==============================] - 1s 588ms/step - loss: 1.2875 - sparse_categorical_accuracy: 0.7695 - val_loss: 2.9226 - val_sparse_categorical_accuracy: 0.7845
# Epoch 27/50
# 2/2 [==============================] - 1s 589ms/step - loss: 1.3328 - sparse_categorical_accuracy: 0.7510 - val_loss: 2.8766 - val_sparse_categorical_accuracy: 0.7940
# Epoch 28/50
# 2/2 [==============================] - 1s 589ms/step - loss: 1.2932 - sparse_categorical_accuracy: 0.7550 - val_loss: 2.8297 - val_sparse_categorical_accuracy: 0.7995
# Epoch 29/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.3019 - sparse_categorical_accuracy: 0.7490 - val_loss: 2.7808 - val_sparse_categorical_accuracy: 0.8075
# Epoch 30/50
# 2/2 [==============================] - 1s 615ms/step - loss: 1.2994 - sparse_categorical_accuracy: 0.7525 - val_loss: 2.7333 - val_sparse_categorical_accuracy: 0.8130
# Epoch 31/50
# 2/2 [==============================] - 1s 603ms/step - loss: 1.2701 - sparse_categorical_accuracy: 0.7625 - val_loss: 2.6879 - val_sparse_categorical_accuracy: 0.8210
# Epoch 32/50
# 2/2 [==============================] - 1s 579ms/step - loss: 1.2731 - sparse_categorical_accuracy: 0.7465 - val_loss: 2.6415 - val_sparse_categorical_accuracy: 0.8245
# Epoch 33/50
# 2/2 [==============================] - 1s 592ms/step - loss: 1.3032 - sparse_categorical_accuracy: 0.7370 - val_loss: 2.5939 - val_sparse_categorical_accuracy: 0.8315
# Epoch 34/50
# 2/2 [==============================] - 1s 591ms/step - loss: 1.2145 - sparse_categorical_accuracy: 0.7710 - val_loss: 2.5489 - val_sparse_categorical_accuracy: 0.8340
# Epoch 35/50
# 2/2 [==============================] - 1s 587ms/step - loss: 1.2181 - sparse_categorical_accuracy: 0.7675 - val_loss: 2.5054 - val_sparse_categorical_accuracy: 0.8380
# Epoch 36/50
# 2/2 [==============================] - 1s 584ms/step - loss: 1.2222 - sparse_categorical_accuracy: 0.7800 - val_loss: 2.4652 - val_sparse_categorical_accuracy: 0.8375
# Epoch 37/50
# 2/2 [==============================] - 1s 585ms/step - loss: 1.2272 - sparse_categorical_accuracy: 0.7630 - val_loss: 2.4284 - val_sparse_categorical_accuracy: 0.8365
# Epoch 38/50
# 2/2 [==============================] - 1s 597ms/step - loss: 1.2122 - sparse_categorical_accuracy: 0.7610 - val_loss: 2.3970 - val_sparse_categorical_accuracy: 0.8385
# Epoch 39/50
# 2/2 [==============================] - 1s 591ms/step - loss: 1.1927 - sparse_categorical_accuracy: 0.7630 - val_loss: 2.3633 - val_sparse_categorical_accuracy: 0.8380
# Epoch 40/50
# 2/2 [==============================] - 1s 594ms/step - loss: 1.1313 - sparse_categorical_accuracy: 0.7820 - val_loss: 2.3203 - val_sparse_categorical_accuracy: 0.8410
# Epoch 41/50
# 2/2 [==============================] - 1s 584ms/step - loss: 1.1260 - sparse_categorical_accuracy: 0.7730 - val_loss: 2.2764 - val_sparse_categorical_accuracy: 0.8450
# Epoch 42/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.1620 - sparse_categorical_accuracy: 0.7690 - val_loss: 2.2368 - val_sparse_categorical_accuracy: 0.8470
# Epoch 43/50
# 2/2 [==============================] - 1s 583ms/step - loss: 1.1587 - sparse_categorical_accuracy: 0.7685 - val_loss: 2.2019 - val_sparse_categorical_accuracy: 0.8475
# Epoch 44/50
# 2/2 [==============================] - 1s 588ms/step - loss: 1.1149 - sparse_categorical_accuracy: 0.7815 - val_loss: 2.1670 - val_sparse_categorical_accuracy: 0.8500
# Epoch 45/50
# 2/2 [==============================] - 1s 588ms/step - loss: 1.1392 - sparse_categorical_accuracy: 0.7790 - val_loss: 2.1379 - val_sparse_categorical_accuracy: 0.8505
# Epoch 46/50
# 2/2 [==============================] - 1s 593ms/step - loss: 1.1622 - sparse_categorical_accuracy: 0.7590 - val_loss: 2.1135 - val_sparse_categorical_accuracy: 0.8505
# Epoch 47/50
# 2/2 [==============================] - 1s 586ms/step - loss: 1.1180 - sparse_categorical_accuracy: 0.7785 - val_loss: 2.0896 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 591ms/step - loss: 1.1246 - sparse_categorical_accuracy: 0.7690 - val_loss: 2.0657 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 587ms/step - loss: 1.1045 - sparse_categorical_accuracy: 0.7595 - val_loss: 2.0410 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 597ms/step - loss: 1.0903 - sparse_categorical_accuracy: 0.7730 - val_loss: 2.0199 - val_sparse_categorical_accuracy: 0.8510
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 2/2 [==============================] - 1s 629ms/step - loss: 1.1322 - sparse_categorical_accuracy: 0.7610 - val_loss: 2.0034 - val_sparse_categorical_accuracy: 0.8510
# Epoch 2/50
# 2/2 [==============================] - 1s 598ms/step - loss: 1.1030 - sparse_categorical_accuracy: 0.7680 - val_loss: 1.9853 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 2/2 [==============================] - 1s 602ms/step - loss: 1.1156 - sparse_categorical_accuracy: 0.7700 - val_loss: 1.9647 - val_sparse_categorical_accuracy: 0.8510
# Epoch 4/50
# 2/2 [==============================] - 1s 595ms/step - loss: 1.1298 - sparse_categorical_accuracy: 0.7670 - val_loss: 1.9428 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/50
# 2/2 [==============================] - 1s 599ms/step - loss: 1.1167 - sparse_categorical_accuracy: 0.7555 - val_loss: 1.9210 - val_sparse_categorical_accuracy: 0.8510
# Epoch 6/50
# 2/2 [==============================] - 1s 597ms/step - loss: 1.0728 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.8982 - val_sparse_categorical_accuracy: 0.8510
# Epoch 7/50
# 2/2 [==============================] - 1s 585ms/step - loss: 1.1123 - sparse_categorical_accuracy: 0.7715 - val_loss: 1.8791 - val_sparse_categorical_accuracy: 0.8505
# Epoch 8/50
# 2/2 [==============================] - 1s 589ms/step - loss: 1.0187 - sparse_categorical_accuracy: 0.7955 - val_loss: 1.8625 - val_sparse_categorical_accuracy: 0.8510
# Epoch 9/50
# 2/2 [==============================] - 1s 586ms/step - loss: 1.0709 - sparse_categorical_accuracy: 0.7620 - val_loss: 1.8502 - val_sparse_categorical_accuracy: 0.8510
# Epoch 10/50
# 2/2 [==============================] - 1s 592ms/step - loss: 1.0460 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.8350 - val_sparse_categorical_accuracy: 0.8510
# Epoch 11/50
# 2/2 [==============================] - 1s 585ms/step - loss: 1.0490 - sparse_categorical_accuracy: 0.7675 - val_loss: 1.8204 - val_sparse_categorical_accuracy: 0.8510
# Epoch 12/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.0496 - sparse_categorical_accuracy: 0.7740 - val_loss: 1.8067 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 701ms/step - loss: 0.9903 - sparse_categorical_accuracy: 0.7830 - val_loss: 1.7956 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 600ms/step - loss: 1.0609 - sparse_categorical_accuracy: 0.7720 - val_loss: 1.7858 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 582ms/step - loss: 1.0222 - sparse_categorical_accuracy: 0.7780 - val_loss: 1.7747 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 1s 600ms/step - loss: 1.0242 - sparse_categorical_accuracy: 0.7650 - val_loss: 1.7632 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# 2/2 [==============================] - 1s 590ms/step - loss: 1.0213 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.7507 - val_sparse_categorical_accuracy: 0.8510
# Epoch 18/50
# 2/2 [==============================] - 1s 596ms/step - loss: 1.0079 - sparse_categorical_accuracy: 0.7875 - val_loss: 1.7381 - val_sparse_categorical_accuracy: 0.8510
# Epoch 19/50
# 2/2 [==============================] - 1s 605ms/step - loss: 1.0056 - sparse_categorical_accuracy: 0.7745 - val_loss: 1.7282 - val_sparse_categorical_accuracy: 0.8510
# Epoch 20/50
# 2/2 [==============================] - 1s 598ms/step - loss: 1.0086 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.7190 - val_sparse_categorical_accuracy: 0.8510
# Epoch 21/50
# 2/2 [==============================] - 1s 610ms/step - loss: 1.0099 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.7109 - val_sparse_categorical_accuracy: 0.8510
# Epoch 22/50
# 2/2 [==============================] - 1s 600ms/step - loss: 1.0105 - sparse_categorical_accuracy: 0.7685 - val_loss: 1.7039 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/50
# 2/2 [==============================] - 1s 598ms/step - loss: 0.9827 - sparse_categorical_accuracy: 0.7680 - val_loss: 1.6948 - val_sparse_categorical_accuracy: 0.8510
# Epoch 24/50
# 2/2 [==============================] - 1s 609ms/step - loss: 1.0145 - sparse_categorical_accuracy: 0.7610 - val_loss: 1.6883 - val_sparse_categorical_accuracy: 0.8510
# Epoch 25/50
# 2/2 [==============================] - 1s 602ms/step - loss: 0.9839 - sparse_categorical_accuracy: 0.7825 - val_loss: 1.6816 - val_sparse_categorical_accuracy: 0.8510
# Epoch 26/50
# 2/2 [==============================] - 1s 584ms/step - loss: 0.9347 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.6765 - val_sparse_categorical_accuracy: 0.8510
# Epoch 27/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.9792 - sparse_categorical_accuracy: 0.7735 - val_loss: 1.6719 - val_sparse_categorical_accuracy: 0.8510
# Epoch 28/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.9588 - sparse_categorical_accuracy: 0.7780 - val_loss: 1.6679 - val_sparse_categorical_accuracy: 0.8510
# Epoch 29/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.9517 - sparse_categorical_accuracy: 0.7700 - val_loss: 1.6639 - val_sparse_categorical_accuracy: 0.8510
# Epoch 30/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.9544 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.6629 - val_sparse_categorical_accuracy: 0.8510
# Epoch 31/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.9756 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.6623 - val_sparse_categorical_accuracy: 0.8510
# Epoch 32/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.9275 - sparse_categorical_accuracy: 0.7875 - val_loss: 1.6606 - val_sparse_categorical_accuracy: 0.8510
# Epoch 33/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.9299 - sparse_categorical_accuracy: 0.7900 - val_loss: 1.6594 - val_sparse_categorical_accuracy: 0.8510
# Epoch 34/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.9142 - sparse_categorical_accuracy: 0.7855 - val_loss: 1.6571 - val_sparse_categorical_accuracy: 0.8510
# Epoch 35/50
# 2/2 [==============================] - 1s 590ms/step - loss: 0.9659 - sparse_categorical_accuracy: 0.7740 - val_loss: 1.6536 - val_sparse_categorical_accuracy: 0.8510
# Epoch 36/50
# 2/2 [==============================] - 1s 582ms/step - loss: 0.9592 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.6501 - val_sparse_categorical_accuracy: 0.8510
# Epoch 37/50
# 2/2 [==============================] - 1s 594ms/step - loss: 0.9422 - sparse_categorical_accuracy: 0.7785 - val_loss: 1.6473 - val_sparse_categorical_accuracy: 0.8510
# Epoch 38/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.9564 - sparse_categorical_accuracy: 0.7640 - val_loss: 1.6457 - val_sparse_categorical_accuracy: 0.8510
# Epoch 39/50
# 2/2 [==============================] - 1s 584ms/step - loss: 0.9492 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.6455 - val_sparse_categorical_accuracy: 0.8510
# Epoch 40/50
# 2/2 [==============================] - 1s 583ms/step - loss: 0.9587 - sparse_categorical_accuracy: 0.7825 - val_loss: 1.6465 - val_sparse_categorical_accuracy: 0.8510
# Epoch 41/50
# 2/2 [==============================] - 1s 584ms/step - loss: 0.9440 - sparse_categorical_accuracy: 0.7705 - val_loss: 1.6484 - val_sparse_categorical_accuracy: 0.8510
# Epoch 42/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.9350 - sparse_categorical_accuracy: 0.7765 - val_loss: 1.6488 - val_sparse_categorical_accuracy: 0.8510
# Epoch 43/50
# 2/2 [==============================] - 1s 584ms/step - loss: 0.9102 - sparse_categorical_accuracy: 0.7810 - val_loss: 1.6494 - val_sparse_categorical_accuracy: 0.8510
# Epoch 44/50
# 2/2 [==============================] - 1s 595ms/step - loss: 0.9305 - sparse_categorical_accuracy: 0.7795 - val_loss: 1.6485 - val_sparse_categorical_accuracy: 0.8510
# Epoch 45/50
# 2/2 [==============================] - 1s 582ms/step - loss: 0.8763 - sparse_categorical_accuracy: 0.7975 - val_loss: 1.6457 - val_sparse_categorical_accuracy: 0.8510
# Epoch 46/50
# 2/2 [==============================] - 1s 596ms/step - loss: 0.9324 - sparse_categorical_accuracy: 0.7655 - val_loss: 1.6431 - val_sparse_categorical_accuracy: 0.8510
# Epoch 47/50
# 2/2 [==============================] - 1s 594ms/step - loss: 0.9690 - sparse_categorical_accuracy: 0.7655 - val_loss: 1.6411 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 585ms/step - loss: 0.8898 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.6392 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 597ms/step - loss: 0.9167 - sparse_categorical_accuracy: 0.7885 - val_loss: 1.6380 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 583ms/step - loss: 0.9551 - sparse_categorical_accuracy: 0.7705 - val_loss: 1.6368 - val_sparse_categorical_accuracy: 0.8510
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 2/2 [==============================] - 1s 624ms/step - loss: 0.9397 - sparse_categorical_accuracy: 0.7765 - val_loss: 1.6364 - val_sparse_categorical_accuracy: 0.8510
# Epoch 2/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.9114 - sparse_categorical_accuracy: 0.7890 - val_loss: 1.6363 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.9071 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.6371 - val_sparse_categorical_accuracy: 0.8510
# Epoch 4/50
# 2/2 [==============================] - 1s 692ms/step - loss: 0.9684 - sparse_categorical_accuracy: 0.7640 - val_loss: 1.6388 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.8702 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.6402 - val_sparse_categorical_accuracy: 0.8510
# Epoch 6/50
# 2/2 [==============================] - 1s 585ms/step - loss: 0.9205 - sparse_categorical_accuracy: 0.7670 - val_loss: 1.6418 - val_sparse_categorical_accuracy: 0.8510
# Epoch 7/50
# 2/2 [==============================] - 1s 583ms/step - loss: 0.8906 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.6433 - val_sparse_categorical_accuracy: 0.8510
# Epoch 8/50
# 2/2 [==============================] - 1s 599ms/step - loss: 0.8940 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.6440 - val_sparse_categorical_accuracy: 0.8510
# Epoch 9/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.9415 - sparse_categorical_accuracy: 0.7690 - val_loss: 1.6438 - val_sparse_categorical_accuracy: 0.8510
# Epoch 10/50
# 2/2 [==============================] - 1s 594ms/step - loss: 0.9182 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.6432 - val_sparse_categorical_accuracy: 0.8510
# Epoch 11/50
# 2/2 [==============================] - 1s 582ms/step - loss: 0.8483 - sparse_categorical_accuracy: 0.8010 - val_loss: 1.6430 - val_sparse_categorical_accuracy: 0.8510
# Epoch 12/50
# 2/2 [==============================] - 1s 594ms/step - loss: 0.9116 - sparse_categorical_accuracy: 0.7725 - val_loss: 1.6439 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 590ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.7955 - val_loss: 1.6456 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 599ms/step - loss: 0.9205 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.6474 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 603ms/step - loss: 0.9071 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.6485 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 1s 583ms/step - loss: 0.8758 - sparse_categorical_accuracy: 0.7785 - val_loss: 1.6492 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# 2/2 [==============================] - 1s 590ms/step - loss: 0.8606 - sparse_categorical_accuracy: 0.7935 - val_loss: 1.6499 - val_sparse_categorical_accuracy: 0.8510
# Epoch 18/50
# 2/2 [==============================] - 1s 588ms/step - loss: 0.8893 - sparse_categorical_accuracy: 0.7780 - val_loss: 1.6510 - val_sparse_categorical_accuracy: 0.8510
# Epoch 19/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.8653 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.6526 - val_sparse_categorical_accuracy: 0.8510
# Epoch 20/50
# 2/2 [==============================] - 1s 601ms/step - loss: 0.8408 - sparse_categorical_accuracy: 0.8010 - val_loss: 1.6543 - val_sparse_categorical_accuracy: 0.8510
# Epoch 21/50
# 2/2 [==============================] - 1s 596ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.7895 - val_loss: 1.6563 - val_sparse_categorical_accuracy: 0.8510
# Epoch 22/50
# 2/2 [==============================] - 1s 585ms/step - loss: 0.8447 - sparse_categorical_accuracy: 0.7950 - val_loss: 1.6576 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/50
# 2/2 [==============================] - 1s 590ms/step - loss: 0.8755 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.6591 - val_sparse_categorical_accuracy: 0.8510
# Epoch 24/50
# 2/2 [==============================] - 1s 595ms/step - loss: 0.8460 - sparse_categorical_accuracy: 0.7905 - val_loss: 1.6601 - val_sparse_categorical_accuracy: 0.8510
# Epoch 25/50
# 2/2 [==============================] - 1s 585ms/step - loss: 0.8794 - sparse_categorical_accuracy: 0.7830 - val_loss: 1.6611 - val_sparse_categorical_accuracy: 0.8510
# Epoch 26/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.9065 - sparse_categorical_accuracy: 0.7660 - val_loss: 1.6622 - val_sparse_categorical_accuracy: 0.8510
# Epoch 27/50
# 2/2 [==============================] - 1s 578ms/step - loss: 0.8708 - sparse_categorical_accuracy: 0.7740 - val_loss: 1.6638 - val_sparse_categorical_accuracy: 0.8510
# Epoch 28/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.8862 - sparse_categorical_accuracy: 0.7755 - val_loss: 1.6650 - val_sparse_categorical_accuracy: 0.8510
# Epoch 29/50
# 2/2 [==============================] - 1s 602ms/step - loss: 0.8831 - sparse_categorical_accuracy: 0.7680 - val_loss: 1.6655 - val_sparse_categorical_accuracy: 0.8510
# Epoch 30/50
# 2/2 [==============================] - 1s 599ms/step - loss: 0.8642 - sparse_categorical_accuracy: 0.7945 - val_loss: 1.6658 - val_sparse_categorical_accuracy: 0.8510
# Epoch 31/50
# 2/2 [==============================] - 1s 613ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.7820 - val_loss: 1.6660 - val_sparse_categorical_accuracy: 0.8510
# Epoch 32/50
# 2/2 [==============================] - 1s 588ms/step - loss: 0.8757 - sparse_categorical_accuracy: 0.7710 - val_loss: 1.6660 - val_sparse_categorical_accuracy: 0.8510
# Epoch 33/50
# 2/2 [==============================] - 1s 595ms/step - loss: 0.8529 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.6664 - val_sparse_categorical_accuracy: 0.8510
# Epoch 34/50
# 2/2 [==============================] - 1s 603ms/step - loss: 0.8478 - sparse_categorical_accuracy: 0.7835 - val_loss: 1.6672 - val_sparse_categorical_accuracy: 0.8510
# Epoch 35/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.7860 - val_loss: 1.6680 - val_sparse_categorical_accuracy: 0.8510
# Epoch 36/50
# 2/2 [==============================] - 1s 587ms/step - loss: 0.7966 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.6685 - val_sparse_categorical_accuracy: 0.8510
# Epoch 37/50
# 2/2 [==============================] - 1s 617ms/step - loss: 0.8778 - sparse_categorical_accuracy: 0.7710 - val_loss: 1.6694 - val_sparse_categorical_accuracy: 0.8510
# Epoch 38/50
# 2/2 [==============================] - 1s 588ms/step - loss: 0.8834 - sparse_categorical_accuracy: 0.7770 - val_loss: 1.6703 - val_sparse_categorical_accuracy: 0.8510
# Epoch 39/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.8692 - sparse_categorical_accuracy: 0.7705 - val_loss: 1.6721 - val_sparse_categorical_accuracy: 0.8510
# Epoch 40/50
# 2/2 [==============================] - 1s 617ms/step - loss: 0.8709 - sparse_categorical_accuracy: 0.7750 - val_loss: 1.6738 - val_sparse_categorical_accuracy: 0.8510
# Epoch 41/50
# 2/2 [==============================] - 1s 611ms/step - loss: 0.8305 - sparse_categorical_accuracy: 0.7975 - val_loss: 1.6752 - val_sparse_categorical_accuracy: 0.8510
# Epoch 42/50
# 2/2 [==============================] - 1s 600ms/step - loss: 0.8409 - sparse_categorical_accuracy: 0.7810 - val_loss: 1.6763 - val_sparse_categorical_accuracy: 0.8510
# Epoch 43/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.8746 - sparse_categorical_accuracy: 0.7860 - val_loss: 1.6775 - val_sparse_categorical_accuracy: 0.8510
# Epoch 44/50
# 2/2 [==============================] - 1s 615ms/step - loss: 0.8233 - sparse_categorical_accuracy: 0.7945 - val_loss: 1.6790 - val_sparse_categorical_accuracy: 0.8510
# Epoch 45/50
# 2/2 [==============================] - 1s 606ms/step - loss: 0.8735 - sparse_categorical_accuracy: 0.7705 - val_loss: 1.6806 - val_sparse_categorical_accuracy: 0.8510
# Epoch 46/50
# 2/2 [==============================] - 1s 612ms/step - loss: 0.8591 - sparse_categorical_accuracy: 0.7900 - val_loss: 1.6825 - val_sparse_categorical_accuracy: 0.8510
# Epoch 47/50
# 2/2 [==============================] - 1s 599ms/step - loss: 0.7976 - sparse_categorical_accuracy: 0.7900 - val_loss: 1.6840 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 620ms/step - loss: 0.8414 - sparse_categorical_accuracy: 0.7860 - val_loss: 1.6852 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 602ms/step - loss: 0.8325 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.6858 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 595ms/step - loss: 0.8430 - sparse_categorical_accuracy: 0.7920 - val_loss: 1.6869 - val_sparse_categorical_accuracy: 0.8510
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 2/2 [==============================] - 1s 636ms/step - loss: 0.8531 - sparse_categorical_accuracy: 0.7905 - val_loss: 1.6880 - val_sparse_categorical_accuracy: 0.8510
# Epoch 2/50
# 2/2 [==============================] - 1s 595ms/step - loss: 0.8646 - sparse_categorical_accuracy: 0.7720 - val_loss: 1.6894 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 2/2 [==============================] - 1s 584ms/step - loss: 0.8185 - sparse_categorical_accuracy: 0.7985 - val_loss: 1.6906 - val_sparse_categorical_accuracy: 0.8510
# Epoch 4/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.8193 - sparse_categorical_accuracy: 0.7745 - val_loss: 1.6918 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/50
# 2/2 [==============================] - 1s 715ms/step - loss: 0.7937 - sparse_categorical_accuracy: 0.7985 - val_loss: 1.6927 - val_sparse_categorical_accuracy: 0.8510
# Epoch 6/50
# 2/2 [==============================] - 1s 601ms/step - loss: 0.7982 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.6938 - val_sparse_categorical_accuracy: 0.8510
# Epoch 7/50
# 2/2 [==============================] - 1s 591ms/step - loss: 0.8373 - sparse_categorical_accuracy: 0.7840 - val_loss: 1.6951 - val_sparse_categorical_accuracy: 0.8510
# Epoch 8/50
# 2/2 [==============================] - 1s 606ms/step - loss: 0.8485 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.6964 - val_sparse_categorical_accuracy: 0.8510
# Epoch 9/50
# 2/2 [==============================] - 1s 596ms/step - loss: 0.8385 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.6982 - val_sparse_categorical_accuracy: 0.8510
# Epoch 10/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.8241 - sparse_categorical_accuracy: 0.7900 - val_loss: 1.6997 - val_sparse_categorical_accuracy: 0.8510
# Epoch 11/50
# 2/2 [==============================] - 1s 592ms/step - loss: 0.8118 - sparse_categorical_accuracy: 0.7980 - val_loss: 1.7012 - val_sparse_categorical_accuracy: 0.8510
# Epoch 12/50
# 2/2 [==============================] - 1s 604ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.7925 - val_loss: 1.7027 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 598ms/step - loss: 0.8510 - sparse_categorical_accuracy: 0.7820 - val_loss: 1.7043 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 585ms/step - loss: 0.7986 - sparse_categorical_accuracy: 0.8025 - val_loss: 1.7060 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 587ms/step - loss: 0.8301 - sparse_categorical_accuracy: 0.7895 - val_loss: 1.7072 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 1s 603ms/step - loss: 0.7907 - sparse_categorical_accuracy: 0.7975 - val_loss: 1.7087 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# 2/2 [==============================] - 1s 593ms/step - loss: 0.8124 - sparse_categorical_accuracy: 0.7870 - val_loss: 1.7101 - val_sparse_categorical_accuracy: 0.8510
# Epoch 18/50
# 2/2 [==============================] - 1s 589ms/step - loss: 0.8026 - sparse_categorical_accuracy: 0.7875 - val_loss: 1.7111 - val_sparse_categorical_accuracy: 0.8510
# Epoch 19/50
# 2/2 [==============================] - 1s 594ms/step - loss: 0.8213 - sparse_categorical_accuracy: 0.7910 - val_loss: 1.7120 - val_sparse_categorical_accuracy: 0.8510
# Epoch 20/50
# 2/2 [==============================] - 1s 600ms/step - loss: 0.8119 - sparse_categorical_accuracy: 0.8040 - val_loss: 1.7135 - val_sparse_categorical_accuracy: 0.8510
# Epoch 21/50
# 2/2 [==============================] - 1s 601ms/step - loss: 0.8278 - sparse_categorical_accuracy: 0.7820 - val_loss: 1.7146 - val_sparse_categorical_accuracy: 0.8510
# Epoch 22/50
# 2/2 [==============================] - 1s 586ms/step - loss: 0.8127 - sparse_categorical_accuracy: 0.7910 - val_loss: 1.7159 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/50
# 2/2 [==============================] - 1s 628ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.7990 - val_loss: 1.7178 - val_sparse_categorical_accuracy: 0.8510
# Epoch 24/50
# 2/2 [==============================] - 1s 629ms/step - loss: 0.8109 - sparse_categorical_accuracy: 0.7905 - val_loss: 1.7193 - val_sparse_categorical_accuracy: 0.8510
# Epoch 25/50
# 2/2 [==============================] - 1s 634ms/step - loss: 0.8238 - sparse_categorical_accuracy: 0.7905 - val_loss: 1.7204 - val_sparse_categorical_accuracy: 0.8510
# Epoch 26/50
# 2/2 [==============================] - 1s 628ms/step - loss: 0.8016 - sparse_categorical_accuracy: 0.7920 - val_loss: 1.7219 - val_sparse_categorical_accuracy: 0.8510
# Epoch 27/50
# 2/2 [==============================] - 1s 626ms/step - loss: 0.8255 - sparse_categorical_accuracy: 0.7895 - val_loss: 1.7230 - val_sparse_categorical_accuracy: 0.8510
# Epoch 28/50
# 2/2 [==============================] - 1s 613ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.7905 - val_loss: 1.7242 - val_sparse_categorical_accuracy: 0.8510
# Epoch 29/50
# 2/2 [==============================] - 1s 620ms/step - loss: 0.8148 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.7256 - val_sparse_categorical_accuracy: 0.8510
# Epoch 30/50
# 2/2 [==============================] - 1s 623ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.7270 - val_sparse_categorical_accuracy: 0.8510
# Epoch 31/50
# 2/2 [==============================] - 1s 645ms/step - loss: 0.7907 - sparse_categorical_accuracy: 0.7975 - val_loss: 1.7278 - val_sparse_categorical_accuracy: 0.8510
# Epoch 32/50
# 2/2 [==============================] - 1s 637ms/step - loss: 0.8282 - sparse_categorical_accuracy: 0.7860 - val_loss: 1.7279 - val_sparse_categorical_accuracy: 0.8510
# Epoch 33/50
# 2/2 [==============================] - 1s 637ms/step - loss: 0.8078 - sparse_categorical_accuracy: 0.7975 - val_loss: 1.7282 - val_sparse_categorical_accuracy: 0.8510
# Epoch 34/50
# 2/2 [==============================] - 1s 625ms/step - loss: 0.7813 - sparse_categorical_accuracy: 0.7990 - val_loss: 1.7288 - val_sparse_categorical_accuracy: 0.8510
# Epoch 35/50
# 2/2 [==============================] - 1s 615ms/step - loss: 0.7672 - sparse_categorical_accuracy: 0.7960 - val_loss: 1.7294 - val_sparse_categorical_accuracy: 0.8510
# Epoch 36/50
# 2/2 [==============================] - 1s 628ms/step - loss: 0.8146 - sparse_categorical_accuracy: 0.7830 - val_loss: 1.7302 - val_sparse_categorical_accuracy: 0.8510
# Epoch 37/50
# 2/2 [==============================] - 1s 624ms/step - loss: 0.7577 - sparse_categorical_accuracy: 0.7980 - val_loss: 1.7314 - val_sparse_categorical_accuracy: 0.8510
# Epoch 38/50
# 2/2 [==============================] - 1s 623ms/step - loss: 0.8345 - sparse_categorical_accuracy: 0.7785 - val_loss: 1.7329 - val_sparse_categorical_accuracy: 0.8510
# Epoch 39/50
# 2/2 [==============================] - 1s 635ms/step - loss: 0.7869 - sparse_categorical_accuracy: 0.7890 - val_loss: 1.7342 - val_sparse_categorical_accuracy: 0.8510
# Epoch 40/50
# 2/2 [==============================] - 1s 625ms/step - loss: 0.8651 - sparse_categorical_accuracy: 0.7755 - val_loss: 1.7358 - val_sparse_categorical_accuracy: 0.8510
# Epoch 41/50
# 2/2 [==============================] - 1s 632ms/step - loss: 0.8069 - sparse_categorical_accuracy: 0.7910 - val_loss: 1.7372 - val_sparse_categorical_accuracy: 0.8510
# Epoch 42/50
# 2/2 [==============================] - 1s 626ms/step - loss: 0.8234 - sparse_categorical_accuracy: 0.7835 - val_loss: 1.7385 - val_sparse_categorical_accuracy: 0.8510
# Epoch 43/50
# 2/2 [==============================] - 1s 619ms/step - loss: 0.7995 - sparse_categorical_accuracy: 0.7860 - val_loss: 1.7398 - val_sparse_categorical_accuracy: 0.8510
# Epoch 44/50
# 2/2 [==============================] - 1s 612ms/step - loss: 0.8262 - sparse_categorical_accuracy: 0.7795 - val_loss: 1.7407 - val_sparse_categorical_accuracy: 0.8510
# Epoch 45/50
# 2/2 [==============================] - 1s 616ms/step - loss: 0.7803 - sparse_categorical_accuracy: 0.7970 - val_loss: 1.7419 - val_sparse_categorical_accuracy: 0.8510
# Epoch 46/50
# 2/2 [==============================] - 1s 615ms/step - loss: 0.8274 - sparse_categorical_accuracy: 0.7895 - val_loss: 1.7429 - val_sparse_categorical_accuracy: 0.8510
# Epoch 47/50
# 2/2 [==============================] - 1s 793ms/step - loss: 0.8301 - sparse_categorical_accuracy: 0.7755 - val_loss: 1.7437 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 618ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.7885 - val_loss: 1.7445 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 621ms/step - loss: 0.8239 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.7460 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 636ms/step - loss: 0.8338 - sparse_categorical_accuracy: 0.7855 - val_loss: 1.7476 - val_sparse_categorical_accuracy: 0.8510
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 2/2 [==============================] - 1s 682ms/step - loss: 0.8156 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.7491 - val_sparse_categorical_accuracy: 0.8510
# Epoch 2/50
# 2/2 [==============================] - 1s 627ms/step - loss: 0.8222 - sparse_categorical_accuracy: 0.7765 - val_loss: 1.7501 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 2/2 [==============================] - 1s 616ms/step - loss: 0.8132 - sparse_categorical_accuracy: 0.7780 - val_loss: 1.7512 - val_sparse_categorical_accuracy: 0.8510
# Epoch 4/50
# 2/2 [==============================] - 1s 640ms/step - loss: 0.7653 - sparse_categorical_accuracy: 0.8045 - val_loss: 1.7522 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/50
# 2/2 [==============================] - 1s 625ms/step - loss: 0.7945 - sparse_categorical_accuracy: 0.7890 - val_loss: 1.7532 - val_sparse_categorical_accuracy: 0.8510
# Epoch 6/50
# 2/2 [==============================] - 1s 621ms/step - loss: 0.8231 - sparse_categorical_accuracy: 0.7740 - val_loss: 1.7549 - val_sparse_categorical_accuracy: 0.8510
# Epoch 7/50
# 2/2 [==============================] - 1s 618ms/step - loss: 0.8058 - sparse_categorical_accuracy: 0.8020 - val_loss: 1.7563 - val_sparse_categorical_accuracy: 0.8510
# Epoch 8/50
# 2/2 [==============================] - 1s 613ms/step - loss: 0.8073 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.7575 - val_sparse_categorical_accuracy: 0.8510
# Epoch 9/50
# 2/2 [==============================] - 1s 629ms/step - loss: 0.7740 - sparse_categorical_accuracy: 0.7890 - val_loss: 1.7581 - val_sparse_categorical_accuracy: 0.8510
# Epoch 10/50
# 2/2 [==============================] - 1s 636ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.7585 - val_sparse_categorical_accuracy: 0.8510
# Epoch 11/50
# 2/2 [==============================] - 1s 618ms/step - loss: 0.7919 - sparse_categorical_accuracy: 0.7875 - val_loss: 1.7588 - val_sparse_categorical_accuracy: 0.8510
# Epoch 12/50
# 2/2 [==============================] - 1s 618ms/step - loss: 0.7882 - sparse_categorical_accuracy: 0.7910 - val_loss: 1.7590 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 628ms/step - loss: 0.7764 - sparse_categorical_accuracy: 0.7990 - val_loss: 1.7593 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 612ms/step - loss: 0.7962 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.7596 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 628ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.7599 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 2s 910ms/step - loss: 0.7932 - sparse_categorical_accuracy: 0.7795 - val_loss: 1.7601 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# ...
# Epoch 12/50
# 2/2 [==============================] - 1s 661ms/step - loss: 0.6449 - sparse_categorical_accuracy: 0.8210 - val_loss: 1.8806 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 663ms/step - loss: 0.6887 - sparse_categorical_accuracy: 0.7980 - val_loss: 1.8811 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.6727 - sparse_categorical_accuracy: 0.8225 - val_loss: 1.8817 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 663ms/step - loss: 0.6846 - sparse_categorical_accuracy: 0.8130 - val_loss: 1.8821 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 1s 656ms/step - loss: 0.6574 - sparse_categorical_accuracy: 0.8250 - val_loss: 1.8821 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.7132 - sparse_categorical_accuracy: 0.8020 - val_loss: 1.8822 - val_sparse_categorical_accuracy: 0.8510
# Epoch 18/50
# 2/2 [==============================] - 1s 662ms/step - loss: 0.6844 - sparse_categorical_accuracy: 0.8100 - val_loss: 1.8822 - val_sparse_categorical_accuracy: 0.8510
# Epoch 19/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.7025 - sparse_categorical_accuracy: 0.8115 - val_loss: 1.8821 - val_sparse_categorical_accuracy: 0.8510
# Epoch 20/50
# 2/2 [==============================] - 1s 654ms/step - loss: 0.6998 - sparse_categorical_accuracy: 0.8110 - val_loss: 1.8817 - val_sparse_categorical_accuracy: 0.8510
# Epoch 21/50
# 2/2 [==============================] - 1s 663ms/step - loss: 0.6800 - sparse_categorical_accuracy: 0.8110 - val_loss: 1.8815 - val_sparse_categorical_accuracy: 0.8510
# Epoch 22/50
# 2/2 [==============================] - 1s 662ms/step - loss: 0.7096 - sparse_categorical_accuracy: 0.8075 - val_loss: 1.8814 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/50
# 2/2 [==============================] - 1s 651ms/step - loss: 0.6867 - sparse_categorical_accuracy: 0.8045 - val_loss: 1.8817 - val_sparse_categorical_accuracy: 0.8510
# Epoch 24/50
# 2/2 [==============================] - 1s 654ms/step - loss: 0.7749 - sparse_categorical_accuracy: 0.7890 - val_loss: 1.8815 - val_sparse_categorical_accuracy: 0.8510
# Epoch 25/50
# 2/2 [==============================] - 1s 671ms/step - loss: 0.6802 - sparse_categorical_accuracy: 0.8100 - val_loss: 1.8819 - val_sparse_categorical_accuracy: 0.8510
# Epoch 26/50
# 2/2 [==============================] - 1s 691ms/step - loss: 0.6837 - sparse_categorical_accuracy: 0.8055 - val_loss: 1.8820 - val_sparse_categorical_accuracy: 0.8510
# Epoch 27/50
# 2/2 [==============================] - 1s 684ms/step - loss: 0.6976 - sparse_categorical_accuracy: 0.8185 - val_loss: 1.8821 - val_sparse_categorical_accuracy: 0.8510
# Epoch 28/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.6753 - sparse_categorical_accuracy: 0.8125 - val_loss: 1.8818 - val_sparse_categorical_accuracy: 0.8510
# Epoch 29/50
# 2/2 [==============================] - 1s 666ms/step - loss: 0.7760 - sparse_categorical_accuracy: 0.7925 - val_loss: 1.8815 - val_sparse_categorical_accuracy: 0.8510
# Epoch 30/50
# 2/2 [==============================] - 1s 692ms/step - loss: 0.6841 - sparse_categorical_accuracy: 0.8030 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.8510
# Epoch 31/50
# 2/2 [==============================] - 1s 675ms/step - loss: 0.7148 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.8813 - val_sparse_categorical_accuracy: 0.8510
# Epoch 32/50
# 2/2 [==============================] - 1s 643ms/step - loss: 0.6483 - sparse_categorical_accuracy: 0.8150 - val_loss: 1.8814 - val_sparse_categorical_accuracy: 0.8510
# Epoch 33/50
# 2/2 [==============================] - 1s 654ms/step - loss: 0.6757 - sparse_categorical_accuracy: 0.8115 - val_loss: 1.8816 - val_sparse_categorical_accuracy: 0.8510
# Epoch 34/50
# 2/2 [==============================] - 1s 640ms/step - loss: 0.6946 - sparse_categorical_accuracy: 0.8060 - val_loss: 1.8817 - val_sparse_categorical_accuracy: 0.8510
# Epoch 35/50
# 2/2 [==============================] - 1s 646ms/step - loss: 0.7202 - sparse_categorical_accuracy: 0.8020 - val_loss: 1.8820 - val_sparse_categorical_accuracy: 0.8510
# Epoch 36/50
# 2/2 [==============================] - 1s 627ms/step - loss: 0.7026 - sparse_categorical_accuracy: 0.8045 - val_loss: 1.8824 - val_sparse_categorical_accuracy: 0.8510
# Epoch 37/50
# 2/2 [==============================] - 1s 659ms/step - loss: 0.7022 - sparse_categorical_accuracy: 0.8015 - val_loss: 1.8826 - val_sparse_categorical_accuracy: 0.8510
# Epoch 38/50
# 2/2 [==============================] - 1s 637ms/step - loss: 0.7074 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8824 - val_sparse_categorical_accuracy: 0.8510
# Epoch 39/50
# 2/2 [==============================] - 1s 642ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.8185 - val_loss: 1.8819 - val_sparse_categorical_accuracy: 0.8510
# Epoch 40/50
# 2/2 [==============================] - 1s 643ms/step - loss: 0.7218 - sparse_categorical_accuracy: 0.8025 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.8510
# Epoch 41/50
# 2/2 [==============================] - 1s 632ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.8075 - val_loss: 1.8804 - val_sparse_categorical_accuracy: 0.8510
# Epoch 42/50
# 2/2 [==============================] - 1s 640ms/step - loss: 0.6597 - sparse_categorical_accuracy: 0.8240 - val_loss: 1.8798 - val_sparse_categorical_accuracy: 0.8510
# Epoch 43/50
# 2/2 [==============================] - 1s 662ms/step - loss: 0.6974 - sparse_categorical_accuracy: 0.8065 - val_loss: 1.8792 - val_sparse_categorical_accuracy: 0.8510
# Epoch 44/50
# 2/2 [==============================] - 1s 671ms/step - loss: 0.7197 - sparse_categorical_accuracy: 0.8045 - val_loss: 1.8787 - val_sparse_categorical_accuracy: 0.8510
# Epoch 45/50
# 2/2 [==============================] - 1s 833ms/step - loss: 0.7092 - sparse_categorical_accuracy: 0.8075 - val_loss: 1.8788 - val_sparse_categorical_accuracy: 0.8510
# Epoch 46/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.6735 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8791 - val_sparse_categorical_accuracy: 0.8510
# Epoch 47/50
# 2/2 [==============================] - 1s 617ms/step - loss: 0.6799 - sparse_categorical_accuracy: 0.8125 - val_loss: 1.8793 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 631ms/step - loss: 0.7655 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.8793 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 653ms/step - loss: 0.6905 - sparse_categorical_accuracy: 0.8030 - val_loss: 1.8792 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 644ms/step - loss: 0.7116 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.8788 - val_sparse_categorical_accuracy: 0.8510
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 2/2 [==============================] - 1s 690ms/step - loss: 0.6716 - sparse_categorical_accuracy: 0.8120 - val_loss: 1.8784 - val_sparse_categorical_accuracy: 0.8510
# Epoch 2/50
# 2/2 [==============================] - 1s 641ms/step - loss: 0.7179 - sparse_categorical_accuracy: 0.8085 - val_loss: 1.8782 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 2/2 [==============================] - 1s 650ms/step - loss: 0.6606 - sparse_categorical_accuracy: 0.8115 - val_loss: 1.8781 - val_sparse_categorical_accuracy: 0.8510
# Epoch 4/50
# 2/2 [==============================] - 1s 630ms/step - loss: 0.6777 - sparse_categorical_accuracy: 0.8155 - val_loss: 1.8786 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/50
# 2/2 [==============================] - 1s 638ms/step - loss: 0.6540 - sparse_categorical_accuracy: 0.8160 - val_loss: 1.8788 - val_sparse_categorical_accuracy: 0.8510
# Epoch 6/50
# 2/2 [==============================] - 1s 652ms/step - loss: 0.6567 - sparse_categorical_accuracy: 0.8020 - val_loss: 1.8790 - val_sparse_categorical_accuracy: 0.8510
# Epoch 7/50
# 2/2 [==============================] - 1s 651ms/step - loss: 0.6707 - sparse_categorical_accuracy: 0.8140 - val_loss: 1.8792 - val_sparse_categorical_accuracy: 0.8510
# Epoch 8/50
# 2/2 [==============================] - 1s 654ms/step - loss: 0.7001 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8791 - val_sparse_categorical_accuracy: 0.8510
# Epoch 9/50
# 2/2 [==============================] - 1s 642ms/step - loss: 0.7296 - sparse_categorical_accuracy: 0.8080 - val_loss: 1.8791 - val_sparse_categorical_accuracy: 0.8510
# Epoch 10/50
# 2/2 [==============================] - 1s 624ms/step - loss: 0.6938 - sparse_categorical_accuracy: 0.8135 - val_loss: 1.8793 - val_sparse_categorical_accuracy: 0.8510
# Epoch 11/50
# 2/2 [==============================] - 1s 633ms/step - loss: 0.6537 - sparse_categorical_accuracy: 0.8220 - val_loss: 1.8798 - val_sparse_categorical_accuracy: 0.8510
# Epoch 12/50
# 2/2 [==============================] - 1s 633ms/step - loss: 0.7052 - sparse_categorical_accuracy: 0.8035 - val_loss: 1.8803 - val_sparse_categorical_accuracy: 0.8510
# Epoch 13/50
# 2/2 [==============================] - 1s 650ms/step - loss: 0.6972 - sparse_categorical_accuracy: 0.8130 - val_loss: 1.8807 - val_sparse_categorical_accuracy: 0.8510
# Epoch 14/50
# 2/2 [==============================] - 1s 645ms/step - loss: 0.7136 - sparse_categorical_accuracy: 0.8030 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.8510
# Epoch 15/50
# 2/2 [==============================] - 1s 645ms/step - loss: 0.7480 - sparse_categorical_accuracy: 0.7990 - val_loss: 1.8814 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/50
# 2/2 [==============================] - 1s 650ms/step - loss: 0.7261 - sparse_categorical_accuracy: 0.7945 - val_loss: 1.8818 - val_sparse_categorical_accuracy: 0.8510
# Epoch 17/50
# 2/2 [==============================] - 1s 631ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.8065 - val_loss: 1.8823 - val_sparse_categorical_accuracy: 0.8510
# Epoch 18/50
# 2/2 [==============================] - 1s 624ms/step - loss: 0.7080 - sparse_categorical_accuracy: 0.7980 - val_loss: 1.8828 - val_sparse_categorical_accuracy: 0.8510
# Epoch 19/50
# 2/2 [==============================] - 1s 650ms/step - loss: 0.7199 - sparse_categorical_accuracy: 0.8000 - val_loss: 1.8836 - val_sparse_categorical_accuracy: 0.8510
# Epoch 20/50
# 2/2 [==============================] - 1s 665ms/step - loss: 0.7250 - sparse_categorical_accuracy: 0.7910 - val_loss: 1.8845 - val_sparse_categorical_accuracy: 0.8510
# Epoch 21/50
# 2/2 [==============================] - 1s 658ms/step - loss: 0.7150 - sparse_categorical_accuracy: 0.8060 - val_loss: 1.8851 - val_sparse_categorical_accuracy: 0.8510
# Epoch 22/50
# 2/2 [==============================] - 1s 664ms/step - loss: 0.6177 - sparse_categorical_accuracy: 0.8270 - val_loss: 1.8854 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/50
# 2/2 [==============================] - 1s 671ms/step - loss: 0.7571 - sparse_categorical_accuracy: 0.7830 - val_loss: 1.8852 - val_sparse_categorical_accuracy: 0.8510
# Epoch 24/50
# 2/2 [==============================] - 1s 655ms/step - loss: 0.6640 - sparse_categorical_accuracy: 0.8115 - val_loss: 1.8848 - val_sparse_categorical_accuracy: 0.8510
# Epoch 25/50
# 2/2 [==============================] - 1s 643ms/step - loss: 0.6767 - sparse_categorical_accuracy: 0.8075 - val_loss: 1.8845 - val_sparse_categorical_accuracy: 0.8510
# Epoch 26/50
# 2/2 [==============================] - 1s 673ms/step - loss: 0.7045 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8841 - val_sparse_categorical_accuracy: 0.8510
# Epoch 27/50
# 2/2 [==============================] - 1s 678ms/step - loss: 0.7148 - sparse_categorical_accuracy: 0.8010 - val_loss: 1.8833 - val_sparse_categorical_accuracy: 0.8510
# Epoch 28/50
# 2/2 [==============================] - 1s 668ms/step - loss: 0.6946 - sparse_categorical_accuracy: 0.8145 - val_loss: 1.8824 - val_sparse_categorical_accuracy: 0.8510
# Epoch 29/50
# 2/2 [==============================] - 1s 674ms/step - loss: 0.7051 - sparse_categorical_accuracy: 0.7995 - val_loss: 1.8814 - val_sparse_categorical_accuracy: 0.8510
# Epoch 30/50
# 2/2 [==============================] - 1s 667ms/step - loss: 0.6678 - sparse_categorical_accuracy: 0.8135 - val_loss: 1.8808 - val_sparse_categorical_accuracy: 0.8510
# Epoch 31/50
# 2/2 [==============================] - 1s 631ms/step - loss: 0.7063 - sparse_categorical_accuracy: 0.8030 - val_loss: 1.8802 - val_sparse_categorical_accuracy: 0.8510
# Epoch 32/50
# 2/2 [==============================] - 1s 627ms/step - loss: 0.6785 - sparse_categorical_accuracy: 0.8095 - val_loss: 1.8797 - val_sparse_categorical_accuracy: 0.8510
# Epoch 33/50
# 2/2 [==============================] - 1s 651ms/step - loss: 0.6296 - sparse_categorical_accuracy: 0.8180 - val_loss: 1.8793 - val_sparse_categorical_accuracy: 0.8510
# Epoch 34/50
# 2/2 [==============================] - 1s 635ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.8025 - val_loss: 1.8796 - val_sparse_categorical_accuracy: 0.8510
# Epoch 35/50
# 2/2 [==============================] - 1s 668ms/step - loss: 0.6381 - sparse_categorical_accuracy: 0.8210 - val_loss: 1.8801 - val_sparse_categorical_accuracy: 0.8510
# Epoch 36/50
# 2/2 [==============================] - 1s 795ms/step - loss: 0.6700 - sparse_categorical_accuracy: 0.8240 - val_loss: 1.8806 - val_sparse_categorical_accuracy: 0.8510
# Epoch 37/50
# 2/2 [==============================] - 1s 662ms/step - loss: 0.7520 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.8811 - val_sparse_categorical_accuracy: 0.8510
# Epoch 38/50
# 2/2 [==============================] - 1s 646ms/step - loss: 0.7129 - sparse_categorical_accuracy: 0.8070 - val_loss: 1.8811 - val_sparse_categorical_accuracy: 0.8510
# Epoch 39/50
# 2/2 [==============================] - 1s 652ms/step - loss: 0.6411 - sparse_categorical_accuracy: 0.8205 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.8510
# Epoch 40/50
# 2/2 [==============================] - 1s 658ms/step - loss: 0.6800 - sparse_categorical_accuracy: 0.8135 - val_loss: 1.8813 - val_sparse_categorical_accuracy: 0.8510
# Epoch 41/50
# 2/2 [==============================] - 1s 670ms/step - loss: 0.6967 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8812 - val_sparse_categorical_accuracy: 0.8510
# Epoch 42/50
# 2/2 [==============================] - 1s 660ms/step - loss: 0.6862 - sparse_categorical_accuracy: 0.8085 - val_loss: 1.8813 - val_sparse_categorical_accuracy: 0.8510
# Epoch 43/50
# 2/2 [==============================] - 1s 683ms/step - loss: 0.6939 - sparse_categorical_accuracy: 0.8150 - val_loss: 1.8815 - val_sparse_categorical_accuracy: 0.8510
# Epoch 44/50
# 2/2 [==============================] - 1s 656ms/step - loss: 0.6996 - sparse_categorical_accuracy: 0.8125 - val_loss: 1.8813 - val_sparse_categorical_accuracy: 0.8510
# Epoch 45/50
# 2/2 [==============================] - 1s 664ms/step - loss: 0.7025 - sparse_categorical_accuracy: 0.8140 - val_loss: 1.8810 - val_sparse_categorical_accuracy: 0.8510
# Epoch 46/50
# 2/2 [==============================] - 1s 677ms/step - loss: 0.6824 - sparse_categorical_accuracy: 0.8065 - val_loss: 1.8809 - val_sparse_categorical_accuracy: 0.8510
# Epoch 47/50
# 2/2 [==============================] - 1s 674ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.8050 - val_loss: 1.8809 - val_sparse_categorical_accuracy: 0.8510
# Epoch 48/50
# 2/2 [==============================] - 1s 667ms/step - loss: 0.6838 - sparse_categorical_accuracy: 0.8125 - val_loss: 1.8808 - val_sparse_categorical_accuracy: 0.8510
# Epoch 49/50
# 2/2 [==============================] - 1s 662ms/step - loss: 0.6976 - sparse_categorical_accuracy: 0.8135 - val_loss: 1.8806 - val_sparse_categorical_accuracy: 0.8510
# Epoch 50/50
# 2/2 [==============================] - 1s 668ms/step - loss: 0.7317 - sparse_categorical_accuracy: 0.8070 - val_loss: 1.8805 - val_sparse_categorical_accuracy: 0.8510

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.45100  BER: 0.13000
# total: 2600
# SNR: 0.500:
#  ->BLER: 0.33200  BER: 0.09250
# total: 1850
# SNR: 1.000:
#  ->BLER: 0.25300  BER: 0.06800
# total: 1360
# SNR: 1.500:
#  ->BLER: 0.20500  BER: 0.05260
# total: 1052
# SNR: 2.000:
#  ->BLER: 0.12500  BER: 0.03255
# total: 651
# SNR: 2.500:
#  ->BLER: 0.07500  BER: 0.01955
# total: 391
# SNR: 3.000:
#  ->BLER: 0.04200  BER: 0.01075
# total: 215
# SNR: 3.500:
#  ->BLER: 0.02700  BER: 0.00680
# total: 136
# SNR: 4.000:
#  ->BLER: 0.01100  BER: 0.00270
# total: 54
# SNR: 4.500:
#  ->BLER: 0.00200  BER: 0.00060
# total: 12
# SNR: 5.000:
#  ->BLER: 0.00300  BER: 0.00060
# total: 12
# SNR: 5.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 6.000:
#  ->BLER: 0.00100  BER: 0.00025
# total: 5
# SNR: 6.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 7.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 7.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size*num_of_input_block)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (1000, 2, 1024)
# SNR: 0.000:-> BLER: 0.44900 BER: 0.12790
# total_bit_error: 2558
# total_msg_error: 449
# SNR: 0.500:-> BLER: 0.32900 BER: 0.09095
# total_bit_error: 1819
# total_msg_error: 329
# SNR: 1.000:-> BLER: 0.25400 BER: 0.06940
# total_bit_error: 1388
# total_msg_error: 254
# SNR: 1.500:-> BLER: 0.16900 BER: 0.04265
# total_bit_error: 853
# total_msg_error: 169
# SNR: 2.000:-> BLER: 0.12000 BER: 0.02975
# total_bit_error: 595
# total_msg_error: 120
# SNR: 2.500:-> BLER: 0.07200 BER: 0.01800
# total_bit_error: 360
# total_msg_error: 72
# SNR: 3.000:-> BLER: 0.04100 BER: 0.01070
# total_bit_error: 214
# total_msg_error: 41
# SNR: 3.500:-> BLER: 0.02400 BER: 0.00570
# total_bit_error: 114
# total_msg_error: 24
# SNR: 4.000:-> BLER: 0.01200 BER: 0.00340
# total_bit_error: 68
# total_msg_error: 12
# SNR: 4.500:-> BLER: 0.00500 BER: 0.00115
# total_bit_error: 23
# total_msg_error: 5
# SNR: 5.000:-> BLER: 0.00100 BER: 0.00020
# total_bit_error: 4
# total_msg_error: 1
# SNR: 5.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.000:-> BLER: 0.00200 BER: 0.00045
# total_bit_error: 9
# total_msg_error: 2
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.13    0.0925  0.068   0.0526  0.03255 0.01955 0.01075 0.0068  0.0027
#  0.0006  0.0006  0.      0.00025 0.      0.      0.      0.      0.
#  0.      0.     ]
# [0.451 0.332 0.253 0.205 0.125 0.075 0.042 0.027 0.011 0.002 0.003 0.
#  0.001 0.    0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 6.3205166

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
print (test_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size*num_of_input_block)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (1000, 2, 1024)
# SNR: 0.000:-> BLER: 0.56400 BER: 0.17105
# total_bit_error: 3421
# total_msg_error: 564
# SNR: 0.500:-> BLER: 0.48900 BER: 0.14285
# total_bit_error: 2857
# total_msg_error: 489
# SNR: 1.000:-> BLER: 0.41900 BER: 0.11765
# total_bit_error: 2353
# total_msg_error: 419
# SNR: 1.500:-> BLER: 0.35600 BER: 0.10270
# total_bit_error: 2054
# total_msg_error: 356
# SNR: 2.000:-> BLER: 0.33500 BER: 0.08935
# total_bit_error: 1787
# total_msg_error: 335
# SNR: 2.500:-> BLER: 0.30100 BER: 0.08740
# total_bit_error: 1748
# total_msg_error: 301
# SNR: 3.000:-> BLER: 0.29200 BER: 0.08205
# total_bit_error: 1641
# total_msg_error: 292
# SNR: 3.500:-> BLER: 0.28200 BER: 0.07685
# total_bit_error: 1537
# total_msg_error: 282
# SNR: 4.000:-> BLER: 0.28100 BER: 0.07490
# total_bit_error: 1498
# total_msg_error: 281
# SNR: 4.500:-> BLER: 0.28200 BER: 0.07565
# total_bit_error: 1513
# total_msg_error: 282
# SNR: 5.000:-> BLER: 0.27600 BER: 0.07485
# total_bit_error: 1497
# total_msg_error: 276
# SNR: 5.500:-> BLER: 0.27600 BER: 0.07825
# total_bit_error: 1565
# total_msg_error: 276
# SNR: 6.000:-> BLER: 0.27600 BER: 0.07775
# total_bit_error: 1555
# total_msg_error: 276
# SNR: 6.500:-> BLER: 0.27600 BER: 0.07580
# total_bit_error: 1516
# total_msg_error: 276
# SNR: 7.000:-> BLER: 0.27600 BER: 0.07495
# total_bit_error: 1499
# total_msg_error: 276
# SNR: 7.500:-> BLER: 0.27600 BER: 0.07680
# total_bit_error: 1536
# total_msg_error: 276
# SNR: 8.000:-> BLER: 0.27600 BER: 0.07690
# total_bit_error: 1538
# total_msg_error: 276
# SNR: 8.500:-> BLER: 0.27600 BER: 0.07755
# total_bit_error: 1551
# total_msg_error: 276
# SNR: 9.000:-> BLER: 0.27600 BER: 0.07605
# total_bit_error: 1521
# total_msg_error: 276
# SNR: 9.500:-> BLER: 0.27600 BER: 0.07805
# total_bit_error: 1561
# total_msg_error: 276
# [0.17105 0.14285 0.11765 0.1027  0.08935 0.0874  0.08205 0.07685 0.0749
#  0.07565 0.07485 0.07825 0.07775 0.0758  0.07495 0.0768  0.0769  0.07755
#  0.07605 0.07805]
# [0.564 0.489 0.419 0.356 0.335 0.301 0.292 0.282 0.281 0.282 0.276 0.276
#  0.276 0.276 0.276 0.276 0.276 0.276 0.276 0.276]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(10x2_20)(kernel=256)(test)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(10x2_20)(kernel=256)(train)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_8_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
