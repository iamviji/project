# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Report/BlockAE_5x2_30_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise
from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 5
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 30
channel_size = 10

train_batch_size = 500

NUM_OF_INPUT_MESSAGE = 5* 1000
NUM_OF_INPUT_MESSAGE_TEST = 1000

SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)

input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))
encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 32)]      0
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 64)           0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 30)           1950        tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 20)           620         enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_5 (TFOpLambda)   (None, 20)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_4 (TFOpLamb ()                   0           tf.math.square_5[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_5 (TFOpLambda)     ()                   0           tf.math.reduce_mean_4[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_5 (TFOpLambda)  (None, 20)           0           enc_layer2[0][0]
#                                                                  tf.math.sqrt_5[0][0]
# ==================================================================================================
# Total params: 2,570
# Trainable params: 2,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 64)                1344
# _________________________________________________________________
# tf.reshape_12 (TFOpLambda)   (None, 2, 32)             0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 32)             1056
# =================================================================
# Total params: 2,400
# Trainable params: 2,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_15 (Functional)        (None, 20)                2570
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_16 (Functional)        (None, 2, 32)             2400
# =================================================================
# Total params: 4,970
# Trainable params: 4,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
print ("Training Started")
beginTime = time.clock()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history

endTime = time.clock()
print('TotalTime: ' + str(endTime - beginTime) + ' s')
# Out:
# Training Started
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 3.5857 - sparse_categorical_accuracy: 0.0340 - val_loss: 3.4729 - val_sparse_categorical_accuracy: 0.0402
# Epoch 2/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.4678 - sparse_categorical_accuracy: 0.0477 - val_loss: 3.3765 - val_sparse_categorical_accuracy: 0.0588
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 3.3816 - sparse_categorical_accuracy: 0.0633 - val_loss: 3.2950 - val_sparse_categorical_accuracy: 0.1054
# Epoch 4/50
# 10/10 [==============================] - 0s 8ms/step - loss: 3.3012 - sparse_categorical_accuracy: 0.1056 - val_loss: 3.2214 - val_sparse_categorical_accuracy: 0.1952
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.2326 - sparse_categorical_accuracy: 0.1606 - val_loss: 3.1524 - val_sparse_categorical_accuracy: 0.3054
# Epoch 6/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.1703 - sparse_categorical_accuracy: 0.2241 - val_loss: 3.0856 - val_sparse_categorical_accuracy: 0.4186
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.1080 - sparse_categorical_accuracy: 0.2967 - val_loss: 3.0200 - val_sparse_categorical_accuracy: 0.5059
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 3.0480 - sparse_categorical_accuracy: 0.3490 - val_loss: 2.9551 - val_sparse_categorical_accuracy: 0.5901
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.9917 - sparse_categorical_accuracy: 0.3866 - val_loss: 2.8907 - val_sparse_categorical_accuracy: 0.6431
# Epoch 10/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.9377 - sparse_categorical_accuracy: 0.4199 - val_loss: 2.8268 - val_sparse_categorical_accuracy: 0.6848
# Epoch 11/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.8818 - sparse_categorical_accuracy: 0.4509 - val_loss: 2.7631 - val_sparse_categorical_accuracy: 0.7203
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.8254 - sparse_categorical_accuracy: 0.4726 - val_loss: 2.6995 - val_sparse_categorical_accuracy: 0.7512
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.7730 - sparse_categorical_accuracy: 0.4917 - val_loss: 2.6358 - val_sparse_categorical_accuracy: 0.7746
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.7256 - sparse_categorical_accuracy: 0.5015 - val_loss: 2.5720 - val_sparse_categorical_accuracy: 0.8046
# Epoch 15/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.6677 - sparse_categorical_accuracy: 0.5185 - val_loss: 2.5078 - val_sparse_categorical_accuracy: 0.8174
# Epoch 16/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.6160 - sparse_categorical_accuracy: 0.5380 - val_loss: 2.4427 - val_sparse_categorical_accuracy: 0.8374
# Epoch 17/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.5661 - sparse_categorical_accuracy: 0.5419 - val_loss: 2.3777 - val_sparse_categorical_accuracy: 0.8501
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.5146 - sparse_categorical_accuracy: 0.5494 - val_loss: 2.3125 - val_sparse_categorical_accuracy: 0.8606
# Epoch 19/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.4631 - sparse_categorical_accuracy: 0.5733 - val_loss: 2.2469 - val_sparse_categorical_accuracy: 0.8747
# Epoch 20/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.4163 - sparse_categorical_accuracy: 0.5707 - val_loss: 2.1815 - val_sparse_categorical_accuracy: 0.8897
# Epoch 21/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.3671 - sparse_categorical_accuracy: 0.5766 - val_loss: 2.1164 - val_sparse_categorical_accuracy: 0.9014
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.3153 - sparse_categorical_accuracy: 0.5939 - val_loss: 2.0517 - val_sparse_categorical_accuracy: 0.9094
# Epoch 23/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.2694 - sparse_categorical_accuracy: 0.5909 - val_loss: 1.9881 - val_sparse_categorical_accuracy: 0.9195
# Epoch 24/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.2190 - sparse_categorical_accuracy: 0.6130 - val_loss: 1.9247 - val_sparse_categorical_accuracy: 0.9243
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.1753 - sparse_categorical_accuracy: 0.6095 - val_loss: 1.8621 - val_sparse_categorical_accuracy: 0.9321
# Epoch 26/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.1282 - sparse_categorical_accuracy: 0.6234 - val_loss: 1.8005 - val_sparse_categorical_accuracy: 0.9390
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0856 - sparse_categorical_accuracy: 0.6340 - val_loss: 1.7403 - val_sparse_categorical_accuracy: 0.9464
# Epoch 28/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0347 - sparse_categorical_accuracy: 0.6434 - val_loss: 1.6807 - val_sparse_categorical_accuracy: 0.9493
# Epoch 29/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0046 - sparse_categorical_accuracy: 0.6438 - val_loss: 1.6230 - val_sparse_categorical_accuracy: 0.9575
# Epoch 30/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.9488 - sparse_categorical_accuracy: 0.6561 - val_loss: 1.5666 - val_sparse_categorical_accuracy: 0.9619
# Epoch 31/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.9152 - sparse_categorical_accuracy: 0.6510 - val_loss: 1.5113 - val_sparse_categorical_accuracy: 0.9623
# Epoch 32/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.6692 - val_loss: 1.4575 - val_sparse_categorical_accuracy: 0.9717
# Epoch 33/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.8400 - sparse_categorical_accuracy: 0.6630 - val_loss: 1.4055 - val_sparse_categorical_accuracy: 0.9781
# Epoch 34/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.7971 - sparse_categorical_accuracy: 0.6814 - val_loss: 1.3552 - val_sparse_categorical_accuracy: 0.9798
# Epoch 35/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.7658 - sparse_categorical_accuracy: 0.6845 - val_loss: 1.3058 - val_sparse_categorical_accuracy: 0.9803
# Epoch 36/50
# 10/10 [==============================] - 0s 27ms/step - loss: 1.7324 - sparse_categorical_accuracy: 0.6823 - val_loss: 1.2578 - val_sparse_categorical_accuracy: 0.9851
# Epoch 37/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.6990 - sparse_categorical_accuracy: 0.6856 - val_loss: 1.2114 - val_sparse_categorical_accuracy: 0.9897
# Epoch 38/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.6639 - sparse_categorical_accuracy: 0.6932 - val_loss: 1.1664 - val_sparse_categorical_accuracy: 0.9927
# Epoch 39/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.6339 - sparse_categorical_accuracy: 0.7044 - val_loss: 1.1238 - val_sparse_categorical_accuracy: 0.9923
# Epoch 40/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.6920 - val_loss: 1.0825 - val_sparse_categorical_accuracy: 0.9916
# Epoch 41/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5802 - sparse_categorical_accuracy: 0.7020 - val_loss: 1.0425 - val_sparse_categorical_accuracy: 0.9940
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.5389 - sparse_categorical_accuracy: 0.7099 - val_loss: 1.0033 - val_sparse_categorical_accuracy: 0.9938
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.5235 - sparse_categorical_accuracy: 0.7077 - val_loss: 0.9659 - val_sparse_categorical_accuracy: 0.9948
# Epoch 44/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.5011 - sparse_categorical_accuracy: 0.7132 - val_loss: 0.9303 - val_sparse_categorical_accuracy: 0.9957
# Epoch 45/50
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4667 - sparse_categorical_accuracy: 0.7161 - val_loss: 0.8951 - val_sparse_categorical_accuracy: 0.9964
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4432 - sparse_categorical_accuracy: 0.7200 - val_loss: 0.8609 - val_sparse_categorical_accuracy: 0.9969
# Epoch 47/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4218 - sparse_categorical_accuracy: 0.7165 - val_loss: 0.8285 - val_sparse_categorical_accuracy: 0.9972
# Epoch 48/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4036 - sparse_categorical_accuracy: 0.7190 - val_loss: 0.7970 - val_sparse_categorical_accuracy: 0.9972
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3723 - sparse_categorical_accuracy: 0.7283 - val_loss: 0.7675 - val_sparse_categorical_accuracy: 0.9972
# Epoch 50/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3522 - sparse_categorical_accuracy: 0.7322 - val_loss: 0.7377 - val_sparse_categorical_accuracy: 0.9977
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 10/10 [==============================] - 0s 13ms/step - loss: 1.3346 - sparse_categorical_accuracy: 0.7292 - val_loss: 0.7097 - val_sparse_categorical_accuracy: 0.9984
# Epoch 2/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3049 - sparse_categorical_accuracy: 0.7356 - val_loss: 0.6827 - val_sparse_categorical_accuracy: 0.9979
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2945 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.6565 - val_sparse_categorical_accuracy: 0.9977
# Epoch 4/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2814 - sparse_categorical_accuracy: 0.7301 - val_loss: 0.6311 - val_sparse_categorical_accuracy: 0.9993
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.2417 - sparse_categorical_accuracy: 0.7482 - val_loss: 0.6067 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 10ms/step - loss: 1.2405 - sparse_categorical_accuracy: 0.7373 - val_loss: 0.5842 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.2184 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.5618 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2152 - sparse_categorical_accuracy: 0.7387 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1898 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.5201 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1701 - sparse_categorical_accuracy: 0.7541 - val_loss: 0.5000 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1577 - sparse_categorical_accuracy: 0.7504 - val_loss: 0.4801 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1351 - sparse_categorical_accuracy: 0.7578 - val_loss: 0.4624 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1254 - sparse_categorical_accuracy: 0.7547 - val_loss: 0.4451 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1085 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.4283 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0957 - sparse_categorical_accuracy: 0.7612 - val_loss: 0.4115 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0822 - sparse_categorical_accuracy: 0.7626 - val_loss: 0.3962 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0833 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0831 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.3670 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0674 - sparse_categorical_accuracy: 0.7520 - val_loss: 0.3539 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0536 - sparse_categorical_accuracy: 0.7562 - val_loss: 0.3403 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0349 - sparse_categorical_accuracy: 0.7662 - val_loss: 0.3274 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0250 - sparse_categorical_accuracy: 0.7611 - val_loss: 0.3152 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0238 - sparse_categorical_accuracy: 0.7603 - val_loss: 0.3038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9970 - sparse_categorical_accuracy: 0.7740 - val_loss: 0.2921 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9970 - sparse_categorical_accuracy: 0.7702 - val_loss: 0.2813 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9897 - sparse_categorical_accuracy: 0.7645 - val_loss: 0.2720 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9643 - sparse_categorical_accuracy: 0.7772 - val_loss: 0.2628 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9769 - sparse_categorical_accuracy: 0.7624 - val_loss: 0.2537 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9739 - sparse_categorical_accuracy: 0.7603 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9644 - sparse_categorical_accuracy: 0.7722 - val_loss: 0.2358 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9328 - sparse_categorical_accuracy: 0.7798 - val_loss: 0.2272 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9387 - sparse_categorical_accuracy: 0.7693 - val_loss: 0.2186 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9293 - sparse_categorical_accuracy: 0.7703 - val_loss: 0.2114 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9148 - sparse_categorical_accuracy: 0.7770 - val_loss: 0.2039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9113 - sparse_categorical_accuracy: 0.7744 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9021 - sparse_categorical_accuracy: 0.7795 - val_loss: 0.1904 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8988 - sparse_categorical_accuracy: 0.7778 - val_loss: 0.1845 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8868 - sparse_categorical_accuracy: 0.7767 - val_loss: 0.1781 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9009 - sparse_categorical_accuracy: 0.7685 - val_loss: 0.1718 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8910 - sparse_categorical_accuracy: 0.7782 - val_loss: 0.1666 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8810 - sparse_categorical_accuracy: 0.7766 - val_loss: 0.1614 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.8894 - sparse_categorical_accuracy: 0.7704 - val_loss: 0.1560 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8618 - sparse_categorical_accuracy: 0.7851 - val_loss: 0.1507 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8500 - sparse_categorical_accuracy: 0.7824 - val_loss: 0.1455 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8522 - sparse_categorical_accuracy: 0.7849 - val_loss: 0.1409 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8483 - sparse_categorical_accuracy: 0.7841 - val_loss: 0.1370 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8386 - sparse_categorical_accuracy: 0.7853 - val_loss: 0.1323 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8421 - sparse_categorical_accuracy: 0.7772 - val_loss: 0.1282 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8249 - sparse_categorical_accuracy: 0.7876 - val_loss: 0.1241 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.8327 - sparse_categorical_accuracy: 0.7820 - val_loss: 0.1204 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.8165 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.1168 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8294 - sparse_categorical_accuracy: 0.7783 - val_loss: 0.1132 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8135 - sparse_categorical_accuracy: 0.7831 - val_loss: 0.1099 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8170 - sparse_categorical_accuracy: 0.7790 - val_loss: 0.1066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8289 - sparse_categorical_accuracy: 0.7752 - val_loss: 0.1039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7958 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.0977 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7931 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.0950 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7940 - sparse_categorical_accuracy: 0.7831 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7861 - sparse_categorical_accuracy: 0.7932 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7876 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.8017 - sparse_categorical_accuracy: 0.7813 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7805 - sparse_categorical_accuracy: 0.7896 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7804 - sparse_categorical_accuracy: 0.7849 - val_loss: 0.0807 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.7877 - val_loss: 0.0784 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7701 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7625 - sparse_categorical_accuracy: 0.7908 - val_loss: 0.0740 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7677 - sparse_categorical_accuracy: 0.7903 - val_loss: 0.0722 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7624 - sparse_categorical_accuracy: 0.7859 - val_loss: 0.0703 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7552 - sparse_categorical_accuracy: 0.7905 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7714 - sparse_categorical_accuracy: 0.7862 - val_loss: 0.0671 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7689 - sparse_categorical_accuracy: 0.7890 - val_loss: 0.0654 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7423 - sparse_categorical_accuracy: 0.7962 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7552 - sparse_categorical_accuracy: 0.7879 - val_loss: 0.0619 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7603 - sparse_categorical_accuracy: 0.7904 - val_loss: 0.0606 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7482 - sparse_categorical_accuracy: 0.7889 - val_loss: 0.0592 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.7809 - val_loss: 0.0579 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7296 - sparse_categorical_accuracy: 0.7966 - val_loss: 0.0566 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7360 - sparse_categorical_accuracy: 0.7938 - val_loss: 0.0550 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7462 - sparse_categorical_accuracy: 0.7857 - val_loss: 0.0537 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7464 - sparse_categorical_accuracy: 0.7903 - val_loss: 0.0525 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7226 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.0511 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7387 - sparse_categorical_accuracy: 0.7887 - val_loss: 0.0500 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7108 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.0490 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.7205 - sparse_categorical_accuracy: 0.7915 - val_loss: 0.0479 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7423 - sparse_categorical_accuracy: 0.7814 - val_loss: 0.0469 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7189 - sparse_categorical_accuracy: 0.7962 - val_loss: 0.0459 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.7980 - val_loss: 0.0450 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7125 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.0440 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7271 - sparse_categorical_accuracy: 0.7876 - val_loss: 0.0429 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7225 - sparse_categorical_accuracy: 0.7915 - val_loss: 0.0421 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7073 - sparse_categorical_accuracy: 0.7957 - val_loss: 0.0413 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7033 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.0404 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7154 - sparse_categorical_accuracy: 0.7908 - val_loss: 0.0395 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7262 - sparse_categorical_accuracy: 0.7875 - val_loss: 0.0387 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6982 - sparse_categorical_accuracy: 0.7958 - val_loss: 0.0380 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7036 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.0372 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6920 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7099 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.0357 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7123 - sparse_categorical_accuracy: 0.7935 - val_loss: 0.0350 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7058 - sparse_categorical_accuracy: 0.7925 - val_loss: 0.0343 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6968 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.0336 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6986 - sparse_categorical_accuracy: 0.7947 - val_loss: 0.0329 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6948 - sparse_categorical_accuracy: 0.7970 - val_loss: 0.0322 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.8061 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6806 - sparse_categorical_accuracy: 0.7975 - val_loss: 0.0312 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6743 - sparse_categorical_accuracy: 0.7986 - val_loss: 0.0307 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6974 - sparse_categorical_accuracy: 0.7939 - val_loss: 0.0300 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6873 - sparse_categorical_accuracy: 0.7962 - val_loss: 0.0294 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6894 - sparse_categorical_accuracy: 0.7922 - val_loss: 0.0289 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6763 - sparse_categorical_accuracy: 0.8014 - val_loss: 0.0283 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6920 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.0278 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6914 - sparse_categorical_accuracy: 0.7963 - val_loss: 0.0273 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6791 - sparse_categorical_accuracy: 0.8024 - val_loss: 0.0268 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6911 - sparse_categorical_accuracy: 0.7919 - val_loss: 0.0263 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6765 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.0257 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7014 - sparse_categorical_accuracy: 0.7934 - val_loss: 0.0254 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6785 - sparse_categorical_accuracy: 0.7973 - val_loss: 0.0250 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6823 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6692 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.0242 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6802 - sparse_categorical_accuracy: 0.7963 - val_loss: 0.0238 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6849 - sparse_categorical_accuracy: 0.7942 - val_loss: 0.0234 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6636 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6972 - sparse_categorical_accuracy: 0.7850 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6670 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6768 - sparse_categorical_accuracy: 0.7960 - val_loss: 0.0215 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6729 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.0211 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.8033 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6671 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6614 - sparse_categorical_accuracy: 0.7978 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6738 - sparse_categorical_accuracy: 0.7970 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6599 - sparse_categorical_accuracy: 0.8012 - val_loss: 0.0196 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6638 - sparse_categorical_accuracy: 0.7967 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6489 - sparse_categorical_accuracy: 0.8067 - val_loss: 0.0190 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6616 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6608 - sparse_categorical_accuracy: 0.8014 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6551 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.0182 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6424 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.7986 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6535 - sparse_categorical_accuracy: 0.8030 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6753 - sparse_categorical_accuracy: 0.7934 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6626 - sparse_categorical_accuracy: 0.7982 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6703 - sparse_categorical_accuracy: 0.7969 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6460 - sparse_categorical_accuracy: 0.8049 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6563 - sparse_categorical_accuracy: 0.7985 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6615 - sparse_categorical_accuracy: 0.8019 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6378 - sparse_categorical_accuracy: 0.8059 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6671 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6524 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6536 - sparse_categorical_accuracy: 0.8006 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6448 - sparse_categorical_accuracy: 0.8067 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6346 - sparse_categorical_accuracy: 0.8068 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6511 - sparse_categorical_accuracy: 0.8012 - val_loss: 0.0145 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6438 - sparse_categorical_accuracy: 0.8026 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6290 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6449 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6473 - sparse_categorical_accuracy: 0.8011 - val_loss: 0.0136 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6503 - sparse_categorical_accuracy: 0.7990 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6418 - sparse_categorical_accuracy: 0.7991 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6552 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6314 - sparse_categorical_accuracy: 0.8099 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6410 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6444 - sparse_categorical_accuracy: 0.8029 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6416 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6517 - sparse_categorical_accuracy: 0.7991 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6374 - sparse_categorical_accuracy: 0.8087 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6443 - sparse_categorical_accuracy: 0.7985 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6311 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6282 - sparse_categorical_accuracy: 0.8070 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6293 - sparse_categorical_accuracy: 0.8093 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6392 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6357 - sparse_categorical_accuracy: 0.8080 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6205 - sparse_categorical_accuracy: 0.8117 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6388 - sparse_categorical_accuracy: 0.8067 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6078 - sparse_categorical_accuracy: 0.8173 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6365 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6395 - sparse_categorical_accuracy: 0.8046 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6155 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.0104 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6334 - sparse_categorical_accuracy: 0.8054 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6106 - sparse_categorical_accuracy: 0.8086 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6231 - sparse_categorical_accuracy: 0.8093 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6104 - sparse_categorical_accuracy: 0.8177 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6269 - sparse_categorical_accuracy: 0.8129 - val_loss: 0.0098 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6209 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.0097 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.8070 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6116 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6253 - sparse_categorical_accuracy: 0.8066 - val_loss: 0.0093 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6441 - sparse_categorical_accuracy: 0.8016 - val_loss: 0.0093 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6054 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6211 - sparse_categorical_accuracy: 0.8083 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6319 - sparse_categorical_accuracy: 0.8026 - val_loss: 0.0090 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6260 - sparse_categorical_accuracy: 0.8070 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6220 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.0088 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6081 - sparse_categorical_accuracy: 0.8109 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6114 - sparse_categorical_accuracy: 0.8139 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6347 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.0086 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6297 - sparse_categorical_accuracy: 0.8068 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6186 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.0084 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6270 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.0083 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.8081 - val_loss: 0.0082 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6303 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.0081 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6221 - sparse_categorical_accuracy: 0.8049 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6362 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6241 - sparse_categorical_accuracy: 0.8058 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6066 - sparse_categorical_accuracy: 0.8134 - val_loss: 0.0078 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6171 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.0078 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6080 - sparse_categorical_accuracy: 0.8066 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6173 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.8081 - val_loss: 0.0075 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6220 - sparse_categorical_accuracy: 0.8112 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6128 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6142 - sparse_categorical_accuracy: 0.8069 - val_loss: 0.0073 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6034 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.0073 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6139 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# ...
# Epoch 13/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5461 - sparse_categorical_accuracy: 0.8261 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5310 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5575 - sparse_categorical_accuracy: 0.8272 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5553 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5562 - sparse_categorical_accuracy: 0.8251 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5227 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5528 - sparse_categorical_accuracy: 0.8216 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5424 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5304 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5517 - sparse_categorical_accuracy: 0.8277 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5506 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5398 - sparse_categorical_accuracy: 0.8302 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5541 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5510 - sparse_categorical_accuracy: 0.8264 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5499 - sparse_categorical_accuracy: 0.8249 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5605 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5454 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.8269 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.8302 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5576 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5382 - sparse_categorical_accuracy: 0.8337 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5587 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5363 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5498 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5582 - sparse_categorical_accuracy: 0.8269 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5287 - sparse_categorical_accuracy: 0.8348 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5554 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5564 - sparse_categorical_accuracy: 0.8253 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5645 - sparse_categorical_accuracy: 0.8224 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5446 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5408 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5448 - sparse_categorical_accuracy: 0.8343 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5430 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5432 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5486 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5421 - sparse_categorical_accuracy: 0.8299 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5638 - sparse_categorical_accuracy: 0.8214 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.5430 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5435 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5568 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5511 - sparse_categorical_accuracy: 0.8261 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5408 - sparse_categorical_accuracy: 0.8276 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5519 - sparse_categorical_accuracy: 0.8264 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5482 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5481 - sparse_categorical_accuracy: 0.8287 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5370 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5517 - sparse_categorical_accuracy: 0.8238 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5493 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5700 - sparse_categorical_accuracy: 0.8211 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5371 - sparse_categorical_accuracy: 0.8317 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.8329 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5504 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5291 - sparse_categorical_accuracy: 0.8354 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5566 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5403 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5837 - sparse_categorical_accuracy: 0.8186 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5497 - sparse_categorical_accuracy: 0.8287 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5336 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5342 - sparse_categorical_accuracy: 0.8299 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5424 - sparse_categorical_accuracy: 0.8319 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5386 - sparse_categorical_accuracy: 0.8287 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5546 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5453 - sparse_categorical_accuracy: 0.8316 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5423 - sparse_categorical_accuracy: 0.8334 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5361 - sparse_categorical_accuracy: 0.8297 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8262 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.5578 - sparse_categorical_accuracy: 0.8239 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5418 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5483 - sparse_categorical_accuracy: 0.8246 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5349 - sparse_categorical_accuracy: 0.8311 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5562 - sparse_categorical_accuracy: 0.8232 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5508 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5540 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5515 - sparse_categorical_accuracy: 0.8246 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5472 - sparse_categorical_accuracy: 0.8304 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5407 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5554 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5360 - sparse_categorical_accuracy: 0.8339 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5458 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# TotalTime: 115.98433300000002 s

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.37500  BER: 0.11246
# total: 5623
# SNR: 0.500:
#  ->BLER: 0.31260  BER: 0.09060
# total: 4530
# SNR: 1.000:
#  ->BLER: 0.23540  BER: 0.06676
# total: 3338
# SNR: 1.500:
#  ->BLER: 0.18620  BER: 0.05160
# total: 2580
# SNR: 2.000:
#  ->BLER: 0.13820  BER: 0.03846
# total: 1923
# SNR: 2.500:
#  ->BLER: 0.09580  BER: 0.02616
# total: 1308
# SNR: 3.000:
#  ->BLER: 0.06580  BER: 0.01742
# total: 871
# SNR: 3.500:
#  ->BLER: 0.03900  BER: 0.01074
# total: 537
# SNR: 4.000:
#  ->BLER: 0.02180  BER: 0.00578
# total: 289
# SNR: 4.500:
#  ->BLER: 0.01420  BER: 0.00408
# total: 204
# SNR: 5.000:
#  ->BLER: 0.00780  BER: 0.00208
# total: 104
# SNR: 5.500:
#  ->BLER: 0.00380  BER: 0.00092
# total: 46
# SNR: 6.000:
#  ->BLER: 0.00100  BER: 0.00030
# total: 15
# SNR: 6.500:
#  ->BLER: 0.00080  BER: 0.00028
# total: 14
# SNR: 7.000:
#  ->BLER: 0.00040  BER: 0.00004
# total: 2
# SNR: 7.500:
#  ->BLER: 0.00040  BER: 0.00010
# total: 5
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (5000, 2, 32)
# SNR: 0.000:-> BLER: 0.36060 BER: 0.10622
# total_bit_error: 5311
# total_msg_error: 1803
# SNR: 0.500:-> BLER: 0.31660 BER: 0.09004
# total_bit_error: 4502
# total_msg_error: 1583
# SNR: 1.000:-> BLER: 0.24720 BER: 0.06884
# total_bit_error: 3442
# total_msg_error: 1236
# SNR: 1.500:-> BLER: 0.18100 BER: 0.05114
# total_bit_error: 2557
# total_msg_error: 905
# SNR: 2.000:-> BLER: 0.14760 BER: 0.04070
# total_bit_error: 2035
# total_msg_error: 738
# SNR: 2.500:-> BLER: 0.09040 BER: 0.02494
# total_bit_error: 1247
# total_msg_error: 452
# SNR: 3.000:-> BLER: 0.06200 BER: 0.01660
# total_bit_error: 830
# total_msg_error: 310
# SNR: 3.500:-> BLER: 0.04320 BER: 0.01160
# total_bit_error: 580
# total_msg_error: 216
# SNR: 4.000:-> BLER: 0.02520 BER: 0.00650
# total_bit_error: 325
# total_msg_error: 126
# SNR: 4.500:-> BLER: 0.01100 BER: 0.00302
# total_bit_error: 151
# total_msg_error: 55
# SNR: 5.000:-> BLER: 0.00660 BER: 0.00176
# total_bit_error: 88
# total_msg_error: 33
# SNR: 5.500:-> BLER: 0.00380 BER: 0.00112
# total_bit_error: 56
# total_msg_error: 19
# SNR: 6.000:-> BLER: 0.00080 BER: 0.00016
# total_bit_error: 8
# total_msg_error: 4
# SNR: 6.500:-> BLER: 0.00040 BER: 0.00008
# total_bit_error: 4
# total_msg_error: 2
# SNR: 7.000:-> BLER: 0.00040 BER: 0.00006
# total_bit_error: 3
# total_msg_error: 2
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [1.1246e-01 9.0600e-02 6.6760e-02 5.1600e-02 3.8460e-02 2.6160e-02
#  1.7420e-02 1.0740e-02 5.7800e-03 4.0800e-03 2.0800e-03 9.2000e-04
#  3.0000e-04 2.8000e-04 4.0000e-05 1.0000e-04 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00]
# [0.375  0.3126 0.2354 0.1862 0.1382 0.0958 0.0658 0.039  0.0218 0.0142
#  0.0078 0.0038 0.001  0.0008 0.0004 0.0004 0.     0.     0.     0.    ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)(train)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(validation)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_ylabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)(train)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(validation)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_ylabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
test_input_message = numpy.random.randint(2**input_block_length, size=(int(NUM_OF_INPUT_MESSAGE_TEST),num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (5000, 2, 32)
# SNR: 0.000:-> BLER: 0.38200 BER: 0.11440
# total_bit_error: 1144
# total_msg_error: 382
# SNR: 0.500:-> BLER: 0.31900 BER: 0.09550
# total_bit_error: 955
# total_msg_error: 319
# SNR: 1.000:-> BLER: 0.25900 BER: 0.07350
# total_bit_error: 735
# total_msg_error: 259
# SNR: 1.500:-> BLER: 0.18200 BER: 0.05200
# total_bit_error: 520
# total_msg_error: 182
# SNR: 2.000:-> BLER: 0.15800 BER: 0.04370
# total_bit_error: 437
# total_msg_error: 158
# SNR: 2.500:-> BLER: 0.08800 BER: 0.02420
# total_bit_error: 242
# total_msg_error: 88
# SNR: 3.000:-> BLER: 0.05500 BER: 0.01460
# total_bit_error: 146
# total_msg_error: 55
# SNR: 3.500:-> BLER: 0.03400 BER: 0.00790
# total_bit_error: 79
# total_msg_error: 34
# SNR: 4.000:-> BLER: 0.02300 BER: 0.00660
# total_bit_error: 66
# total_msg_error: 23
# SNR: 4.500:-> BLER: 0.01100 BER: 0.00270
# total_bit_error: 27
# total_msg_error: 11
# SNR: 5.000:-> BLER: 0.00500 BER: 0.00120
# total_bit_error: 12
# total_msg_error: 5
# SNR: 5.500:-> BLER: 0.00300 BER: 0.00100
# total_bit_error: 10
# total_msg_error: 3
# SNR: 6.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.1144 0.0955 0.0735 0.052  0.0437 0.0242 0.0146 0.0079 0.0066 0.0027
#  0.0012 0.001  0.     0.     0.     0.     0.     0.     0.     0.    ]
# [0.382 0.319 0.259 0.182 0.158 0.088 0.055 0.034 0.023 0.011 0.005 0.003
#  0.    0.    0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(test)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(train)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_ylabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(test)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(train)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_ylabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel ("Iteration")
plt.ylabel ("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 4.4714594

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)
train_batch_size = 500
input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
#enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))

x = tf.sqrt(tf.reduce_sum(tf.square(enc_layer2), axis=1))
x = tf.reshape (x, (-1,1))
enc_layer3 = enc_layer2 / x


encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 32)]      0
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 64)           0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 30)           1950        tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 20)           620         enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_1 (TFOpLambda)   (None, 20)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None,)              0           tf.math.square_1[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_1 (TFOpLambda)     (None,)              0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 1)            0           tf.math.sqrt_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 20)           0           enc_layer2[0][0]
#                                                                  tf.reshape_3[0][0]
# ==================================================================================================
# Total params: 2,570
# Trainable params: 2,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 64)                1344
# _________________________________________________________________
# tf.reshape_4 (TFOpLambda)    (None, 2, 32)             0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 32)             1056
# =================================================================
# Total params: 2,400
# Trainable params: 2,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_3 (Functional)         (None, 20)                2570
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_4 (Functional)         (None, 2, 32)             2400
# =================================================================
# Total params: 4,970
# Trainable params: 4,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history2 = dict ()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history2 [snr] = history
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 4/4 [==============================] - 1s 70ms/step - loss: 3.6123 - sparse_categorical_accuracy: 0.0386 - val_loss: 3.6016 - val_sparse_categorical_accuracy: 0.0327
# Epoch 2/50
# 4/4 [==============================] - 0s 80ms/step - loss: 3.5796 - sparse_categorical_accuracy: 0.0346 - val_loss: 3.5723 - val_sparse_categorical_accuracy: 0.0367
# Epoch 3/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5522 - sparse_categorical_accuracy: 0.0402 - val_loss: 3.5467 - val_sparse_categorical_accuracy: 0.0408
# Epoch 4/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.5299 - sparse_categorical_accuracy: 0.0390 - val_loss: 3.5246 - val_sparse_categorical_accuracy: 0.0435
# Epoch 5/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.5113 - sparse_categorical_accuracy: 0.0380 - val_loss: 3.5054 - val_sparse_categorical_accuracy: 0.0530
# Epoch 6/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4934 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4888 - val_sparse_categorical_accuracy: 0.0635
# Epoch 7/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4828 - sparse_categorical_accuracy: 0.0434 - val_loss: 3.4743 - val_sparse_categorical_accuracy: 0.0845
# Epoch 8/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.4631 - sparse_categorical_accuracy: 0.0492 - val_loss: 3.4616 - val_sparse_categorical_accuracy: 0.1070
# Epoch 9/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.4560 - sparse_categorical_accuracy: 0.0514 - val_loss: 3.4503 - val_sparse_categorical_accuracy: 0.1335
# Epoch 10/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4464 - sparse_categorical_accuracy: 0.0534 - val_loss: 3.4403 - val_sparse_categorical_accuracy: 0.1482
# Epoch 11/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4402 - sparse_categorical_accuracy: 0.0546 - val_loss: 3.4312 - val_sparse_categorical_accuracy: 0.1375
# Epoch 12/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4326 - sparse_categorical_accuracy: 0.0545 - val_loss: 3.4229 - val_sparse_categorical_accuracy: 0.1273
# Epoch 13/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4293 - sparse_categorical_accuracy: 0.0620 - val_loss: 3.4154 - val_sparse_categorical_accuracy: 0.1195
# Epoch 14/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.4238 - sparse_categorical_accuracy: 0.0634 - val_loss: 3.4084 - val_sparse_categorical_accuracy: 0.1147
# Epoch 15/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.4170 - sparse_categorical_accuracy: 0.0619 - val_loss: 3.4020 - val_sparse_categorical_accuracy: 0.1243
# Epoch 16/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.4051 - sparse_categorical_accuracy: 0.0683 - val_loss: 3.3960 - val_sparse_categorical_accuracy: 0.1297
# Epoch 17/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.4036 - sparse_categorical_accuracy: 0.0805 - val_loss: 3.3903 - val_sparse_categorical_accuracy: 0.1347
# Epoch 18/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.3991 - sparse_categorical_accuracy: 0.0730 - val_loss: 3.3849 - val_sparse_categorical_accuracy: 0.1437
# Epoch 19/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.3934 - sparse_categorical_accuracy: 0.0750 - val_loss: 3.3797 - val_sparse_categorical_accuracy: 0.1535
# Epoch 20/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.3885 - sparse_categorical_accuracy: 0.0833 - val_loss: 3.3748 - val_sparse_categorical_accuracy: 0.1628
# Epoch 21/50
# 4/4 [==============================] - 0s 28ms/step - loss: 3.3876 - sparse_categorical_accuracy: 0.0696 - val_loss: 3.3700 - val_sparse_categorical_accuracy: 0.1740
# Epoch 22/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.3790 - sparse_categorical_accuracy: 0.0802 - val_loss: 3.3654 - val_sparse_categorical_accuracy: 0.1835
# Epoch 23/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.3769 - sparse_categorical_accuracy: 0.0808 - val_loss: 3.3608 - val_sparse_categorical_accuracy: 0.1918
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3763 - sparse_categorical_accuracy: 0.0920 - val_loss: 3.3564 - val_sparse_categorical_accuracy: 0.2017
# Epoch 25/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3701 - sparse_categorical_accuracy: 0.0873 - val_loss: 3.3521 - val_sparse_categorical_accuracy: 0.2125
# Epoch 26/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.3740 - sparse_categorical_accuracy: 0.0853 - val_loss: 3.3479 - val_sparse_categorical_accuracy: 0.2175
# Epoch 27/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3666 - sparse_categorical_accuracy: 0.0838 - val_loss: 3.3437 - val_sparse_categorical_accuracy: 0.2278
# Epoch 28/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3586 - sparse_categorical_accuracy: 0.0866 - val_loss: 3.3396 - val_sparse_categorical_accuracy: 0.2385
# Epoch 29/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.3622 - sparse_categorical_accuracy: 0.0849 - val_loss: 3.3355 - val_sparse_categorical_accuracy: 0.2510
# Epoch 30/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3619 - sparse_categorical_accuracy: 0.0865 - val_loss: 3.3315 - val_sparse_categorical_accuracy: 0.2615
# Epoch 31/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3534 - sparse_categorical_accuracy: 0.1014 - val_loss: 3.3276 - val_sparse_categorical_accuracy: 0.2730
# Epoch 32/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3525 - sparse_categorical_accuracy: 0.0872 - val_loss: 3.3237 - val_sparse_categorical_accuracy: 0.2817
# Epoch 33/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3530 - sparse_categorical_accuracy: 0.0904 - val_loss: 3.3199 - val_sparse_categorical_accuracy: 0.2970
# Epoch 34/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3479 - sparse_categorical_accuracy: 0.0835 - val_loss: 3.3162 - val_sparse_categorical_accuracy: 0.3035
# Epoch 35/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3449 - sparse_categorical_accuracy: 0.1021 - val_loss: 3.3124 - val_sparse_categorical_accuracy: 0.3117
# Epoch 36/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3351 - sparse_categorical_accuracy: 0.1058 - val_loss: 3.3086 - val_sparse_categorical_accuracy: 0.3183
# Epoch 37/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3426 - sparse_categorical_accuracy: 0.0901 - val_loss: 3.3049 - val_sparse_categorical_accuracy: 0.3237
# Epoch 38/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3373 - sparse_categorical_accuracy: 0.0974 - val_loss: 3.3012 - val_sparse_categorical_accuracy: 0.3275
# Epoch 39/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3300 - sparse_categorical_accuracy: 0.0995 - val_loss: 3.2975 - val_sparse_categorical_accuracy: 0.3318
# Epoch 40/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3359 - sparse_categorical_accuracy: 0.0918 - val_loss: 3.2939 - val_sparse_categorical_accuracy: 0.3390
# Epoch 41/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3365 - sparse_categorical_accuracy: 0.0963 - val_loss: 3.2902 - val_sparse_categorical_accuracy: 0.3455
# Epoch 42/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3300 - sparse_categorical_accuracy: 0.0967 - val_loss: 3.2866 - val_sparse_categorical_accuracy: 0.3475
# Epoch 43/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3284 - sparse_categorical_accuracy: 0.0924 - val_loss: 3.2829 - val_sparse_categorical_accuracy: 0.3543
# Epoch 44/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.3237 - sparse_categorical_accuracy: 0.0976 - val_loss: 3.2793 - val_sparse_categorical_accuracy: 0.3607
# Epoch 45/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3220 - sparse_categorical_accuracy: 0.0961 - val_loss: 3.2756 - val_sparse_categorical_accuracy: 0.3645
# Epoch 46/50
# 4/4 [==============================] - 0s 57ms/step - loss: 3.3193 - sparse_categorical_accuracy: 0.1019 - val_loss: 3.2720 - val_sparse_categorical_accuracy: 0.3665
# Epoch 47/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3158 - sparse_categorical_accuracy: 0.1062 - val_loss: 3.2683 - val_sparse_categorical_accuracy: 0.3713
# Epoch 48/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3167 - sparse_categorical_accuracy: 0.0910 - val_loss: 3.2646 - val_sparse_categorical_accuracy: 0.3715
# Epoch 49/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.3131 - sparse_categorical_accuracy: 0.1039 - val_loss: 3.2609 - val_sparse_categorical_accuracy: 0.3755
# Epoch 50/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.3062 - sparse_categorical_accuracy: 0.0968 - val_loss: 3.2572 - val_sparse_categorical_accuracy: 0.3785
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 4/4 [==============================] - 0s 31ms/step - loss: 3.3110 - sparse_categorical_accuracy: 0.0997 - val_loss: 3.2535 - val_sparse_categorical_accuracy: 0.3808
# Epoch 2/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3144 - sparse_categorical_accuracy: 0.0978 - val_loss: 3.2498 - val_sparse_categorical_accuracy: 0.3835
# Epoch 3/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3014 - sparse_categorical_accuracy: 0.1042 - val_loss: 3.2461 - val_sparse_categorical_accuracy: 0.3865
# Epoch 4/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.3074 - sparse_categorical_accuracy: 0.0962 - val_loss: 3.2424 - val_sparse_categorical_accuracy: 0.3893
# Epoch 5/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2940 - sparse_categorical_accuracy: 0.1037 - val_loss: 3.2387 - val_sparse_categorical_accuracy: 0.3905
# Epoch 6/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2960 - sparse_categorical_accuracy: 0.0988 - val_loss: 3.2349 - val_sparse_categorical_accuracy: 0.3920
# Epoch 7/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2970 - sparse_categorical_accuracy: 0.1000 - val_loss: 3.2311 - val_sparse_categorical_accuracy: 0.3927
# Epoch 8/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3000 - sparse_categorical_accuracy: 0.0935 - val_loss: 3.2274 - val_sparse_categorical_accuracy: 0.3943
# Epoch 9/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2962 - sparse_categorical_accuracy: 0.1037 - val_loss: 3.2236 - val_sparse_categorical_accuracy: 0.3972
# Epoch 10/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2851 - sparse_categorical_accuracy: 0.0980 - val_loss: 3.2199 - val_sparse_categorical_accuracy: 0.3997
# Epoch 11/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2953 - sparse_categorical_accuracy: 0.1005 - val_loss: 3.2161 - val_sparse_categorical_accuracy: 0.4020
# Epoch 12/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2968 - sparse_categorical_accuracy: 0.0978 - val_loss: 3.2123 - val_sparse_categorical_accuracy: 0.4038
# Epoch 13/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2780 - sparse_categorical_accuracy: 0.1058 - val_loss: 3.2086 - val_sparse_categorical_accuracy: 0.4085
# Epoch 14/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2830 - sparse_categorical_accuracy: 0.1007 - val_loss: 3.2048 - val_sparse_categorical_accuracy: 0.4125
# Epoch 15/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2863 - sparse_categorical_accuracy: 0.0990 - val_loss: 3.2010 - val_sparse_categorical_accuracy: 0.4117
# Epoch 16/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2887 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1973 - val_sparse_categorical_accuracy: 0.4135
# Epoch 17/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2821 - sparse_categorical_accuracy: 0.0948 - val_loss: 3.1937 - val_sparse_categorical_accuracy: 0.4135
# Epoch 18/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2833 - sparse_categorical_accuracy: 0.1005 - val_loss: 3.1900 - val_sparse_categorical_accuracy: 0.4160
# Epoch 19/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2800 - sparse_categorical_accuracy: 0.0927 - val_loss: 3.1863 - val_sparse_categorical_accuracy: 0.4180
# Epoch 20/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2741 - sparse_categorical_accuracy: 0.0980 - val_loss: 3.1826 - val_sparse_categorical_accuracy: 0.4227
# Epoch 21/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2762 - sparse_categorical_accuracy: 0.0967 - val_loss: 3.1789 - val_sparse_categorical_accuracy: 0.4248
# Epoch 22/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2728 - sparse_categorical_accuracy: 0.1007 - val_loss: 3.1752 - val_sparse_categorical_accuracy: 0.4252
# Epoch 23/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2659 - sparse_categorical_accuracy: 0.1053 - val_loss: 3.1714 - val_sparse_categorical_accuracy: 0.4265
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2716 - sparse_categorical_accuracy: 0.0943 - val_loss: 3.1676 - val_sparse_categorical_accuracy: 0.4288
# Epoch 25/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2638 - sparse_categorical_accuracy: 0.0993 - val_loss: 3.1638 - val_sparse_categorical_accuracy: 0.4313
# Epoch 26/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2592 - sparse_categorical_accuracy: 0.1037 - val_loss: 3.1600 - val_sparse_categorical_accuracy: 0.4333
# Epoch 27/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2704 - sparse_categorical_accuracy: 0.0978 - val_loss: 3.1563 - val_sparse_categorical_accuracy: 0.4370
# Epoch 28/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2583 - sparse_categorical_accuracy: 0.1032 - val_loss: 3.1525 - val_sparse_categorical_accuracy: 0.4425
# Epoch 29/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2649 - sparse_categorical_accuracy: 0.0990 - val_loss: 3.1488 - val_sparse_categorical_accuracy: 0.4442
# Epoch 30/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2595 - sparse_categorical_accuracy: 0.0953 - val_loss: 3.1451 - val_sparse_categorical_accuracy: 0.4442
# Epoch 31/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2547 - sparse_categorical_accuracy: 0.1015 - val_loss: 3.1415 - val_sparse_categorical_accuracy: 0.4480
# Epoch 32/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2563 - sparse_categorical_accuracy: 0.1015 - val_loss: 3.1378 - val_sparse_categorical_accuracy: 0.4480
# Epoch 33/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2579 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1342 - val_sparse_categorical_accuracy: 0.4457
# Epoch 34/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2455 - sparse_categorical_accuracy: 0.1007 - val_loss: 3.1305 - val_sparse_categorical_accuracy: 0.4460
# Epoch 35/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2589 - sparse_categorical_accuracy: 0.0953 - val_loss: 3.1268 - val_sparse_categorical_accuracy: 0.4475
# Epoch 36/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2460 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.1232 - val_sparse_categorical_accuracy: 0.4500
# Epoch 37/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2391 - sparse_categorical_accuracy: 0.1053 - val_loss: 3.1194 - val_sparse_categorical_accuracy: 0.4527
# Epoch 38/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2618 - sparse_categorical_accuracy: 0.0993 - val_loss: 3.1157 - val_sparse_categorical_accuracy: 0.4580
# Epoch 39/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2449 - sparse_categorical_accuracy: 0.1110 - val_loss: 3.1121 - val_sparse_categorical_accuracy: 0.4580
# Epoch 40/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2446 - sparse_categorical_accuracy: 0.1002 - val_loss: 3.1085 - val_sparse_categorical_accuracy: 0.4605
# Epoch 41/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2452 - sparse_categorical_accuracy: 0.1020 - val_loss: 3.1048 - val_sparse_categorical_accuracy: 0.4647
# Epoch 42/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2459 - sparse_categorical_accuracy: 0.1020 - val_loss: 3.1013 - val_sparse_categorical_accuracy: 0.4622
# Epoch 43/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2468 - sparse_categorical_accuracy: 0.0985 - val_loss: 3.0979 - val_sparse_categorical_accuracy: 0.4630
# Epoch 44/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2420 - sparse_categorical_accuracy: 0.1055 - val_loss: 3.0945 - val_sparse_categorical_accuracy: 0.4602
# Epoch 45/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2459 - sparse_categorical_accuracy: 0.1010 - val_loss: 3.0911 - val_sparse_categorical_accuracy: 0.4618
# Epoch 46/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.2276 - sparse_categorical_accuracy: 0.0970 - val_loss: 3.0878 - val_sparse_categorical_accuracy: 0.4633
# Epoch 47/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2343 - sparse_categorical_accuracy: 0.1007 - val_loss: 3.0842 - val_sparse_categorical_accuracy: 0.4663
# Epoch 48/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2522 - sparse_categorical_accuracy: 0.0962 - val_loss: 3.0809 - val_sparse_categorical_accuracy: 0.4650
# Epoch 49/50
# 4/4 [==============================] - 0s 57ms/step - loss: 3.2273 - sparse_categorical_accuracy: 0.0993 - val_loss: 3.0776 - val_sparse_categorical_accuracy: 0.4633
# Epoch 50/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2391 - sparse_categorical_accuracy: 0.1053 - val_loss: 3.0744 - val_sparse_categorical_accuracy: 0.4610
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 4/4 [==============================] - 0s 30ms/step - loss: 3.2320 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.0712 - val_sparse_categorical_accuracy: 0.4618
# Epoch 2/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2248 - sparse_categorical_accuracy: 0.1013 - val_loss: 3.0680 - val_sparse_categorical_accuracy: 0.4640
# Epoch 3/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2366 - sparse_categorical_accuracy: 0.1007 - val_loss: 3.0647 - val_sparse_categorical_accuracy: 0.4690
# Epoch 4/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2343 - sparse_categorical_accuracy: 0.0945 - val_loss: 3.0616 - val_sparse_categorical_accuracy: 0.4697
# Epoch 5/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2262 - sparse_categorical_accuracy: 0.1010 - val_loss: 3.0584 - val_sparse_categorical_accuracy: 0.4723
# Epoch 6/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2319 - sparse_categorical_accuracy: 0.1010 - val_loss: 3.0553 - val_sparse_categorical_accuracy: 0.4708
# Epoch 7/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2288 - sparse_categorical_accuracy: 0.0993 - val_loss: 3.0524 - val_sparse_categorical_accuracy: 0.4705
# Epoch 8/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2385 - sparse_categorical_accuracy: 0.0995 - val_loss: 3.0495 - val_sparse_categorical_accuracy: 0.4660
# Epoch 9/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2179 - sparse_categorical_accuracy: 0.1045 - val_loss: 3.0465 - val_sparse_categorical_accuracy: 0.4665
# Epoch 10/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2233 - sparse_categorical_accuracy: 0.0978 - val_loss: 3.0435 - val_sparse_categorical_accuracy: 0.4652
# Epoch 11/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2212 - sparse_categorical_accuracy: 0.0957 - val_loss: 3.0405 - val_sparse_categorical_accuracy: 0.4680
# Epoch 12/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2249 - sparse_categorical_accuracy: 0.1013 - val_loss: 3.0374 - val_sparse_categorical_accuracy: 0.4697
# Epoch 13/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2293 - sparse_categorical_accuracy: 0.1042 - val_loss: 3.0346 - val_sparse_categorical_accuracy: 0.4753
# Epoch 14/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2264 - sparse_categorical_accuracy: 0.1060 - val_loss: 3.0318 - val_sparse_categorical_accuracy: 0.4745
# Epoch 15/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2174 - sparse_categorical_accuracy: 0.0945 - val_loss: 3.0290 - val_sparse_categorical_accuracy: 0.4695
# Epoch 16/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2294 - sparse_categorical_accuracy: 0.0967 - val_loss: 3.0263 - val_sparse_categorical_accuracy: 0.4692
# Epoch 17/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2297 - sparse_categorical_accuracy: 0.1013 - val_loss: 3.0236 - val_sparse_categorical_accuracy: 0.4733
# Epoch 18/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2212 - sparse_categorical_accuracy: 0.0960 - val_loss: 3.0210 - val_sparse_categorical_accuracy: 0.4767
# Epoch 19/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2264 - sparse_categorical_accuracy: 0.1015 - val_loss: 3.0185 - val_sparse_categorical_accuracy: 0.4765
# Epoch 20/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2251 - sparse_categorical_accuracy: 0.1015 - val_loss: 3.0160 - val_sparse_categorical_accuracy: 0.4753
# Epoch 21/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2129 - sparse_categorical_accuracy: 0.0993 - val_loss: 3.0135 - val_sparse_categorical_accuracy: 0.4780
# Epoch 22/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2255 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.0109 - val_sparse_categorical_accuracy: 0.4798
# Epoch 23/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2258 - sparse_categorical_accuracy: 0.0972 - val_loss: 3.0085 - val_sparse_categorical_accuracy: 0.4787
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2325 - sparse_categorical_accuracy: 0.0995 - val_loss: 3.0063 - val_sparse_categorical_accuracy: 0.4807
# Epoch 25/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2205 - sparse_categorical_accuracy: 0.0995 - val_loss: 3.0041 - val_sparse_categorical_accuracy: 0.4785
# Epoch 26/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2297 - sparse_categorical_accuracy: 0.0967 - val_loss: 3.0019 - val_sparse_categorical_accuracy: 0.4800
# Epoch 27/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2154 - sparse_categorical_accuracy: 0.0978 - val_loss: 2.9998 - val_sparse_categorical_accuracy: 0.4840
# Epoch 28/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2235 - sparse_categorical_accuracy: 0.0882 - val_loss: 2.9977 - val_sparse_categorical_accuracy: 0.4827
# Epoch 29/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2283 - sparse_categorical_accuracy: 0.1032 - val_loss: 2.9957 - val_sparse_categorical_accuracy: 0.4807
# Epoch 30/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2149 - sparse_categorical_accuracy: 0.1020 - val_loss: 2.9936 - val_sparse_categorical_accuracy: 0.4823
# Epoch 31/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2121 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.9913 - val_sparse_categorical_accuracy: 0.4888
# Epoch 32/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2182 - sparse_categorical_accuracy: 0.1040 - val_loss: 2.9892 - val_sparse_categorical_accuracy: 0.4888
# Epoch 33/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2014 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.9871 - val_sparse_categorical_accuracy: 0.4908
# Epoch 34/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2242 - sparse_categorical_accuracy: 0.0932 - val_loss: 2.9851 - val_sparse_categorical_accuracy: 0.4958
# Epoch 35/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2120 - sparse_categorical_accuracy: 0.1077 - val_loss: 2.9833 - val_sparse_categorical_accuracy: 0.4905
# Epoch 36/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2172 - sparse_categorical_accuracy: 0.0980 - val_loss: 2.9814 - val_sparse_categorical_accuracy: 0.4895
# Epoch 37/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2103 - sparse_categorical_accuracy: 0.1047 - val_loss: 2.9794 - val_sparse_categorical_accuracy: 0.4885
# Epoch 38/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2092 - sparse_categorical_accuracy: 0.0980 - val_loss: 2.9774 - val_sparse_categorical_accuracy: 0.4927
# Epoch 39/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2161 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.9754 - val_sparse_categorical_accuracy: 0.4933
# Epoch 40/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2074 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.9734 - val_sparse_categorical_accuracy: 0.4930
# Epoch 41/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2227 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.9716 - val_sparse_categorical_accuracy: 0.4947
# Epoch 42/50
# 4/4 [==============================] - 0s 60ms/step - loss: 3.2067 - sparse_categorical_accuracy: 0.0980 - val_loss: 2.9698 - val_sparse_categorical_accuracy: 0.4952
# Epoch 43/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2232 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.9681 - val_sparse_categorical_accuracy: 0.4942
# Epoch 44/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2167 - sparse_categorical_accuracy: 0.1000 - val_loss: 2.9665 - val_sparse_categorical_accuracy: 0.4938
# Epoch 45/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2080 - sparse_categorical_accuracy: 0.0967 - val_loss: 2.9648 - val_sparse_categorical_accuracy: 0.4967
# Epoch 46/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2149 - sparse_categorical_accuracy: 0.0965 - val_loss: 2.9631 - val_sparse_categorical_accuracy: 0.5015
# Epoch 47/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2078 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.9614 - val_sparse_categorical_accuracy: 0.4980
# Epoch 48/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2080 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.9598 - val_sparse_categorical_accuracy: 0.4990
# Epoch 49/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2076 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.9580 - val_sparse_categorical_accuracy: 0.5000
# Epoch 50/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2175 - sparse_categorical_accuracy: 0.0993 - val_loss: 2.9563 - val_sparse_categorical_accuracy: 0.5038
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 4/4 [==============================] - 0s 33ms/step - loss: 3.2030 - sparse_categorical_accuracy: 0.0988 - val_loss: 2.9547 - val_sparse_categorical_accuracy: 0.5033
# Epoch 2/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2115 - sparse_categorical_accuracy: 0.0993 - val_loss: 2.9531 - val_sparse_categorical_accuracy: 0.5058
# Epoch 3/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2070 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.9515 - val_sparse_categorical_accuracy: 0.5015
# Epoch 4/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2164 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.9500 - val_sparse_categorical_accuracy: 0.5017
# Epoch 5/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2172 - sparse_categorical_accuracy: 0.0950 - val_loss: 2.9486 - val_sparse_categorical_accuracy: 0.5020
# Epoch 6/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1939 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.9470 - val_sparse_categorical_accuracy: 0.5038
# Epoch 7/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.9455 - val_sparse_categorical_accuracy: 0.5082
# Epoch 8/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2206 - sparse_categorical_accuracy: 0.0970 - val_loss: 2.9440 - val_sparse_categorical_accuracy: 0.5052
# Epoch 9/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2224 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.9428 - val_sparse_categorical_accuracy: 0.5073
# Epoch 10/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1945 - sparse_categorical_accuracy: 0.0995 - val_loss: 2.9415 - val_sparse_categorical_accuracy: 0.5040
# Epoch 11/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2158 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.9403 - val_sparse_categorical_accuracy: 0.5005
# Epoch 12/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2042 - sparse_categorical_accuracy: 0.1018 - val_loss: 2.9391 - val_sparse_categorical_accuracy: 0.5052
# Epoch 13/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2094 - sparse_categorical_accuracy: 0.0882 - val_loss: 2.9379 - val_sparse_categorical_accuracy: 0.5052
# Epoch 14/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2153 - sparse_categorical_accuracy: 0.0985 - val_loss: 2.9367 - val_sparse_categorical_accuracy: 0.5040
# Epoch 15/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2157 - sparse_categorical_accuracy: 0.1070 - val_loss: 2.9356 - val_sparse_categorical_accuracy: 0.5132
# Epoch 16/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2030 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.9343 - val_sparse_categorical_accuracy: 0.5188
# Epoch 17/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2155 - sparse_categorical_accuracy: 0.0978 - val_loss: 2.9333 - val_sparse_categorical_accuracy: 0.5188
# Epoch 18/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2097 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.9321 - val_sparse_categorical_accuracy: 0.5197
# Epoch 19/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2152 - sparse_categorical_accuracy: 0.0922 - val_loss: 2.9310 - val_sparse_categorical_accuracy: 0.5210
# Epoch 20/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2171 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.9300 - val_sparse_categorical_accuracy: 0.5167
# Epoch 21/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2199 - sparse_categorical_accuracy: 0.0970 - val_loss: 2.9290 - val_sparse_categorical_accuracy: 0.5145
# Epoch 22/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2177 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.9281 - val_sparse_categorical_accuracy: 0.5167
# Epoch 23/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1960 - sparse_categorical_accuracy: 0.1077 - val_loss: 2.9271 - val_sparse_categorical_accuracy: 0.5190
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2173 - sparse_categorical_accuracy: 0.0948 - val_loss: 2.9262 - val_sparse_categorical_accuracy: 0.5213
# Epoch 25/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1857 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.9251 - val_sparse_categorical_accuracy: 0.5213
# Epoch 26/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1959 - sparse_categorical_accuracy: 0.0978 - val_loss: 2.9237 - val_sparse_categorical_accuracy: 0.5242
# Epoch 27/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1991 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.9224 - val_sparse_categorical_accuracy: 0.5288
# Epoch 28/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2075 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.9212 - val_sparse_categorical_accuracy: 0.5255
# Epoch 29/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2103 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.9201 - val_sparse_categorical_accuracy: 0.5285
# Epoch 30/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2029 - sparse_categorical_accuracy: 0.0955 - val_loss: 2.9190 - val_sparse_categorical_accuracy: 0.5250
# Epoch 31/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2094 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.9180 - val_sparse_categorical_accuracy: 0.5230
# Epoch 32/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2128 - sparse_categorical_accuracy: 0.0990 - val_loss: 2.9171 - val_sparse_categorical_accuracy: 0.5260
# Epoch 33/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2154 - sparse_categorical_accuracy: 0.0955 - val_loss: 2.9163 - val_sparse_categorical_accuracy: 0.5263
# Epoch 34/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2028 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.9155 - val_sparse_categorical_accuracy: 0.5240
# Epoch 35/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2029 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.9144 - val_sparse_categorical_accuracy: 0.5263
# Epoch 36/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2168 - sparse_categorical_accuracy: 0.0945 - val_loss: 2.9135 - val_sparse_categorical_accuracy: 0.5290
# Epoch 37/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1979 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.9125 - val_sparse_categorical_accuracy: 0.5225
# Epoch 38/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1032 - val_loss: 2.9116 - val_sparse_categorical_accuracy: 0.5150
# Epoch 39/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2157 - sparse_categorical_accuracy: 0.0945 - val_loss: 2.9107 - val_sparse_categorical_accuracy: 0.5175
# Epoch 40/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1872 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.9099 - val_sparse_categorical_accuracy: 0.5203
# Epoch 41/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2007 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.9088 - val_sparse_categorical_accuracy: 0.5222
# Epoch 42/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.9079 - val_sparse_categorical_accuracy: 0.5253
# Epoch 43/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1937 - sparse_categorical_accuracy: 0.1018 - val_loss: 2.9070 - val_sparse_categorical_accuracy: 0.5263
# Epoch 44/50
# 4/4 [==============================] - 0s 58ms/step - loss: 3.1943 - sparse_categorical_accuracy: 0.1130 - val_loss: 2.9060 - val_sparse_categorical_accuracy: 0.5285
# Epoch 45/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2105 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.9051 - val_sparse_categorical_accuracy: 0.5282
# Epoch 46/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1971 - sparse_categorical_accuracy: 0.0978 - val_loss: 2.9042 - val_sparse_categorical_accuracy: 0.5325
# Epoch 47/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2044 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.9033 - val_sparse_categorical_accuracy: 0.5350
# Epoch 48/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1973 - sparse_categorical_accuracy: 0.0983 - val_loss: 2.9023 - val_sparse_categorical_accuracy: 0.5315
# Epoch 49/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2155 - sparse_categorical_accuracy: 0.1013 - val_loss: 2.9015 - val_sparse_categorical_accuracy: 0.5312
# Epoch 50/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2050 - sparse_categorical_accuracy: 0.0995 - val_loss: 2.9008 - val_sparse_categorical_accuracy: 0.5350
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 4/4 [==============================] - 0s 32ms/step - loss: 3.1920 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.9000 - val_sparse_categorical_accuracy: 0.5330
# Epoch 2/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1936 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.8992 - val_sparse_categorical_accuracy: 0.5318
# Epoch 3/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1933 - sparse_categorical_accuracy: 0.1088 - val_loss: 2.8982 - val_sparse_categorical_accuracy: 0.5410
# Epoch 4/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2122 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8972 - val_sparse_categorical_accuracy: 0.5418
# Epoch 5/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2015 - sparse_categorical_accuracy: 0.0955 - val_loss: 2.8964 - val_sparse_categorical_accuracy: 0.5445
# Epoch 6/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1000 - val_loss: 2.8957 - val_sparse_categorical_accuracy: 0.5468
# Epoch 7/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1995 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.8950 - val_sparse_categorical_accuracy: 0.5470
# Epoch 8/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1960 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8943 - val_sparse_categorical_accuracy: 0.5437
# Epoch 9/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2014 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8935 - val_sparse_categorical_accuracy: 0.5440
# Epoch 10/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2014 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8927 - val_sparse_categorical_accuracy: 0.5422
# Epoch 11/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2195 - sparse_categorical_accuracy: 0.0938 - val_loss: 2.8921 - val_sparse_categorical_accuracy: 0.5383
# Epoch 12/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2044 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8916 - val_sparse_categorical_accuracy: 0.5428
# Epoch 13/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2094 - sparse_categorical_accuracy: 0.0975 - val_loss: 2.8913 - val_sparse_categorical_accuracy: 0.5422
# Epoch 14/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2116 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8909 - val_sparse_categorical_accuracy: 0.5445
# Epoch 15/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.8904 - val_sparse_categorical_accuracy: 0.5475
# Epoch 16/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1962 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.8898 - val_sparse_categorical_accuracy: 0.5490
# Epoch 17/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1918 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.8892 - val_sparse_categorical_accuracy: 0.5480
# Epoch 18/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2007 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.8885 - val_sparse_categorical_accuracy: 0.5495
# Epoch 19/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2061 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8879 - val_sparse_categorical_accuracy: 0.5497
# Epoch 20/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2157 - sparse_categorical_accuracy: 0.1047 - val_loss: 2.8875 - val_sparse_categorical_accuracy: 0.5508
# Epoch 21/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2155 - sparse_categorical_accuracy: 0.0930 - val_loss: 2.8872 - val_sparse_categorical_accuracy: 0.5480
# Epoch 22/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8868 - val_sparse_categorical_accuracy: 0.5455
# Epoch 23/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1947 - sparse_categorical_accuracy: 0.1090 - val_loss: 2.8863 - val_sparse_categorical_accuracy: 0.5465
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1991 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.8857 - val_sparse_categorical_accuracy: 0.5535
# Epoch 25/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1992 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8851 - val_sparse_categorical_accuracy: 0.5548
# Epoch 26/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1708 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8844 - val_sparse_categorical_accuracy: 0.5530
# Epoch 27/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2135 - sparse_categorical_accuracy: 0.0935 - val_loss: 2.8838 - val_sparse_categorical_accuracy: 0.5562
# Epoch 28/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2197 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8833 - val_sparse_categorical_accuracy: 0.5558
# Epoch 29/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1928 - sparse_categorical_accuracy: 0.1047 - val_loss: 2.8829 - val_sparse_categorical_accuracy: 0.5552
# Epoch 30/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2186 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8827 - val_sparse_categorical_accuracy: 0.5573
# Epoch 31/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1963 - sparse_categorical_accuracy: 0.1000 - val_loss: 2.8822 - val_sparse_categorical_accuracy: 0.5570
# Epoch 32/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2019 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8818 - val_sparse_categorical_accuracy: 0.5565
# Epoch 33/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1853 - sparse_categorical_accuracy: 0.0980 - val_loss: 2.8812 - val_sparse_categorical_accuracy: 0.5540
# Epoch 34/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2098 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8806 - val_sparse_categorical_accuracy: 0.5530
# Epoch 35/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1938 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.8801 - val_sparse_categorical_accuracy: 0.5548
# Epoch 36/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1909 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.8795 - val_sparse_categorical_accuracy: 0.5573
# Epoch 37/50
# 4/4 [==============================] - 0s 57ms/step - loss: 3.1825 - sparse_categorical_accuracy: 0.1080 - val_loss: 2.8788 - val_sparse_categorical_accuracy: 0.5605
# Epoch 38/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2015 - sparse_categorical_accuracy: 0.1053 - val_loss: 2.8781 - val_sparse_categorical_accuracy: 0.5640
# Epoch 39/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2030 - sparse_categorical_accuracy: 0.1018 - val_loss: 2.8776 - val_sparse_categorical_accuracy: 0.5658
# Epoch 40/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1952 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.8770 - val_sparse_categorical_accuracy: 0.5695
# Epoch 41/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2036 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8766 - val_sparse_categorical_accuracy: 0.5725
# Epoch 42/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1865 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8762 - val_sparse_categorical_accuracy: 0.5688
# Epoch 43/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2000 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8756 - val_sparse_categorical_accuracy: 0.5675
# Epoch 44/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1911 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8751 - val_sparse_categorical_accuracy: 0.5660
# Epoch 45/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1965 - sparse_categorical_accuracy: 0.1095 - val_loss: 2.8747 - val_sparse_categorical_accuracy: 0.5665
# Epoch 46/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1965 - sparse_categorical_accuracy: 0.1042 - val_loss: 2.8742 - val_sparse_categorical_accuracy: 0.5633
# Epoch 47/50
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2179 - sparse_categorical_accuracy: 0.0932 - val_loss: 2.8740 - val_sparse_categorical_accuracy: 0.5608
# Epoch 48/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1939 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.8737 - val_sparse_categorical_accuracy: 0.5592
# Epoch 49/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2207 - sparse_categorical_accuracy: 0.0967 - val_loss: 2.8734 - val_sparse_categorical_accuracy: 0.5630
# Epoch 50/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.2001 - sparse_categorical_accuracy: 0.0975 - val_loss: 2.8732 - val_sparse_categorical_accuracy: 0.5660
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 4/4 [==============================] - 0s 30ms/step - loss: 3.2045 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8728 - val_sparse_categorical_accuracy: 0.5698
# Epoch 2/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2072 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.8726 - val_sparse_categorical_accuracy: 0.5688
# Epoch 3/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2112 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8725 - val_sparse_categorical_accuracy: 0.5620
# Epoch 4/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1923 - sparse_categorical_accuracy: 0.1115 - val_loss: 2.8723 - val_sparse_categorical_accuracy: 0.5612
# Epoch 5/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2067 - sparse_categorical_accuracy: 0.0978 - val_loss: 2.8721 - val_sparse_categorical_accuracy: 0.5623
# Epoch 6/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1896 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8718 - val_sparse_categorical_accuracy: 0.5648
# Epoch 7/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1895 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.8714 - val_sparse_categorical_accuracy: 0.5685
# Epoch 8/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2225 - sparse_categorical_accuracy: 0.0957 - val_loss: 2.8712 - val_sparse_categorical_accuracy: 0.5673
# Epoch 9/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2135 - sparse_categorical_accuracy: 0.0943 - val_loss: 2.8712 - val_sparse_categorical_accuracy: 0.5688
# Epoch 10/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1865 - sparse_categorical_accuracy: 0.1072 - val_loss: 2.8711 - val_sparse_categorical_accuracy: 0.5740
# Epoch 11/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2024 - sparse_categorical_accuracy: 0.0970 - val_loss: 2.8707 - val_sparse_categorical_accuracy: 0.5727
# Epoch 12/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2094 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8705 - val_sparse_categorical_accuracy: 0.5745
# Epoch 13/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2004 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8703 - val_sparse_categorical_accuracy: 0.5785
# Epoch 14/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.2031 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8701 - val_sparse_categorical_accuracy: 0.5775
# Epoch 15/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1952 - sparse_categorical_accuracy: 0.1040 - val_loss: 2.8697 - val_sparse_categorical_accuracy: 0.5773
# Epoch 16/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1844 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.8693 - val_sparse_categorical_accuracy: 0.5765
# Epoch 17/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1942 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8688 - val_sparse_categorical_accuracy: 0.5727
# Epoch 18/50
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1845 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8682 - val_sparse_categorical_accuracy: 0.5807
# Epoch 19/50
# ...
# Epoch 12/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1777 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7235
# Epoch 13/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1899 - sparse_categorical_accuracy: 0.1090 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7268
# Epoch 14/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1680 - sparse_categorical_accuracy: 0.1255 - val_loss: 2.8278 - val_sparse_categorical_accuracy: 0.7255
# Epoch 15/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1817 - sparse_categorical_accuracy: 0.1125 - val_loss: 2.8279 - val_sparse_categorical_accuracy: 0.7228
# Epoch 16/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1817 - sparse_categorical_accuracy: 0.1117 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7237
# Epoch 17/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1779 - sparse_categorical_accuracy: 0.1163 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7258
# Epoch 18/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1751 - sparse_categorical_accuracy: 0.1230 - val_loss: 2.8274 - val_sparse_categorical_accuracy: 0.7285
# Epoch 19/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1940 - sparse_categorical_accuracy: 0.1205 - val_loss: 2.8273 - val_sparse_categorical_accuracy: 0.7237
# Epoch 20/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1600 - sparse_categorical_accuracy: 0.1155 - val_loss: 2.8272 - val_sparse_categorical_accuracy: 0.7253
# Epoch 21/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1714 - sparse_categorical_accuracy: 0.1142 - val_loss: 2.8271 - val_sparse_categorical_accuracy: 0.7210
# Epoch 22/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1989 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7230
# Epoch 23/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1998 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7247
# Epoch 24/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1894 - sparse_categorical_accuracy: 0.1105 - val_loss: 2.8271 - val_sparse_categorical_accuracy: 0.7232
# Epoch 25/50
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1898 - sparse_categorical_accuracy: 0.1095 - val_loss: 2.8273 - val_sparse_categorical_accuracy: 0.7262
# Epoch 26/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1756 - sparse_categorical_accuracy: 0.1125 - val_loss: 2.8273 - val_sparse_categorical_accuracy: 0.7260
# Epoch 27/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1956 - sparse_categorical_accuracy: 0.1077 - val_loss: 2.8274 - val_sparse_categorical_accuracy: 0.7247
# Epoch 28/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1881 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8274 - val_sparse_categorical_accuracy: 0.7262
# Epoch 29/50
# 4/4 [==============================] - 0s 26ms/step - loss: 3.1767 - sparse_categorical_accuracy: 0.1182 - val_loss: 2.8273 - val_sparse_categorical_accuracy: 0.7283
# Epoch 30/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1798 - sparse_categorical_accuracy: 0.1157 - val_loss: 2.8271 - val_sparse_categorical_accuracy: 0.7275
# Epoch 31/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1954 - sparse_categorical_accuracy: 0.1133 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7270
# Epoch 32/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1824 - sparse_categorical_accuracy: 0.1168 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7278
# Epoch 33/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1952 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7320
# Epoch 34/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1942 - sparse_categorical_accuracy: 0.1128 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7330
# Epoch 35/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.8272 - val_sparse_categorical_accuracy: 0.7280
# Epoch 36/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1657 - sparse_categorical_accuracy: 0.1210 - val_loss: 2.8273 - val_sparse_categorical_accuracy: 0.7262
# Epoch 37/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1980 - sparse_categorical_accuracy: 0.1125 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7240
# Epoch 38/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1715 - sparse_categorical_accuracy: 0.1100 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7255
# Epoch 39/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1794 - sparse_categorical_accuracy: 0.1217 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7283
# Epoch 40/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1888 - sparse_categorical_accuracy: 0.1070 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7272
# Epoch 41/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1838 - sparse_categorical_accuracy: 0.1090 - val_loss: 2.8276 - val_sparse_categorical_accuracy: 0.7245
# Epoch 42/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1730 - sparse_categorical_accuracy: 0.1067 - val_loss: 2.8276 - val_sparse_categorical_accuracy: 0.7290
# Epoch 43/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1944 - sparse_categorical_accuracy: 0.1150 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7290
# Epoch 44/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1809 - sparse_categorical_accuracy: 0.1115 - val_loss: 2.8276 - val_sparse_categorical_accuracy: 0.7343
# Epoch 45/50
# 4/4 [==============================] - 0s 26ms/step - loss: 3.1758 - sparse_categorical_accuracy: 0.1182 - val_loss: 2.8274 - val_sparse_categorical_accuracy: 0.7345
# Epoch 46/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1760 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.8272 - val_sparse_categorical_accuracy: 0.7312
# Epoch 47/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1690 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8270 - val_sparse_categorical_accuracy: 0.7312
# Epoch 48/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1531 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8266 - val_sparse_categorical_accuracy: 0.7300
# Epoch 49/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1770 - sparse_categorical_accuracy: 0.1123 - val_loss: 2.8262 - val_sparse_categorical_accuracy: 0.7245
# Epoch 50/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1855 - sparse_categorical_accuracy: 0.1165 - val_loss: 2.8260 - val_sparse_categorical_accuracy: 0.7270
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 4/4 [==============================] - 0s 33ms/step - loss: 3.1774 - sparse_categorical_accuracy: 0.1088 - val_loss: 2.8257 - val_sparse_categorical_accuracy: 0.7247
# Epoch 2/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1768 - sparse_categorical_accuracy: 0.1252 - val_loss: 2.8256 - val_sparse_categorical_accuracy: 0.7243
# Epoch 3/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1933 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.8255 - val_sparse_categorical_accuracy: 0.7253
# Epoch 4/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1753 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8254 - val_sparse_categorical_accuracy: 0.7262
# Epoch 5/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1613 - sparse_categorical_accuracy: 0.1173 - val_loss: 2.8253 - val_sparse_categorical_accuracy: 0.7245
# Epoch 6/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1793 - sparse_categorical_accuracy: 0.1130 - val_loss: 2.8251 - val_sparse_categorical_accuracy: 0.7265
# Epoch 7/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1737 - sparse_categorical_accuracy: 0.1243 - val_loss: 2.8250 - val_sparse_categorical_accuracy: 0.7245
# Epoch 8/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1887 - sparse_categorical_accuracy: 0.1135 - val_loss: 2.8248 - val_sparse_categorical_accuracy: 0.7275
# Epoch 9/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1942 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8247 - val_sparse_categorical_accuracy: 0.7262
# Epoch 10/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1819 - sparse_categorical_accuracy: 0.1098 - val_loss: 2.8248 - val_sparse_categorical_accuracy: 0.7280
# Epoch 11/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2108 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8249 - val_sparse_categorical_accuracy: 0.7268
# Epoch 12/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1532 - sparse_categorical_accuracy: 0.1210 - val_loss: 2.8250 - val_sparse_categorical_accuracy: 0.7253
# Epoch 13/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1852 - sparse_categorical_accuracy: 0.1213 - val_loss: 2.8250 - val_sparse_categorical_accuracy: 0.7283
# Epoch 14/50
# 4/4 [==============================] - 0s 63ms/step - loss: 3.1860 - sparse_categorical_accuracy: 0.1125 - val_loss: 2.8251 - val_sparse_categorical_accuracy: 0.7270
# Epoch 15/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1731 - sparse_categorical_accuracy: 0.1245 - val_loss: 2.8251 - val_sparse_categorical_accuracy: 0.7250
# Epoch 16/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1645 - sparse_categorical_accuracy: 0.1222 - val_loss: 2.8250 - val_sparse_categorical_accuracy: 0.7287
# Epoch 17/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1742 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8249 - val_sparse_categorical_accuracy: 0.7297
# Epoch 18/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1655 - sparse_categorical_accuracy: 0.1130 - val_loss: 2.8245 - val_sparse_categorical_accuracy: 0.7337
# Epoch 19/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1789 - sparse_categorical_accuracy: 0.1173 - val_loss: 2.8243 - val_sparse_categorical_accuracy: 0.7385
# Epoch 20/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1878 - sparse_categorical_accuracy: 0.1133 - val_loss: 2.8242 - val_sparse_categorical_accuracy: 0.7368
# Epoch 21/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1848 - sparse_categorical_accuracy: 0.1177 - val_loss: 2.8241 - val_sparse_categorical_accuracy: 0.7395
# Epoch 22/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2028 - sparse_categorical_accuracy: 0.1095 - val_loss: 2.8243 - val_sparse_categorical_accuracy: 0.7315
# Epoch 23/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1798 - sparse_categorical_accuracy: 0.1120 - val_loss: 2.8246 - val_sparse_categorical_accuracy: 0.7330
# Epoch 24/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1699 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8246 - val_sparse_categorical_accuracy: 0.7312
# Epoch 25/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1780 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8244 - val_sparse_categorical_accuracy: 0.7278
# Epoch 26/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1870 - sparse_categorical_accuracy: 0.1105 - val_loss: 2.8244 - val_sparse_categorical_accuracy: 0.7228
# Epoch 27/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1857 - sparse_categorical_accuracy: 0.1103 - val_loss: 2.8243 - val_sparse_categorical_accuracy: 0.7220
# Epoch 28/50
# 4/4 [==============================] - 0s 25ms/step - loss: 3.1802 - sparse_categorical_accuracy: 0.1130 - val_loss: 2.8243 - val_sparse_categorical_accuracy: 0.7247
# Epoch 29/50
# 4/4 [==============================] - 0s 26ms/step - loss: 3.1923 - sparse_categorical_accuracy: 0.1098 - val_loss: 2.8244 - val_sparse_categorical_accuracy: 0.7285
# Epoch 30/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1818 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8243 - val_sparse_categorical_accuracy: 0.7358
# Epoch 31/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.2008 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8244 - val_sparse_categorical_accuracy: 0.7340
# Epoch 32/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1992 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8246 - val_sparse_categorical_accuracy: 0.7333
# Epoch 33/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1833 - sparse_categorical_accuracy: 0.1070 - val_loss: 2.8249 - val_sparse_categorical_accuracy: 0.7365
# Epoch 34/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1790 - sparse_categorical_accuracy: 0.1225 - val_loss: 2.8252 - val_sparse_categorical_accuracy: 0.7385
# Epoch 35/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1799 - sparse_categorical_accuracy: 0.1100 - val_loss: 2.8254 - val_sparse_categorical_accuracy: 0.7365
# Epoch 36/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1886 - sparse_categorical_accuracy: 0.1095 - val_loss: 2.8256 - val_sparse_categorical_accuracy: 0.7375
# Epoch 37/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1707 - sparse_categorical_accuracy: 0.1208 - val_loss: 2.8256 - val_sparse_categorical_accuracy: 0.7383
# Epoch 38/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1971 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8257 - val_sparse_categorical_accuracy: 0.7370
# Epoch 39/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1822 - sparse_categorical_accuracy: 0.1160 - val_loss: 2.8257 - val_sparse_categorical_accuracy: 0.7345
# Epoch 40/50
# 4/4 [==============================] - 0s 27ms/step - loss: 3.1851 - sparse_categorical_accuracy: 0.1090 - val_loss: 2.8258 - val_sparse_categorical_accuracy: 0.7337
# Epoch 41/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1903 - sparse_categorical_accuracy: 0.1145 - val_loss: 2.8259 - val_sparse_categorical_accuracy: 0.7347
# Epoch 42/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1968 - sparse_categorical_accuracy: 0.1142 - val_loss: 2.8260 - val_sparse_categorical_accuracy: 0.7362
# Epoch 43/50
# 4/4 [==============================] - 0s 24ms/step - loss: 3.1894 - sparse_categorical_accuracy: 0.1105 - val_loss: 2.8262 - val_sparse_categorical_accuracy: 0.7352
# Epoch 44/50
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1890 - sparse_categorical_accuracy: 0.1093 - val_loss: 2.8264 - val_sparse_categorical_accuracy: 0.7308
# Epoch 45/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1082 - val_loss: 2.8268 - val_sparse_categorical_accuracy: 0.7283
# Epoch 46/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1996 - sparse_categorical_accuracy: 0.1115 - val_loss: 2.8271 - val_sparse_categorical_accuracy: 0.7245
# Epoch 47/50
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1684 - sparse_categorical_accuracy: 0.1192 - val_loss: 2.8274 - val_sparse_categorical_accuracy: 0.7278
# Epoch 48/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.2076 - sparse_categorical_accuracy: 0.1082 - val_loss: 2.8275 - val_sparse_categorical_accuracy: 0.7333
# Epoch 49/50
# 4/4 [==============================] - 0s 23ms/step - loss: 3.1774 - sparse_categorical_accuracy: 0.1152 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7337
# Epoch 50/50
# 4/4 [==============================] - 0s 22ms/step - loss: 3.1719 - sparse_categorical_accuracy: 0.1222 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.7315

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor3, bler_per_iter_dl_tensor3, channel_out3  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (2000, 2, 32)
# SNR: 0.000:-> BLER: 0.99250 BER: 0.46160
# total_bit_error: 9232
# total_msg_error: 1985
# SNR: 0.500:-> BLER: 0.97850 BER: 0.46060
# total_bit_error: 9212
# total_msg_error: 1957
# SNR: 1.000:-> BLER: 0.98300 BER: 0.45895
# total_bit_error: 9179
# total_msg_error: 1966
# SNR: 1.500:-> BLER: 0.98450 BER: 0.45930
# total_bit_error: 9186
# total_msg_error: 1969
# SNR: 2.000:-> BLER: 0.98300 BER: 0.45315
# total_bit_error: 9063
# total_msg_error: 1966
# SNR: 2.500:-> BLER: 0.97800 BER: 0.44865
# total_bit_error: 8973
# total_msg_error: 1956
# SNR: 3.000:-> BLER: 0.97150 BER: 0.44445
# total_bit_error: 8889
# total_msg_error: 1943
# SNR: 3.500:-> BLER: 0.96900 BER: 0.43950
# total_bit_error: 8790
# total_msg_error: 1938
# SNR: 4.000:-> BLER: 0.96650 BER: 0.43815
# total_bit_error: 8763
# total_msg_error: 1933
# SNR: 4.500:-> BLER: 0.96550 BER: 0.43545
# total_bit_error: 8709
# total_msg_error: 1931
# SNR: 5.000:-> BLER: 0.95550 BER: 0.42130
# total_bit_error: 8426
# total_msg_error: 1911
# SNR: 5.500:-> BLER: 0.95500 BER: 0.40840
# total_bit_error: 8168
# total_msg_error: 1910
# SNR: 6.000:-> BLER: 0.94750 BER: 0.40850
# total_bit_error: 8170
# total_msg_error: 1895
# SNR: 6.500:-> BLER: 0.94400 BER: 0.39560
# total_bit_error: 7912
# total_msg_error: 1888
# SNR: 7.000:-> BLER: 0.92800 BER: 0.39300
# total_bit_error: 7860
# total_msg_error: 1856
# SNR: 7.500:-> BLER: 0.92700 BER: 0.37930
# total_bit_error: 7586
# total_msg_error: 1854
# SNR: 8.000:-> BLER: 0.89550 BER: 0.36045
# total_bit_error: 7209
# total_msg_error: 1791
# SNR: 8.500:-> BLER: 0.89250 BER: 0.35405
# total_bit_error: 7081
# total_msg_error: 1785
# SNR: 9.000:-> BLER: 0.87050 BER: 0.34415
# total_bit_error: 6883
# total_msg_error: 1741
# SNR: 9.500:-> BLER: 0.86850 BER: 0.33480
# total_bit_error: 6696
# total_msg_error: 1737
# [1.2105e-01 9.8450e-02 7.2950e-02 6.2150e-02 4.9450e-02 2.8500e-02
#  2.2700e-02 1.3800e-02 9.3000e-03 5.7500e-03 2.7000e-03 1.4500e-03
#  7.0000e-04 2.5000e-04 1.5000e-04 1.0000e-04 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00]
# [0.4185 0.3415 0.2655 0.219  0.1815 0.115  0.086  0.0505 0.033  0.021
#  0.01   0.005  0.002  0.001  0.0005 0.0005 0.     0.     0.     0.    ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor3,'', label="ai-dl(5x2_30_10)(3)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor3,'', label="ai-dl(5x2_30_10)(3)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 1.0
