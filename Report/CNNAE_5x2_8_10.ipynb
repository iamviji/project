# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Report/CNNAE_5x2_8_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise, BatchNormalization, Conv1D, Activation, Lambda, Flatten

from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 5
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 8
channel_size = 5 


NUM_OF_INPUT_MESSAGE = 1000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
def PowerNormLayer(x):
    nx =  x / tf.sqrt(tf.reduce_mean(tf.square(x)))
    return nx

# %%
snr_std = Snr2Sigma(7.0)
num_filters = 2**encoder_output_length
print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)

input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_1')(input_message_x)
enc = BatchNormalization(name='enc_2')(enc)
enc = Activation('elu', name='enc_3')(enc)

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_4')(enc)
enc = BatchNormalization(name='enc_5')(enc)
enc = Activation('elu', name='ecn_6')(enc)

enc = Conv1D(filters=2 * channel_size, strides=1, kernel_size=1, name='ch_1')(enc)
enc = BatchNormalization(name='ch_2')(enc)
enc = Activation('linear', name='ch_3')(enc)
enc = Flatten()(enc)
encoder_out = Lambda(PowerNormLayer, name='PowerNorm')(enc)

encoder = Model(input_message_x, encoder_out)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

encoded_input = Input(shape=(num_of_input_block*2*channel_size,))

reshaped_input = tf.reshape (encoded_input, (-1,num_of_input_block,2*channel_size))


dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_1')(reshaped_input)
dec = BatchNormalization(name='dec_2')(dec)
dec = Activation('elu', name='dec_3')(dec)

dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_4')(dec)
dec = BatchNormalization(name='dec_5')(dec)
dec = Activation('elu', name='dec_6')(dec)

model_output = Conv1D(filters=2 ** input_block_length, strides=1, kernel_size=1, name='d_10', activation='softmax')(dec)


decoder = Model(encoded_input, model_output)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# enc_1 (Conv1D)               (None, 2, 256)            8448
# _________________________________________________________________
# enc_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# enc_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# enc_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# enc_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# ecn_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# ch_1 (Conv1D)                (None, 2, 10)             2570
# _________________________________________________________________
# ch_2 (BatchNormalization)    (None, 2, 10)             40
# _________________________________________________________________
# ch_3 (Activation)            (None, 2, 10)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 20)                0
# _________________________________________________________________
# PowerNorm (Lambda)           (None, 20)                0
# =================================================================
# Total params: 78,898
# Trainable params: 77,854
# Non-trainable params: 1,044
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# tf.reshape (TFOpLambda)      (None, 2, 10)             0
# _________________________________________________________________
# dec_1 (Conv1D)               (None, 2, 256)            2816
# _________________________________________________________________
# dec_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# dec_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# dec_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# d_10 (Conv1D)                (None, 2, 32)             8224
# =================================================================
# Total params: 78,880
# Trainable params: 77,856
# Non-trainable params: 1,024
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model (Functional)           (None, 20)                78898
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 20)                0
# _________________________________________________________________
# model_1 (Functional)         (None, 2, 32)             78880
# =================================================================
# Total params: 157,778
# Trainable params: 155,710
# Non-trainable params: 2,068
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
beginTime = time.clock()
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=500,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history
endTime = time.clock()
print('TotalTime: ' + str(endTime - beginTime) + ' s')
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 2/2 [==============================] - 2s 507ms/step - loss: 3.8208 - sparse_categorical_accuracy: 0.0593 - val_loss: 2.8741 - val_sparse_categorical_accuracy: 0.6570
# Epoch 2/50
# 2/2 [==============================] - 0s 99ms/step - loss: 2.1167 - sparse_categorical_accuracy: 0.4710 - val_loss: 2.4712 - val_sparse_categorical_accuracy: 0.9680
# Epoch 3/50
# 2/2 [==============================] - 0s 102ms/step - loss: 1.5733 - sparse_categorical_accuracy: 0.6647 - val_loss: 2.2053 - val_sparse_categorical_accuracy: 0.9680
# Epoch 4/50
# 2/2 [==============================] - 0s 97ms/step - loss: 1.3442 - sparse_categorical_accuracy: 0.6910 - val_loss: 1.9483 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 97ms/step - loss: 1.1053 - sparse_categorical_accuracy: 0.7350 - val_loss: 1.7008 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9441 - sparse_categorical_accuracy: 0.7513 - val_loss: 1.4825 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.8512 - sparse_categorical_accuracy: 0.7923 - val_loss: 1.2999 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.7755 - sparse_categorical_accuracy: 0.7760 - val_loss: 1.1497 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.7213 - sparse_categorical_accuracy: 0.8007 - val_loss: 1.0264 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6588 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.9243 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6647 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.8392 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.6742 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.7672 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.8070 - val_loss: 0.7045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6250 - sparse_categorical_accuracy: 0.8177 - val_loss: 0.6505 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6288 - sparse_categorical_accuracy: 0.8133 - val_loss: 0.6042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5808 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.5654 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6126 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.5335 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 187ms/step - loss: 0.5856 - sparse_categorical_accuracy: 0.8117 - val_loss: 0.5066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5609 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.4827 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6012 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.4610 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5908 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.4416 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5918 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.4235 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5323 - sparse_categorical_accuracy: 0.8413 - val_loss: 0.4045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5717 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.3871 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5526 - sparse_categorical_accuracy: 0.8227 - val_loss: 0.3711 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5672 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.3573 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5548 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.8373 - val_loss: 0.3373 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5581 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.3278 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5391 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.3182 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5173 - sparse_categorical_accuracy: 0.8377 - val_loss: 0.3092 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5443 - sparse_categorical_accuracy: 0.8237 - val_loss: 0.3007 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5375 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.2922 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.8337 - val_loss: 0.2838 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5579 - sparse_categorical_accuracy: 0.8193 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5617 - sparse_categorical_accuracy: 0.8223 - val_loss: 0.2660 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5534 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.2574 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5844 - sparse_categorical_accuracy: 0.8083 - val_loss: 0.2479 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5192 - sparse_categorical_accuracy: 0.8517 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5443 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.2328 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5387 - sparse_categorical_accuracy: 0.8210 - val_loss: 0.2268 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5232 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.2190 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5637 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.2097 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5719 - sparse_categorical_accuracy: 0.8150 - val_loss: 0.2012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5143 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.1948 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5476 - sparse_categorical_accuracy: 0.8283 - val_loss: 0.1889 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5640 - sparse_categorical_accuracy: 0.8253 - val_loss: 0.1827 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5601 - sparse_categorical_accuracy: 0.8373 - val_loss: 0.1768 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5383 - sparse_categorical_accuracy: 0.8367 - val_loss: 0.1696 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5576 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.1634 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5625 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.1585 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5662 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.1533 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5926 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.1470 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5039 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.1398 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.1347 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5117 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.1312 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5358 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.1264 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5419 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.1215 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5858 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.1160 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5136 - sparse_categorical_accuracy: 0.8265 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5197 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.1087 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5502 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.1056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5229 - sparse_categorical_accuracy: 0.8265 - val_loss: 0.1023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5137 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5381 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0923 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5769 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5214 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 210ms/step - loss: 0.5453 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.0771 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5463 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5134 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5641 - sparse_categorical_accuracy: 0.8275 - val_loss: 0.0693 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5431 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0680 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5364 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0659 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5475 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0629 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5055 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0598 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5253 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0566 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.4903 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0508 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5051 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0481 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5299 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0458 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5264 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.0444 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0436 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5128 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0429 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5560 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0413 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5548 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0394 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5482 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.0370 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.4953 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5492 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0322 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5228 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0304 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5083 - sparse_categorical_accuracy: 0.8545 - val_loss: 0.0292 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5069 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0284 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5424 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0276 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5250 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.0267 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5095 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5291 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0245 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5097 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4881 - sparse_categorical_accuracy: 0.8490 - val_loss: 0.0219 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5172 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 2/2 [==============================] - 0s 144ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.0185 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5328 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0177 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5478 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5257 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.4472 - sparse_categorical_accuracy: 0.8565 - val_loss: 0.0155 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5497 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5023 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5167 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 204ms/step - loss: 0.4914 - sparse_categorical_accuracy: 0.8535 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5157 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5101 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5555 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4919 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5110 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5058 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4891 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5216 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5576 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5121 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5036 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5306 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5362 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0082 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5320 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5363 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4849 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5153 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5282 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4973 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4946 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4976 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4572 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5039 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5690 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5835 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4864 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5511 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5435 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5294 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4797 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5747 - sparse_categorical_accuracy: 0.8175 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4845 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4928 - sparse_categorical_accuracy: 0.8540 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5223 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0041 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5252 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5147 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5185 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5278 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5169 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5181 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5308 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.4796 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5129 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5013 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5081 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 207ms/step - loss: 0.4849 - sparse_categorical_accuracy: 0.8480 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5100 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4909 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.5008 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5217 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.4978 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5275 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5077 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5150 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5415 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5339 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4915 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4981 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4828 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4976 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5217 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5190 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5245 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5558 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4960 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4819 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5278 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5058 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4851 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.4888 - sparse_categorical_accuracy: 0.8405 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5194 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5026 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5198 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5366 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5006 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5257 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4900 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.4909 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5278 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.4870 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.4813 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5031 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5260 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5168 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5084 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4657 - sparse_categorical_accuracy: 0.8490 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 209ms/step - loss: 0.5052 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 2/2 [==============================] - 0s 135ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5185 - sparse_categorical_accuracy: 0.8265 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5011 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5179 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5097 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5518 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5011 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4812 - sparse_categorical_accuracy: 0.8540 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.5109 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5065 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5180 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5170 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5171 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.4986 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5596 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5479 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4610 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5009 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5137 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5295 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5237 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5246 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4959 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5222 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5424 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5009 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5084 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4861 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5284 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4841 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5156 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5277 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4749 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5217 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5040 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5092 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5326 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5550 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5465 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5485 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5008 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5145 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5292 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5318 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4902 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5338 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5141 - sparse_categorical_accuracy: 0.8405 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 205ms/step - loss: 0.4891 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5519 - sparse_categorical_accuracy: 0.8190 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5488 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5361 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5038 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5197 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5108 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.8205 - val_loss: 9.9503e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5047 - sparse_categorical_accuracy: 0.8395 - val_loss: 9.9727e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5132 - sparse_categorical_accuracy: 0.8425 - val_loss: 9.9844e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5470 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5163 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5175 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5270 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5281 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5266 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5249 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# ...
# Epoch 13/50
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5084 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5278 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5013 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4945 - sparse_categorical_accuracy: 0.8420 - val_loss: 9.9646e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5044 - sparse_categorical_accuracy: 0.8375 - val_loss: 9.8574e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5059 - sparse_categorical_accuracy: 0.8410 - val_loss: 9.7813e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4693 - sparse_categorical_accuracy: 0.8545 - val_loss: 9.8374e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5175 - sparse_categorical_accuracy: 0.8460 - val_loss: 9.9505e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4682 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4877 - sparse_categorical_accuracy: 0.8500 - val_loss: 9.9296e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4764 - sparse_categorical_accuracy: 0.8545 - val_loss: 9.9279e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5103 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5119 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5026 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.4817 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5198 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 200ms/step - loss: 0.5177 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4711 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 137ms/step - loss: 0.4915 - sparse_categorical_accuracy: 0.8360 - val_loss: 9.8989e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4682 - sparse_categorical_accuracy: 0.8485 - val_loss: 9.8146e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5144 - sparse_categorical_accuracy: 0.8375 - val_loss: 9.7858e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 129ms/step - loss: 0.5452 - sparse_categorical_accuracy: 0.8250 - val_loss: 9.8271e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.4987 - sparse_categorical_accuracy: 0.8405 - val_loss: 9.9362e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5261 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.5067 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5505 - sparse_categorical_accuracy: 0.8235 - val_loss: 9.9725e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.5086 - sparse_categorical_accuracy: 0.8435 - val_loss: 9.9027e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8300 - val_loss: 9.8132e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5258 - sparse_categorical_accuracy: 0.8320 - val_loss: 9.7881e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5190 - sparse_categorical_accuracy: 0.8345 - val_loss: 9.8018e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5433 - sparse_categorical_accuracy: 0.8295 - val_loss: 9.8702e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.4842 - sparse_categorical_accuracy: 0.8495 - val_loss: 9.9235e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.4800 - sparse_categorical_accuracy: 0.8490 - val_loss: 9.8788e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 143ms/step - loss: 0.4723 - sparse_categorical_accuracy: 0.8530 - val_loss: 9.8030e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5031 - sparse_categorical_accuracy: 0.8405 - val_loss: 9.8057e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4962 - sparse_categorical_accuracy: 0.8375 - val_loss: 9.8819e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.4956 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5018 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.5412 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5250 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5080 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5484 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5035 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 132ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5087 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5370 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4559 - sparse_categorical_accuracy: 0.8540 - val_loss: 9.9415e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5267 - sparse_categorical_accuracy: 0.8370 - val_loss: 9.8551e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5001 - sparse_categorical_accuracy: 0.8500 - val_loss: 9.8392e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5143 - sparse_categorical_accuracy: 0.8415 - val_loss: 9.9502e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5141 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4848 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.5045 - sparse_categorical_accuracy: 0.8440 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 128ms/step - loss: 0.4727 - sparse_categorical_accuracy: 0.8605 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4828 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4986 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5415 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4877 - sparse_categorical_accuracy: 0.8405 - val_loss: 9.9340e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 136ms/step - loss: 0.4967 - sparse_categorical_accuracy: 0.8440 - val_loss: 9.9600e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4931 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.5440 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5234 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4942 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.5257 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.5076 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5116 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 208ms/step - loss: 0.5219 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.5145 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 132ms/step - loss: 0.4895 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4845 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4916 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 124ms/step - loss: 0.5105 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4904 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5014 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 137ms/step - loss: 0.5092 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4881 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.5063 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5116 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5146 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4896 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 134ms/step - loss: 0.5006 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 129ms/step - loss: 0.5391 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.5064 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 128ms/step - loss: 0.4820 - sparse_categorical_accuracy: 0.8490 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 133ms/step - loss: 0.4962 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4910 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4692 - sparse_categorical_accuracy: 0.8555 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# TotalTime: 265.22006799999997 s

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.35500  BER: 0.10020
# total: 1002
# SNR: 0.500:
#  ->BLER: 0.27800  BER: 0.07810
# total: 781
# SNR: 1.000:
#  ->BLER: 0.22300  BER: 0.05900
# total: 590
# SNR: 1.500:
#  ->BLER: 0.17300  BER: 0.04750
# total: 475
# SNR: 2.000:
#  ->BLER: 0.12700  BER: 0.03190
# total: 319
# SNR: 2.500:
#  ->BLER: 0.07900  BER: 0.01960
# total: 196
# SNR: 3.000:
#  ->BLER: 0.06000  BER: 0.01530
# total: 153
# SNR: 3.500:
#  ->BLER: 0.02700  BER: 0.00670
# total: 67
# SNR: 4.000:
#  ->BLER: 0.02100  BER: 0.00500
# total: 50
# SNR: 4.500:
#  ->BLER: 0.00500  BER: 0.00190
# total: 19
# SNR: 5.000:
#  ->BLER: 0.00600  BER: 0.00190
# total: 19
# SNR: 5.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 6.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 6.500:
#  ->BLER: 0.00100  BER: 0.00030
# total: 3
# SNR: 7.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 7.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size*num_of_input_block)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.35800 BER: 0.09850
# total_bit_error: 985
# total_msg_error: 358
# SNR: 0.500:-> BLER: 0.26200 BER: 0.07000
# total_bit_error: 700
# total_msg_error: 262
# SNR: 1.000:-> BLER: 0.22600 BER: 0.05840
# total_bit_error: 584
# total_msg_error: 226
# SNR: 1.500:-> BLER: 0.14600 BER: 0.03970
# total_bit_error: 397
# total_msg_error: 146
# SNR: 2.000:-> BLER: 0.13200 BER: 0.03600
# total_bit_error: 360
# total_msg_error: 132
# SNR: 2.500:-> BLER: 0.09700 BER: 0.02450
# total_bit_error: 245
# total_msg_error: 97
# SNR: 3.000:-> BLER: 0.06100 BER: 0.01610
# total_bit_error: 161
# total_msg_error: 61
# SNR: 3.500:-> BLER: 0.04300 BER: 0.00960
# total_bit_error: 96
# total_msg_error: 43
# SNR: 4.000:-> BLER: 0.01900 BER: 0.00510
# total_bit_error: 51
# total_msg_error: 19
# SNR: 4.500:-> BLER: 0.01600 BER: 0.00380
# total_bit_error: 38
# total_msg_error: 16
# SNR: 5.000:-> BLER: 0.00500 BER: 0.00120
# total_bit_error: 12
# total_msg_error: 5
# SNR: 5.500:-> BLER: 0.00100 BER: 0.00030
# total_bit_error: 3
# total_msg_error: 1
# SNR: 6.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.1002 0.0781 0.059  0.0475 0.0319 0.0196 0.0153 0.0067 0.005  0.0019
#  0.0019 0.     0.     0.0003 0.     0.     0.     0.     0.     0.    ]
# [0.355 0.278 0.223 0.173 0.127 0.079 0.06  0.027 0.021 0.005 0.006 0.
#  0.    0.001 0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_10)(kernel=256)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_10)(kernel=256)(batch)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_10)(kernel=256)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_10)(kernel=256)(batch))") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 4.470895

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('Iteration')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
print (test_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size*num_of_input_block)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.32400 BER: 0.09150
# total_bit_error: 915
# total_msg_error: 324
# SNR: 0.500:-> BLER: 0.28800 BER: 0.08150
# total_bit_error: 815
# total_msg_error: 288
# SNR: 1.000:-> BLER: 0.23600 BER: 0.06320
# total_bit_error: 632
# total_msg_error: 236
# SNR: 1.500:-> BLER: 0.17900 BER: 0.04770
# total_bit_error: 477
# total_msg_error: 179
# SNR: 2.000:-> BLER: 0.13900 BER: 0.03720
# total_bit_error: 372
# total_msg_error: 139
# SNR: 2.500:-> BLER: 0.07900 BER: 0.01970
# total_bit_error: 197
# total_msg_error: 79
# SNR: 3.000:-> BLER: 0.05800 BER: 0.01480
# total_bit_error: 148
# total_msg_error: 58
# SNR: 3.500:-> BLER: 0.03100 BER: 0.00730
# total_bit_error: 73
# total_msg_error: 31
# SNR: 4.000:-> BLER: 0.02500 BER: 0.00650
# total_bit_error: 65
# total_msg_error: 25
# SNR: 4.500:-> BLER: 0.01000 BER: 0.00260
# total_bit_error: 26
# total_msg_error: 10
# SNR: 5.000:-> BLER: 0.00400 BER: 0.00090
# total_bit_error: 9
# total_msg_error: 4
# SNR: 5.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.000:-> BLER: 0.00200 BER: 0.00060
# total_bit_error: 6
# total_msg_error: 2
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.0915 0.0815 0.0632 0.0477 0.0372 0.0197 0.0148 0.0073 0.0065 0.0026
#  0.0009 0.     0.0006 0.     0.     0.     0.     0.     0.     0.    ]
# [0.324 0.288 0.236 0.179 0.139 0.079 0.058 0.031 0.025 0.01  0.004 0.
#  0.002 0.    0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(5x2_10)(kernel=256)(test)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_10)(kernel=256)(train)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
#ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_10)(kernel=256)(test)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_10)(kernel=256)(train)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_xlabel('SNR')
#ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
