# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Final/run/BlockAE_10x1_40_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise
from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 10
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 40
channel_size = 20


NUM_OF_INPUT_MESSAGE = 1000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)
train_batch_size = 500
input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))
encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 10
# Model: "model_60"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 1024)]    0
# __________________________________________________________________________________________________
# tf.reshape_36 (TFOpLambda)      (None, 2048)         0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 40)           81960       tf.reshape_36[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 40)           1640        enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_22 (TFOpLambda)  (None, 40)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_22 (TFOpLam ()                   0           tf.math.square_22[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_22 (TFOpLambda)    ()                   0           tf.math.reduce_mean_22[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_22 (TFOpLambda) (None, 40)           0           enc_layer2[0][0]
#                                                                  tf.math.sqrt_22[0][0]
# ==================================================================================================
# Total params: 83,600
# Trainable params: 83,600
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 40)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 2048)              83968
# _________________________________________________________________
# tf.reshape_37 (TFOpLambda)   (None, 2, 1024)           0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 1024)           1049600
# =================================================================
# Total params: 1,133,568
# Trainable params: 1,133,568
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 1024)]         0
# _________________________________________________________________
# model_60 (Functional)        (None, 40)                83600
# _________________________________________________________________
# gaussian_noise_22 (GaussianN (None, 40)                0
# _________________________________________________________________
# model_61 (Functional)        (None, 2, 1024)           1133568
# =================================================================
# Total params: 1,217,168
# Trainable params: 1,217,168
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
NUM_OF_INPUT_MESSAGE = train_batch_size * 10
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 10/10 [==============================] - 3s 206ms/step - loss: 0.3089 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.6466 - val_sparse_categorical_accuracy: 0.8513
# Epoch 2/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.6457 - val_sparse_categorical_accuracy: 0.8510
# Epoch 3/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2903 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.8506
# Epoch 4/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.3307 - sparse_categorical_accuracy: 0.9009 - val_loss: 0.6610 - val_sparse_categorical_accuracy: 0.8465
# Epoch 5/50
# 10/10 [==============================] - 2s 198ms/step - loss: 0.3152 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.6460 - val_sparse_categorical_accuracy: 0.8511
# Epoch 6/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.6399 - val_sparse_categorical_accuracy: 0.8530
# Epoch 7/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3098 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.6443 - val_sparse_categorical_accuracy: 0.8489
# Epoch 8/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2855 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6482 - val_sparse_categorical_accuracy: 0.8501
# Epoch 9/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2804 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6466 - val_sparse_categorical_accuracy: 0.8531
# Epoch 10/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3108 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.6469 - val_sparse_categorical_accuracy: 0.8545
# Epoch 11/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3038 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.6474 - val_sparse_categorical_accuracy: 0.8559
# Epoch 12/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3043 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.6386 - val_sparse_categorical_accuracy: 0.8548
# Epoch 13/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3218 - sparse_categorical_accuracy: 0.9048 - val_loss: 0.6416 - val_sparse_categorical_accuracy: 0.8530
# Epoch 14/50
# 10/10 [==============================] - 2s 198ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.6388 - val_sparse_categorical_accuracy: 0.8542
# Epoch 15/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.6320 - val_sparse_categorical_accuracy: 0.8554
# Epoch 16/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3005 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6249 - val_sparse_categorical_accuracy: 0.8550
# Epoch 17/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.3273 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.8583
# Epoch 18/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2708 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6254 - val_sparse_categorical_accuracy: 0.8570
# Epoch 19/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2894 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6269 - val_sparse_categorical_accuracy: 0.8587
# Epoch 20/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2848 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.6336 - val_sparse_categorical_accuracy: 0.8548
# Epoch 21/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3215 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.6286 - val_sparse_categorical_accuracy: 0.8561
# Epoch 22/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2902 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.6263 - val_sparse_categorical_accuracy: 0.8572
# Epoch 23/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3125 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.6254 - val_sparse_categorical_accuracy: 0.8583
# Epoch 24/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2817 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.6293 - val_sparse_categorical_accuracy: 0.8565
# Epoch 25/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2934 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.6231 - val_sparse_categorical_accuracy: 0.8587
# Epoch 26/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2871 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.6256 - val_sparse_categorical_accuracy: 0.8595
# Epoch 27/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2934 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.6263 - val_sparse_categorical_accuracy: 0.8597
# Epoch 28/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2946 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.6249 - val_sparse_categorical_accuracy: 0.8583
# Epoch 29/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2954 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.6211 - val_sparse_categorical_accuracy: 0.8580
# Epoch 30/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.8603
# Epoch 31/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3017 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.6176 - val_sparse_categorical_accuracy: 0.8634
# Epoch 32/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.9183 - val_loss: 0.6201 - val_sparse_categorical_accuracy: 0.8608
# Epoch 33/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3091 - sparse_categorical_accuracy: 0.9064 - val_loss: 0.6160 - val_sparse_categorical_accuracy: 0.8629
# Epoch 34/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2925 - sparse_categorical_accuracy: 0.9112 - val_loss: 0.6218 - val_sparse_categorical_accuracy: 0.8585
# Epoch 35/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3112 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.6302 - val_sparse_categorical_accuracy: 0.8560
# Epoch 36/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.6320 - val_sparse_categorical_accuracy: 0.8570
# Epoch 37/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3115 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.6242 - val_sparse_categorical_accuracy: 0.8601
# Epoch 38/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2974 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.6202 - val_sparse_categorical_accuracy: 0.8606
# Epoch 39/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2907 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.6239 - val_sparse_categorical_accuracy: 0.8599
# Epoch 40/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3144 - sparse_categorical_accuracy: 0.9050 - val_loss: 0.6219 - val_sparse_categorical_accuracy: 0.8592
# Epoch 41/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3060 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6188 - val_sparse_categorical_accuracy: 0.8634
# Epoch 42/50
# 10/10 [==============================] - 2s 206ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.6206 - val_sparse_categorical_accuracy: 0.8594
# Epoch 43/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2943 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6177 - val_sparse_categorical_accuracy: 0.8608
# Epoch 44/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.3193 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.6136 - val_sparse_categorical_accuracy: 0.8599
# Epoch 45/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3207 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.6220 - val_sparse_categorical_accuracy: 0.8605
# Epoch 46/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2979 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.6251 - val_sparse_categorical_accuracy: 0.8613
# Epoch 47/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.6217 - val_sparse_categorical_accuracy: 0.8611
# Epoch 48/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3001 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.6191 - val_sparse_categorical_accuracy: 0.8608
# Epoch 49/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.3030 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.6167 - val_sparse_categorical_accuracy: 0.8626
# Epoch 50/50
# 10/10 [==============================] - 2s 199ms/step - loss: 0.3024 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6185 - val_sparse_categorical_accuracy: 0.8614
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 10/10 [==============================] - 2s 200ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.6139 - val_sparse_categorical_accuracy: 0.8641
# Epoch 2/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2836 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6199 - val_sparse_categorical_accuracy: 0.8637
# Epoch 3/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3033 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6210 - val_sparse_categorical_accuracy: 0.8601
# Epoch 4/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6083 - val_sparse_categorical_accuracy: 0.8617
# Epoch 5/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2962 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.8648
# Epoch 6/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2889 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8616
# Epoch 7/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3000 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.6159 - val_sparse_categorical_accuracy: 0.8600
# Epoch 8/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.6135 - val_sparse_categorical_accuracy: 0.8600
# Epoch 9/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3025 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.6074 - val_sparse_categorical_accuracy: 0.8635
# Epoch 10/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3067 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.6028 - val_sparse_categorical_accuracy: 0.8629
# Epoch 11/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2979 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.6060 - val_sparse_categorical_accuracy: 0.8632
# Epoch 12/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3030 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.6061 - val_sparse_categorical_accuracy: 0.8636
# Epoch 13/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.6107 - val_sparse_categorical_accuracy: 0.8615
# Epoch 14/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3155 - sparse_categorical_accuracy: 0.9067 - val_loss: 0.6110 - val_sparse_categorical_accuracy: 0.8605
# Epoch 15/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2821 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6168 - val_sparse_categorical_accuracy: 0.8581
# Epoch 16/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2878 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6121 - val_sparse_categorical_accuracy: 0.8607
# Epoch 17/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3005 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.6080 - val_sparse_categorical_accuracy: 0.8639
# Epoch 18/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2717 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.6112 - val_sparse_categorical_accuracy: 0.8599
# Epoch 19/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2984 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.6125 - val_sparse_categorical_accuracy: 0.8587
# Epoch 20/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3111 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.6148 - val_sparse_categorical_accuracy: 0.8587
# Epoch 21/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.6196 - val_sparse_categorical_accuracy: 0.8612
# Epoch 22/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.6179 - val_sparse_categorical_accuracy: 0.8624
# Epoch 23/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6144 - val_sparse_categorical_accuracy: 0.8619
# Epoch 24/50
# 10/10 [==============================] - 2s 198ms/step - loss: 0.2939 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.6094 - val_sparse_categorical_accuracy: 0.8631
# Epoch 25/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2843 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.6058 - val_sparse_categorical_accuracy: 0.8645
# Epoch 26/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2985 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.6060 - val_sparse_categorical_accuracy: 0.8625
# Epoch 27/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8626
# Epoch 28/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3062 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8618
# Epoch 29/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3215 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.6184 - val_sparse_categorical_accuracy: 0.8589
# Epoch 30/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.6206 - val_sparse_categorical_accuracy: 0.8586
# Epoch 31/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3135 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.6148 - val_sparse_categorical_accuracy: 0.8632
# Epoch 32/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2929 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.6131 - val_sparse_categorical_accuracy: 0.8612
# Epoch 33/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3011 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.6118 - val_sparse_categorical_accuracy: 0.8609
# Epoch 34/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2904 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.6134 - val_sparse_categorical_accuracy: 0.8617
# Epoch 35/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.3077 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8603
# Epoch 36/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2859 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.6193 - val_sparse_categorical_accuracy: 0.8578
# Epoch 37/50
# 10/10 [==============================] - 2s 204ms/step - loss: 0.2878 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.6175 - val_sparse_categorical_accuracy: 0.8595
# Epoch 38/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2943 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.8587
# Epoch 39/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3069 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8610
# Epoch 40/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3073 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.6158 - val_sparse_categorical_accuracy: 0.8567
# Epoch 41/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2870 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.6113 - val_sparse_categorical_accuracy: 0.8607
# Epoch 42/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2787 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.6172 - val_sparse_categorical_accuracy: 0.8577
# Epoch 43/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3076 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.6174 - val_sparse_categorical_accuracy: 0.8587
# Epoch 44/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3025 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.8593
# Epoch 45/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3080 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.6115 - val_sparse_categorical_accuracy: 0.8613
# Epoch 46/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3044 - sparse_categorical_accuracy: 0.9088 - val_loss: 0.6117 - val_sparse_categorical_accuracy: 0.8596
# Epoch 47/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2944 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.6204 - val_sparse_categorical_accuracy: 0.8575
# Epoch 48/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3076 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.8598
# Epoch 49/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2919 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.6111 - val_sparse_categorical_accuracy: 0.8611
# Epoch 50/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.3093 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.6139 - val_sparse_categorical_accuracy: 0.8600
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2974 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.6168 - val_sparse_categorical_accuracy: 0.8579
# Epoch 2/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2847 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.6143 - val_sparse_categorical_accuracy: 0.8572
# Epoch 3/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2863 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.6062 - val_sparse_categorical_accuracy: 0.8592
# Epoch 4/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2787 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.6012 - val_sparse_categorical_accuracy: 0.8633
# Epoch 5/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3153 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.6051 - val_sparse_categorical_accuracy: 0.8610
# Epoch 6/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2998 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.6082 - val_sparse_categorical_accuracy: 0.8610
# Epoch 7/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3037 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.6103 - val_sparse_categorical_accuracy: 0.8616
# Epoch 8/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2947 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8622
# Epoch 9/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2961 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6211 - val_sparse_categorical_accuracy: 0.8590
# Epoch 10/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2917 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.6131 - val_sparse_categorical_accuracy: 0.8591
# Epoch 11/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2988 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.6009 - val_sparse_categorical_accuracy: 0.8627
# Epoch 12/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2885 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6003 - val_sparse_categorical_accuracy: 0.8638
# Epoch 13/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2979 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.6047 - val_sparse_categorical_accuracy: 0.8636
# Epoch 14/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3008 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.6097 - val_sparse_categorical_accuracy: 0.8617
# Epoch 15/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2916 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.6181 - val_sparse_categorical_accuracy: 0.8577
# Epoch 16/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3005 - sparse_categorical_accuracy: 0.9069 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8591
# Epoch 17/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2937 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.6078 - val_sparse_categorical_accuracy: 0.8606
# Epoch 18/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3061 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.6089 - val_sparse_categorical_accuracy: 0.8624
# Epoch 19/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2855 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.6037 - val_sparse_categorical_accuracy: 0.8624
# Epoch 20/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2981 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.6079 - val_sparse_categorical_accuracy: 0.8610
# Epoch 21/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2862 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.6094 - val_sparse_categorical_accuracy: 0.8597
# Epoch 22/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2982 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.6138 - val_sparse_categorical_accuracy: 0.8576
# Epoch 23/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3016 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.6071 - val_sparse_categorical_accuracy: 0.8585
# Epoch 24/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2970 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.6028 - val_sparse_categorical_accuracy: 0.8618
# Epoch 25/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2802 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.8593
# Epoch 26/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3012 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.6112 - val_sparse_categorical_accuracy: 0.8585
# Epoch 27/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2897 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6077 - val_sparse_categorical_accuracy: 0.8577
# Epoch 28/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2908 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.6135 - val_sparse_categorical_accuracy: 0.8591
# Epoch 29/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.6102 - val_sparse_categorical_accuracy: 0.8575
# Epoch 30/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2894 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.6000 - val_sparse_categorical_accuracy: 0.8589
# Epoch 31/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3087 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.6029 - val_sparse_categorical_accuracy: 0.8615
# Epoch 32/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3043 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.6085 - val_sparse_categorical_accuracy: 0.8623
# Epoch 33/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2896 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.6052 - val_sparse_categorical_accuracy: 0.8596
# Epoch 34/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3020 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.6090 - val_sparse_categorical_accuracy: 0.8589
# Epoch 35/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2823 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.6116 - val_sparse_categorical_accuracy: 0.8583
# Epoch 36/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3011 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.6060 - val_sparse_categorical_accuracy: 0.8623
# Epoch 37/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2957 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.6054 - val_sparse_categorical_accuracy: 0.8602
# Epoch 38/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2919 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6018 - val_sparse_categorical_accuracy: 0.8632
# Epoch 39/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2868 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6052 - val_sparse_categorical_accuracy: 0.8623
# Epoch 40/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2999 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.6115 - val_sparse_categorical_accuracy: 0.8590
# Epoch 41/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2774 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8586
# Epoch 42/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2897 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6111 - val_sparse_categorical_accuracy: 0.8612
# Epoch 43/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6145 - val_sparse_categorical_accuracy: 0.8615
# Epoch 44/50
# 10/10 [==============================] - 2s 202ms/step - loss: 0.2937 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6085 - val_sparse_categorical_accuracy: 0.8629
# Epoch 45/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2958 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.6123 - val_sparse_categorical_accuracy: 0.8579
# Epoch 46/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.3081 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.6122 - val_sparse_categorical_accuracy: 0.8605
# Epoch 47/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2925 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8590
# Epoch 48/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3183 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.6229 - val_sparse_categorical_accuracy: 0.8567
# Epoch 49/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.6256 - val_sparse_categorical_accuracy: 0.8577
# Epoch 50/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.8606
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.6104 - val_sparse_categorical_accuracy: 0.8589
# Epoch 2/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.6167 - val_sparse_categorical_accuracy: 0.8592
# Epoch 3/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2996 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.6193 - val_sparse_categorical_accuracy: 0.8563
# Epoch 4/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2936 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.6142 - val_sparse_categorical_accuracy: 0.8608
# Epoch 5/50
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2784 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.6174 - val_sparse_categorical_accuracy: 0.8576
# Epoch 6/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.6168 - val_sparse_categorical_accuracy: 0.8572
# Epoch 7/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2875 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.6107 - val_sparse_categorical_accuracy: 0.8593
# Epoch 8/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2875 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.6107 - val_sparse_categorical_accuracy: 0.8611
# Epoch 9/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2892 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.6073 - val_sparse_categorical_accuracy: 0.8626
# Epoch 10/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.6038 - val_sparse_categorical_accuracy: 0.8643
# Epoch 11/50
# 10/10 [==============================] - 2s 185ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.6047 - val_sparse_categorical_accuracy: 0.8622
# Epoch 12/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2819 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.6046 - val_sparse_categorical_accuracy: 0.8631
# Epoch 13/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2884 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.6042 - val_sparse_categorical_accuracy: 0.8620
# Epoch 14/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2973 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.6134 - val_sparse_categorical_accuracy: 0.8609
# Epoch 15/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2969 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.6195 - val_sparse_categorical_accuracy: 0.8559
# Epoch 16/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2886 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.6205 - val_sparse_categorical_accuracy: 0.8582
# Epoch 17/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2976 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8609
# Epoch 18/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3009 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.8591
# Epoch 19/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2886 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6163 - val_sparse_categorical_accuracy: 0.8588
# Epoch 20/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.2900 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.6141 - val_sparse_categorical_accuracy: 0.8582
# Epoch 21/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9166 - val_loss: 0.6211 - val_sparse_categorical_accuracy: 0.8585
# Epoch 22/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2837 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.6238 - val_sparse_categorical_accuracy: 0.8582
# Epoch 23/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2921 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.6206 - val_sparse_categorical_accuracy: 0.8587
# Epoch 24/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3017 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.6160 - val_sparse_categorical_accuracy: 0.8577
# Epoch 25/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.9073 - val_loss: 0.6136 - val_sparse_categorical_accuracy: 0.8603
# Epoch 26/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3073 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.6126 - val_sparse_categorical_accuracy: 0.8626
# Epoch 27/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.3058 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.6209 - val_sparse_categorical_accuracy: 0.8596
# Epoch 28/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3071 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.6202 - val_sparse_categorical_accuracy: 0.8577
# Epoch 29/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3108 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8626
# Epoch 30/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2913 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.6227 - val_sparse_categorical_accuracy: 0.8608
# Epoch 31/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.3082 - sparse_categorical_accuracy: 0.9073 - val_loss: 0.6275 - val_sparse_categorical_accuracy: 0.8553
# Epoch 32/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2834 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.6230 - val_sparse_categorical_accuracy: 0.8580
# Epoch 33/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2804 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.8581
# Epoch 34/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2899 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.6103 - val_sparse_categorical_accuracy: 0.8616
# Epoch 35/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8575
# Epoch 36/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2861 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.6152 - val_sparse_categorical_accuracy: 0.8606
# Epoch 37/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.6213 - val_sparse_categorical_accuracy: 0.8575
# Epoch 38/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3144 - sparse_categorical_accuracy: 0.9097 - val_loss: 0.6209 - val_sparse_categorical_accuracy: 0.8604
# Epoch 39/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.8618
# Epoch 40/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2890 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.6133 - val_sparse_categorical_accuracy: 0.8594
# Epoch 41/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2911 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.6203 - val_sparse_categorical_accuracy: 0.8586
# Epoch 42/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2931 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.6143 - val_sparse_categorical_accuracy: 0.8601
# Epoch 43/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.3022 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8583
# Epoch 44/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2803 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6100 - val_sparse_categorical_accuracy: 0.8578
# Epoch 45/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2837 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.6047 - val_sparse_categorical_accuracy: 0.8595
# Epoch 46/50
# 10/10 [==============================] - 2s 204ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.6075 - val_sparse_categorical_accuracy: 0.8591
# Epoch 47/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6109 - val_sparse_categorical_accuracy: 0.8641
# Epoch 48/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.6106 - val_sparse_categorical_accuracy: 0.8609
# Epoch 49/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3019 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.6209 - val_sparse_categorical_accuracy: 0.8569
# Epoch 50/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.3024 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.6135 - val_sparse_categorical_accuracy: 0.8604
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 10/10 [==============================] - 2s 199ms/step - loss: 0.2998 - sparse_categorical_accuracy: 0.9073 - val_loss: 0.6164 - val_sparse_categorical_accuracy: 0.8581
# Epoch 2/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2948 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.8577
# Epoch 3/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3046 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.6172 - val_sparse_categorical_accuracy: 0.8567
# Epoch 4/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2864 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.6185 - val_sparse_categorical_accuracy: 0.8582
# Epoch 5/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2954 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.6232 - val_sparse_categorical_accuracy: 0.8579
# Epoch 6/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2910 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.6234 - val_sparse_categorical_accuracy: 0.8582
# Epoch 7/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.9086 - val_loss: 0.6117 - val_sparse_categorical_accuracy: 0.8598
# Epoch 8/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2904 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.6088 - val_sparse_categorical_accuracy: 0.8609
# Epoch 9/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2901 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8588
# Epoch 10/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8569
# Epoch 11/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2906 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.6145 - val_sparse_categorical_accuracy: 0.8617
# Epoch 12/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.6144 - val_sparse_categorical_accuracy: 0.8617
# Epoch 13/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2945 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.6193 - val_sparse_categorical_accuracy: 0.8595
# Epoch 14/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.6217 - val_sparse_categorical_accuracy: 0.8600
# Epoch 15/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.6133 - val_sparse_categorical_accuracy: 0.8605
# Epoch 16/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2936 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.6170 - val_sparse_categorical_accuracy: 0.8598
# Epoch 17/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2966 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.6166 - val_sparse_categorical_accuracy: 0.8598
# Epoch 18/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3038 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.6104 - val_sparse_categorical_accuracy: 0.8623
# Epoch 19/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2787 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6078 - val_sparse_categorical_accuracy: 0.8626
# Epoch 20/50
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2899 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.6032 - val_sparse_categorical_accuracy: 0.8640
# Epoch 21/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2858 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.6097 - val_sparse_categorical_accuracy: 0.8589
# Epoch 22/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.9162 - val_loss: 0.6087 - val_sparse_categorical_accuracy: 0.8610
# Epoch 23/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3006 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.6050 - val_sparse_categorical_accuracy: 0.8624
# Epoch 24/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.2939 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6043 - val_sparse_categorical_accuracy: 0.8633
# Epoch 25/50
# 10/10 [==============================] - 2s 188ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.6148 - val_sparse_categorical_accuracy: 0.8588
# Epoch 26/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2980 - sparse_categorical_accuracy: 0.9110 - val_loss: 0.6115 - val_sparse_categorical_accuracy: 0.8593
# Epoch 27/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.6127 - val_sparse_categorical_accuracy: 0.8618
# Epoch 28/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3110 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.5994 - val_sparse_categorical_accuracy: 0.8628
# Epoch 29/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2900 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.6014 - val_sparse_categorical_accuracy: 0.8630
# Epoch 30/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2849 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6031 - val_sparse_categorical_accuracy: 0.8639
# Epoch 31/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6131 - val_sparse_categorical_accuracy: 0.8585
# Epoch 32/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2778 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.6208 - val_sparse_categorical_accuracy: 0.8584
# Epoch 33/50
# 10/10 [==============================] - 2s 197ms/step - loss: 0.2985 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.6177 - val_sparse_categorical_accuracy: 0.8605
# Epoch 34/50
# 10/10 [==============================] - 2s 198ms/step - loss: 0.2881 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.8592
# Epoch 35/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.2986 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.6171 - val_sparse_categorical_accuracy: 0.8606
# Epoch 36/50
# 10/10 [==============================] - 2s 199ms/step - loss: 0.2757 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.6189 - val_sparse_categorical_accuracy: 0.8581
# Epoch 37/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2927 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.6117 - val_sparse_categorical_accuracy: 0.8575
# Epoch 38/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3054 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.6068 - val_sparse_categorical_accuracy: 0.8611
# Epoch 39/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.6071 - val_sparse_categorical_accuracy: 0.8607
# Epoch 40/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.2881 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.6106 - val_sparse_categorical_accuracy: 0.8600
# Epoch 41/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3081 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.6178 - val_sparse_categorical_accuracy: 0.8554
# Epoch 42/50
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2827 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.6171 - val_sparse_categorical_accuracy: 0.8587
# Epoch 43/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.6119 - val_sparse_categorical_accuracy: 0.8584
# Epoch 44/50
# 10/10 [==============================] - 2s 189ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.8568
# Epoch 45/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3011 - sparse_categorical_accuracy: 0.9156 - val_loss: 0.6215 - val_sparse_categorical_accuracy: 0.8560
# Epoch 46/50
# 10/10 [==============================] - 2s 191ms/step - loss: 0.2808 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.6217 - val_sparse_categorical_accuracy: 0.8581
# Epoch 47/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2969 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.6027 - val_sparse_categorical_accuracy: 0.8626
# Epoch 48/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.6009 - val_sparse_categorical_accuracy: 0.8630
# Epoch 49/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3111 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.6120 - val_sparse_categorical_accuracy: 0.8583
# Epoch 50/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.3057 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.6107 - val_sparse_categorical_accuracy: 0.8596
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.6145 - val_sparse_categorical_accuracy: 0.8587
# Epoch 2/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2853 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.6090 - val_sparse_categorical_accuracy: 0.8614
# Epoch 3/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2949 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.6051 - val_sparse_categorical_accuracy: 0.8603
# Epoch 4/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.9138 - val_loss: 0.6103 - val_sparse_categorical_accuracy: 0.8602
# Epoch 5/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.6072 - val_sparse_categorical_accuracy: 0.8608
# Epoch 6/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3002 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.6023 - val_sparse_categorical_accuracy: 0.8620
# Epoch 7/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.6000 - val_sparse_categorical_accuracy: 0.8611
# Epoch 8/50
# 10/10 [==============================] - 2s 193ms/step - loss: 0.2920 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.5998 - val_sparse_categorical_accuracy: 0.8633
# Epoch 9/50
# 10/10 [==============================] - 2s 196ms/step - loss: 0.2814 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.6079 - val_sparse_categorical_accuracy: 0.8622
# Epoch 10/50
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2944 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.6198 - val_sparse_categorical_accuracy: 0.8577
# Epoch 11/50
# 10/10 [==============================] - 2s 190ms/step - loss: 0.2948 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.6111 - val_sparse_categorical_accuracy: 0.8595
# Epoch 12/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2895 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8620
# Epoch 13/50
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2684 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.6158 - val_sparse_categorical_accuracy: 0.8609
# Epoch 14/50
# ...
# Epoch 13/50
# 10/10 [==============================] - 2s 210ms/step - loss: 0.2530 - sparse_categorical_accuracy: 0.9208 - val_loss: 0.6177 - val_sparse_categorical_accuracy: 0.8635
# Epoch 14/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.6139 - val_sparse_categorical_accuracy: 0.8634
# Epoch 15/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2796 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.6122 - val_sparse_categorical_accuracy: 0.8611
# Epoch 16/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2634 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.6161 - val_sparse_categorical_accuracy: 0.8612
# Epoch 17/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2734 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.6078 - val_sparse_categorical_accuracy: 0.8651
# Epoch 18/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2965 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.6096 - val_sparse_categorical_accuracy: 0.8602
# Epoch 19/50
# 10/10 [==============================] - 2s 209ms/step - loss: 0.2662 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.6091 - val_sparse_categorical_accuracy: 0.8590
# Epoch 20/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2649 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.6152 - val_sparse_categorical_accuracy: 0.8571
# Epoch 21/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2714 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.6225 - val_sparse_categorical_accuracy: 0.8596
# Epoch 22/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2736 - sparse_categorical_accuracy: 0.9171 - val_loss: 0.6256 - val_sparse_categorical_accuracy: 0.8583
# Epoch 23/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2804 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.6321 - val_sparse_categorical_accuracy: 0.8578
# Epoch 24/50
# 10/10 [==============================] - 2s 220ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.6231 - val_sparse_categorical_accuracy: 0.8581
# Epoch 25/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.6216 - val_sparse_categorical_accuracy: 0.8602
# Epoch 26/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2695 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.6252 - val_sparse_categorical_accuracy: 0.8571
# Epoch 27/50
# 10/10 [==============================] - 2s 211ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.6230 - val_sparse_categorical_accuracy: 0.8581
# Epoch 28/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.9221 - val_loss: 0.6238 - val_sparse_categorical_accuracy: 0.8560
# Epoch 29/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2859 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.6265 - val_sparse_categorical_accuracy: 0.8588
# Epoch 30/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2794 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.6169 - val_sparse_categorical_accuracy: 0.8588
# Epoch 31/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2935 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.8625
# Epoch 32/50
# 10/10 [==============================] - 2s 210ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.6189 - val_sparse_categorical_accuracy: 0.8597
# Epoch 33/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2809 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.6205 - val_sparse_categorical_accuracy: 0.8608
# Epoch 34/50
# 10/10 [==============================] - 2s 221ms/step - loss: 0.2732 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6280 - val_sparse_categorical_accuracy: 0.8591
# Epoch 35/50
# 10/10 [==============================] - 2s 220ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.6204 - val_sparse_categorical_accuracy: 0.8590
# Epoch 36/50
# 10/10 [==============================] - 2s 210ms/step - loss: 0.2705 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.6202 - val_sparse_categorical_accuracy: 0.8604
# Epoch 37/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.6250 - val_sparse_categorical_accuracy: 0.8580
# Epoch 38/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2725 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6261 - val_sparse_categorical_accuracy: 0.8571
# Epoch 39/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2643 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.6187 - val_sparse_categorical_accuracy: 0.8599
# Epoch 40/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2743 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.6077 - val_sparse_categorical_accuracy: 0.8616
# Epoch 41/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2707 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.6086 - val_sparse_categorical_accuracy: 0.8629
# Epoch 42/50
# 10/10 [==============================] - 2s 211ms/step - loss: 0.2829 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.6123 - val_sparse_categorical_accuracy: 0.8601
# Epoch 43/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2970 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.6260 - val_sparse_categorical_accuracy: 0.8583
# Epoch 44/50
# 10/10 [==============================] - 2s 225ms/step - loss: 0.2672 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.6285 - val_sparse_categorical_accuracy: 0.8584
# Epoch 45/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2653 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.6216 - val_sparse_categorical_accuracy: 0.8581
# Epoch 46/50
# 10/10 [==============================] - 2s 211ms/step - loss: 0.2526 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.6196 - val_sparse_categorical_accuracy: 0.8603
# Epoch 47/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2661 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.6200 - val_sparse_categorical_accuracy: 0.8577
# Epoch 48/50
# 10/10 [==============================] - 2s 209ms/step - loss: 0.2670 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.6193 - val_sparse_categorical_accuracy: 0.8584
# Epoch 49/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2620 - sparse_categorical_accuracy: 0.9226 - val_loss: 0.6166 - val_sparse_categorical_accuracy: 0.8595
# Epoch 50/50
# 10/10 [==============================] - 2s 207ms/step - loss: 0.2604 - sparse_categorical_accuracy: 0.9248 - val_loss: 0.6194 - val_sparse_categorical_accuracy: 0.8590
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2673 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.6245 - val_sparse_categorical_accuracy: 0.8604
# Epoch 2/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2746 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.6309 - val_sparse_categorical_accuracy: 0.8591
# Epoch 3/50
# 10/10 [==============================] - 2s 218ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.6256 - val_sparse_categorical_accuracy: 0.8585
# Epoch 4/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2785 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.6180 - val_sparse_categorical_accuracy: 0.8600
# Epoch 5/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2857 - sparse_categorical_accuracy: 0.9163 - val_loss: 0.6109 - val_sparse_categorical_accuracy: 0.8638
# Epoch 6/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2714 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.6205 - val_sparse_categorical_accuracy: 0.8593
# Epoch 7/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.6215 - val_sparse_categorical_accuracy: 0.8578
# Epoch 8/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2694 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.6227 - val_sparse_categorical_accuracy: 0.8599
# Epoch 9/50
# 10/10 [==============================] - 2s 221ms/step - loss: 0.2863 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.6208 - val_sparse_categorical_accuracy: 0.8581
# Epoch 10/50
# 10/10 [==============================] - 2s 218ms/step - loss: 0.2672 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.6234 - val_sparse_categorical_accuracy: 0.8572
# Epoch 11/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.6259 - val_sparse_categorical_accuracy: 0.8583
# Epoch 12/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2687 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.6271 - val_sparse_categorical_accuracy: 0.8580
# Epoch 13/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.6230 - val_sparse_categorical_accuracy: 0.8560
# Epoch 14/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2770 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.6183 - val_sparse_categorical_accuracy: 0.8581
# Epoch 15/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2687 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.6157 - val_sparse_categorical_accuracy: 0.8594
# Epoch 16/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.6241 - val_sparse_categorical_accuracy: 0.8563
# Epoch 17/50
# 10/10 [==============================] - 2s 210ms/step - loss: 0.2683 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.6276 - val_sparse_categorical_accuracy: 0.8578
# Epoch 18/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.6327 - val_sparse_categorical_accuracy: 0.8536
# Epoch 19/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2807 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.6393 - val_sparse_categorical_accuracy: 0.8528
# Epoch 20/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2726 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.6400 - val_sparse_categorical_accuracy: 0.8553
# Epoch 21/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2688 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.6283 - val_sparse_categorical_accuracy: 0.8584
# Epoch 22/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2643 - sparse_categorical_accuracy: 0.9241 - val_loss: 0.6170 - val_sparse_categorical_accuracy: 0.8551
# Epoch 23/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2603 - sparse_categorical_accuracy: 0.9241 - val_loss: 0.6197 - val_sparse_categorical_accuracy: 0.8572
# Epoch 24/50
# 10/10 [==============================] - 2s 211ms/step - loss: 0.2702 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.6242 - val_sparse_categorical_accuracy: 0.8574
# Epoch 25/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2652 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.6216 - val_sparse_categorical_accuracy: 0.8605
# Epoch 26/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2861 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.6271 - val_sparse_categorical_accuracy: 0.8622
# Epoch 27/50
# 10/10 [==============================] - 2s 218ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.6227 - val_sparse_categorical_accuracy: 0.8608
# Epoch 28/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2817 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.6205 - val_sparse_categorical_accuracy: 0.8597
# Epoch 29/50
# 10/10 [==============================] - 2s 218ms/step - loss: 0.2730 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.6196 - val_sparse_categorical_accuracy: 0.8594
# Epoch 30/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2791 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.6190 - val_sparse_categorical_accuracy: 0.8583
# Epoch 31/50
# 10/10 [==============================] - 2s 216ms/step - loss: 0.2648 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.6185 - val_sparse_categorical_accuracy: 0.8543
# Epoch 32/50
# 10/10 [==============================] - 2s 218ms/step - loss: 0.2481 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.6167 - val_sparse_categorical_accuracy: 0.8568
# Epoch 33/50
# 10/10 [==============================] - 2s 215ms/step - loss: 0.2723 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.6190 - val_sparse_categorical_accuracy: 0.8572
# Epoch 34/50
# 10/10 [==============================] - 2s 219ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.6155 - val_sparse_categorical_accuracy: 0.8580
# Epoch 35/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2782 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.6122 - val_sparse_categorical_accuracy: 0.8613
# Epoch 36/50
# 10/10 [==============================] - 2s 221ms/step - loss: 0.2635 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.6200 - val_sparse_categorical_accuracy: 0.8582
# Epoch 37/50
# 10/10 [==============================] - 2s 220ms/step - loss: 0.2714 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.6258 - val_sparse_categorical_accuracy: 0.8567
# Epoch 38/50
# 10/10 [==============================] - 2s 228ms/step - loss: 0.2617 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.6233 - val_sparse_categorical_accuracy: 0.8588
# Epoch 39/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9197 - val_loss: 0.6230 - val_sparse_categorical_accuracy: 0.8586
# Epoch 40/50
# 10/10 [==============================] - 2s 220ms/step - loss: 0.2678 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.6222 - val_sparse_categorical_accuracy: 0.8584
# Epoch 41/50
# 10/10 [==============================] - 2s 222ms/step - loss: 0.2648 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.6156 - val_sparse_categorical_accuracy: 0.8613
# Epoch 42/50
# 10/10 [==============================] - 2s 222ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.8620
# Epoch 43/50
# 10/10 [==============================] - 2s 217ms/step - loss: 0.2691 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.6279 - val_sparse_categorical_accuracy: 0.8587
# Epoch 44/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.8614
# Epoch 45/50
# 10/10 [==============================] - 2s 221ms/step - loss: 0.2905 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.6147 - val_sparse_categorical_accuracy: 0.8604
# Epoch 46/50
# 10/10 [==============================] - 2s 213ms/step - loss: 0.2908 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.6137 - val_sparse_categorical_accuracy: 0.8620
# Epoch 47/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2809 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.6152 - val_sparse_categorical_accuracy: 0.8606
# Epoch 48/50
# 10/10 [==============================] - 2s 212ms/step - loss: 0.2772 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.6218 - val_sparse_categorical_accuracy: 0.8594
# Epoch 49/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2757 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.6306 - val_sparse_categorical_accuracy: 0.8554
# Epoch 50/50
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.6330 - val_sparse_categorical_accuracy: 0.8551

# %%
print (training_history1)
# Out:
# {0.0: <tensorflow.python.keras.callbacks.History object at 0x7f24d9043240>, 0.5: <tensorflow.python.keras.callbacks.History object at 0x7f24df064940>, 1.0: <tensorflow.python.keras.callbacks.History object at 0x7f24da8ed438>, 1.5: <tensorflow.python.keras.callbacks.History object at 0x7f24d9cb2518>, 2.0: <tensorflow.python.keras.callbacks.History object at 0x7f24da1c82e8>, 2.5: <tensorflow.python.keras.callbacks.History object at 0x7f24dba58780>, 3.0: <tensorflow.python.keras.callbacks.History object at 0x7f24db68fe48>, 3.5: <tensorflow.python.keras.callbacks.History object at 0x7f24d9ee16d8>, 4.0: <tensorflow.python.keras.callbacks.History object at 0x7f24dc690908>, 4.5: <tensorflow.python.keras.callbacks.History object at 0x7f24d9ae7b38>, 5.0: <tensorflow.python.keras.callbacks.History object at 0x7f24daad9630>, 5.5: <tensorflow.python.keras.callbacks.History object at 0x7f24d9a4fcc0>, 6.0: <tensorflow.python.keras.callbacks.History object at 0x7f24dfa5e198>, 6.5: <tensorflow.python.keras.callbacks.History object at 0x7f24d9e22c50>, 7.0: <tensorflow.python.keras.callbacks.History object at 0x7f24db886f60>, 7.5: <tensorflow.python.keras.callbacks.History object at 0x7f24dc0d2518>, 8.0: <tensorflow.python.keras.callbacks.History object at 0x7f24dc0855f8>, 8.5: <tensorflow.python.keras.callbacks.History object at 0x7f24da1c8898>, 9.0: <tensorflow.python.keras.callbacks.History object at 0x7f24db743a20>, 9.5: <tensorflow.python.keras.callbacks.History object at 0x7f24da8ed0f0>}

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 2
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
#ber_iteration = 2
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.19820  BER: 0.05557
# SNR: 0.500:
#  ->BLER: 0.14960  BER: 0.03973
# SNR: 1.000:
#  ->BLER: 0.10480  BER: 0.02764
# SNR: 1.500:
#  ->BLER: 0.06920  BER: 0.01772
# SNR: 2.000:
#  ->BLER: 0.04120  BER: 0.01071
# SNR: 2.500:
#  ->BLER: 0.02700  BER: 0.00683
# SNR: 3.000:
#  ->BLER: 0.01480  BER: 0.00398
# SNR: 3.500:
#  ->BLER: 0.00820  BER: 0.00201
# SNR: 4.000:
#  ->BLER: 0.00420  BER: 0.00098
# SNR: 4.500:
#  ->BLER: 0.00160  BER: 0.00040
# SNR: 5.000:
#  ->BLER: 0.00140  BER: 0.00030
# SNR: 5.500:
#  ->BLER: 0.00100  BER: 0.00027
# SNR: 6.000:
#  ->BLER: 0.00040  BER: 0.00010
# SNR: 6.500:
#  ->BLER: 0.00020  BER: 0.00003
# SNR: 7.000:
#  ->BLER: 0.00020  BER: 0.00005
# SNR: 7.500:
#  ->BLER: 0.00000  BER: 0.00000
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor1)
print (bler_per_iter_dl_tensor1)
# Out:
# (5000, 2, 1024)
# SNR: 0.000:-> BLER: 0.19520 BER: 0.05456
# total_bit_error: 5456
# total_msg_error: 976
# SNR: 0.500:-> BLER: 0.14720 BER: 0.04042
# total_bit_error: 4042
# total_msg_error: 736
# SNR: 1.000:-> BLER: 0.10060 BER: 0.02664
# total_bit_error: 2664
# total_msg_error: 503
# SNR: 1.500:-> BLER: 0.06300 BER: 0.01628
# total_bit_error: 1628
# total_msg_error: 315
# SNR: 2.000:-> BLER: 0.04700 BER: 0.01212
# total_bit_error: 1212
# total_msg_error: 235
# SNR: 2.500:-> BLER: 0.02480 BER: 0.00630
# total_bit_error: 630
# total_msg_error: 124
# SNR: 3.000:-> BLER: 0.01540 BER: 0.00396
# total_bit_error: 396
# total_msg_error: 77
# SNR: 3.500:-> BLER: 0.00960 BER: 0.00225
# total_bit_error: 225
# total_msg_error: 48
# SNR: 4.000:-> BLER: 0.00460 BER: 0.00130
# total_bit_error: 130
# total_msg_error: 23
# SNR: 4.500:-> BLER: 0.00320 BER: 0.00075
# total_bit_error: 75
# total_msg_error: 16
# SNR: 5.000:-> BLER: 0.00160 BER: 0.00037
# total_bit_error: 37
# total_msg_error: 8
# SNR: 5.500:-> BLER: 0.00060 BER: 0.00012
# total_bit_error: 12
# total_msg_error: 3
# SNR: 6.000:-> BLER: 0.00020 BER: 0.00005
# total_bit_error: 5
# total_msg_error: 1
# SNR: 6.500:-> BLER: 0.00020 BER: 0.00004
# total_bit_error: 4
# total_msg_error: 1
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [5.456e-02 4.042e-02 2.664e-02 1.628e-02 1.212e-02 6.300e-03 3.960e-03
#  2.250e-03 1.300e-03 7.500e-04 3.700e-04 1.200e-04 5.000e-05 4.000e-05
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# [0.1952 0.1472 0.1006 0.063  0.047  0.0248 0.0154 0.0096 0.0046 0.0032
#  0.0016 0.0006 0.0002 0.0002 0.     0.     0.     0.     0.     0.    ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(10x2_40_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(10x2_40_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(10x2_40_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(10x2_40_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 6.322856
