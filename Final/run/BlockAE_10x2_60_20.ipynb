# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Final/run/BlockAE_10x2_60_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise
from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 5
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 30
channel_size = 10


NUM_OF_INPUT_MESSAGE = 10000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)
train_batch_size = 500
input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))
encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 32)]      0
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 64)           0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 30)           1950        tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 20)           620         enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_4 (TFOpLambda)   (None, 20)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_3 (TFOpLamb ()                   0           tf.math.square_4[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_4 (TFOpLambda)     ()                   0           tf.math.reduce_mean_3[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_4 (TFOpLambda)  (None, 20)           0           enc_layer2[0][0]
#                                                                  tf.math.sqrt_4[0][0]
# ==================================================================================================
# Total params: 2,570
# Trainable params: 2,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 64)                1344
# _________________________________________________________________
# tf.reshape_10 (TFOpLambda)   (None, 2, 32)             0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 32)             1056
# =================================================================
# Total params: 2,400
# Trainable params: 2,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_12 (Functional)        (None, 20)                2570
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_13 (Functional)        (None, 2, 32)             2400
# =================================================================
# Total params: 4,970
# Trainable params: 4,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 20/20 [==============================] - 1s 15ms/step - loss: 3.5580 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.3877 - val_sparse_categorical_accuracy: 0.0890
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3659 - sparse_categorical_accuracy: 0.0952 - val_loss: 3.2337 - val_sparse_categorical_accuracy: 0.2472
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2301 - sparse_categorical_accuracy: 0.1909 - val_loss: 3.1009 - val_sparse_categorical_accuracy: 0.3962
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1109 - sparse_categorical_accuracy: 0.2885 - val_loss: 2.9745 - val_sparse_categorical_accuracy: 0.5253
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9991 - sparse_categorical_accuracy: 0.3694 - val_loss: 2.8481 - val_sparse_categorical_accuracy: 0.6367
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.8874 - sparse_categorical_accuracy: 0.4276 - val_loss: 2.7200 - val_sparse_categorical_accuracy: 0.7081
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.7783 - sparse_categorical_accuracy: 0.4753 - val_loss: 2.5910 - val_sparse_categorical_accuracy: 0.7592
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 2.6728 - sparse_categorical_accuracy: 0.5036 - val_loss: 2.4620 - val_sparse_categorical_accuracy: 0.8076
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5643 - sparse_categorical_accuracy: 0.5290 - val_loss: 2.3329 - val_sparse_categorical_accuracy: 0.8371
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4689 - sparse_categorical_accuracy: 0.5505 - val_loss: 2.2058 - val_sparse_categorical_accuracy: 0.8541
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3757 - sparse_categorical_accuracy: 0.5636 - val_loss: 2.0814 - val_sparse_categorical_accuracy: 0.8773
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 2.2771 - sparse_categorical_accuracy: 0.5824 - val_loss: 1.9600 - val_sparse_categorical_accuracy: 0.8954
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1895 - sparse_categorical_accuracy: 0.5996 - val_loss: 1.8430 - val_sparse_categorical_accuracy: 0.9083
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 2.0987 - sparse_categorical_accuracy: 0.6113 - val_loss: 1.7299 - val_sparse_categorical_accuracy: 0.9230
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 2.0207 - sparse_categorical_accuracy: 0.6277 - val_loss: 1.6209 - val_sparse_categorical_accuracy: 0.9342
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9443 - sparse_categorical_accuracy: 0.6389 - val_loss: 1.5171 - val_sparse_categorical_accuracy: 0.9465
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8748 - sparse_categorical_accuracy: 0.6470 - val_loss: 1.4169 - val_sparse_categorical_accuracy: 0.9527
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.7979 - sparse_categorical_accuracy: 0.6703 - val_loss: 1.3187 - val_sparse_categorical_accuracy: 0.9592
# Epoch 19/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.7335 - sparse_categorical_accuracy: 0.6808 - val_loss: 1.2276 - val_sparse_categorical_accuracy: 0.9649
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.6672 - sparse_categorical_accuracy: 0.6857 - val_loss: 1.1382 - val_sparse_categorical_accuracy: 0.9786
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.6935 - val_loss: 1.0530 - val_sparse_categorical_accuracy: 0.9864
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5545 - sparse_categorical_accuracy: 0.7002 - val_loss: 0.9736 - val_sparse_categorical_accuracy: 0.9926
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4992 - sparse_categorical_accuracy: 0.7130 - val_loss: 0.8982 - val_sparse_categorical_accuracy: 0.9966
# Epoch 24/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.4384 - sparse_categorical_accuracy: 0.7270 - val_loss: 0.8270 - val_sparse_categorical_accuracy: 0.9995
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3961 - sparse_categorical_accuracy: 0.7307 - val_loss: 0.7605 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3442 - sparse_categorical_accuracy: 0.7349 - val_loss: 0.6990 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3119 - sparse_categorical_accuracy: 0.7379 - val_loss: 0.6433 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.2669 - sparse_categorical_accuracy: 0.7462 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.2323 - sparse_categorical_accuracy: 0.7541 - val_loss: 0.5422 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1980 - sparse_categorical_accuracy: 0.7508 - val_loss: 0.4989 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1603 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.4585 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1361 - sparse_categorical_accuracy: 0.7521 - val_loss: 0.4215 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0962 - sparse_categorical_accuracy: 0.7634 - val_loss: 0.3888 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0677 - sparse_categorical_accuracy: 0.7714 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0498 - sparse_categorical_accuracy: 0.7659 - val_loss: 0.3303 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0485 - sparse_categorical_accuracy: 0.7641 - val_loss: 0.3048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0040 - sparse_categorical_accuracy: 0.7696 - val_loss: 0.2819 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9858 - sparse_categorical_accuracy: 0.7710 - val_loss: 0.2615 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.9588 - sparse_categorical_accuracy: 0.7727 - val_loss: 0.2424 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9472 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.2245 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9308 - sparse_categorical_accuracy: 0.7771 - val_loss: 0.2088 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9144 - sparse_categorical_accuracy: 0.7762 - val_loss: 0.1949 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9103 - sparse_categorical_accuracy: 0.7710 - val_loss: 0.1819 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8920 - sparse_categorical_accuracy: 0.7781 - val_loss: 0.1696 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8766 - sparse_categorical_accuracy: 0.7777 - val_loss: 0.1590 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.8769 - sparse_categorical_accuracy: 0.7766 - val_loss: 0.1492 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8510 - sparse_categorical_accuracy: 0.7825 - val_loss: 0.1398 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.8402 - sparse_categorical_accuracy: 0.7850 - val_loss: 0.1314 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8388 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.1234 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8200 - sparse_categorical_accuracy: 0.7841 - val_loss: 0.1162 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.8149 - sparse_categorical_accuracy: 0.7864 - val_loss: 0.1096 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.7864 - val_loss: 0.1032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.7815 - val_loss: 0.0975 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7997 - sparse_categorical_accuracy: 0.7814 - val_loss: 0.0923 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7888 - sparse_categorical_accuracy: 0.7862 - val_loss: 0.0878 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7793 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.7861 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7732 - sparse_categorical_accuracy: 0.7851 - val_loss: 0.0751 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7781 - sparse_categorical_accuracy: 0.7835 - val_loss: 0.0715 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7644 - sparse_categorical_accuracy: 0.7843 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7676 - sparse_categorical_accuracy: 0.7819 - val_loss: 0.0654 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.7530 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7451 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.0592 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7361 - sparse_categorical_accuracy: 0.7882 - val_loss: 0.0567 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7407 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.7862 - val_loss: 0.0519 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7406 - sparse_categorical_accuracy: 0.7843 - val_loss: 0.0498 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7295 - sparse_categorical_accuracy: 0.7851 - val_loss: 0.0478 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7148 - sparse_categorical_accuracy: 0.7920 - val_loss: 0.0458 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7256 - sparse_categorical_accuracy: 0.7885 - val_loss: 0.0440 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7178 - sparse_categorical_accuracy: 0.7890 - val_loss: 0.0425 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7110 - sparse_categorical_accuracy: 0.7905 - val_loss: 0.0409 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.7130 - sparse_categorical_accuracy: 0.7909 - val_loss: 0.0392 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7082 - sparse_categorical_accuracy: 0.7927 - val_loss: 0.0378 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7014 - sparse_categorical_accuracy: 0.7918 - val_loss: 0.0364 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7111 - sparse_categorical_accuracy: 0.7904 - val_loss: 0.0352 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6997 - sparse_categorical_accuracy: 0.7930 - val_loss: 0.0338 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6960 - sparse_categorical_accuracy: 0.7915 - val_loss: 0.0327 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7010 - sparse_categorical_accuracy: 0.7918 - val_loss: 0.0315 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6942 - sparse_categorical_accuracy: 0.7887 - val_loss: 0.0304 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7055 - sparse_categorical_accuracy: 0.7861 - val_loss: 0.0296 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6811 - sparse_categorical_accuracy: 0.7980 - val_loss: 0.0286 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.7890 - val_loss: 0.0277 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6833 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.0267 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6766 - sparse_categorical_accuracy: 0.7991 - val_loss: 0.0259 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6855 - sparse_categorical_accuracy: 0.7926 - val_loss: 0.0251 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6799 - sparse_categorical_accuracy: 0.7933 - val_loss: 0.0244 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6808 - sparse_categorical_accuracy: 0.7945 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6822 - sparse_categorical_accuracy: 0.7927 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6673 - sparse_categorical_accuracy: 0.7984 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6781 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6826 - sparse_categorical_accuracy: 0.7948 - val_loss: 0.0210 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6796 - sparse_categorical_accuracy: 0.7940 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6805 - sparse_categorical_accuracy: 0.7923 - val_loss: 0.0199 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6690 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6649 - sparse_categorical_accuracy: 0.7954 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6591 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6680 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6614 - sparse_categorical_accuracy: 0.7956 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6635 - sparse_categorical_accuracy: 0.7952 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6576 - sparse_categorical_accuracy: 0.7958 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6697 - sparse_categorical_accuracy: 0.7958 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6675 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6463 - sparse_categorical_accuracy: 0.7986 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6589 - sparse_categorical_accuracy: 0.7980 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6500 - sparse_categorical_accuracy: 0.7994 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6515 - sparse_categorical_accuracy: 0.7994 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6562 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6545 - sparse_categorical_accuracy: 0.7991 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6446 - sparse_categorical_accuracy: 0.8013 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6444 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6500 - sparse_categorical_accuracy: 0.8016 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6461 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6477 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6440 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6341 - sparse_categorical_accuracy: 0.8019 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6469 - sparse_categorical_accuracy: 0.7991 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6345 - sparse_categorical_accuracy: 0.8027 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6466 - sparse_categorical_accuracy: 0.7980 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6446 - sparse_categorical_accuracy: 0.8001 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6346 - sparse_categorical_accuracy: 0.8026 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6365 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6333 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6391 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6407 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6332 - sparse_categorical_accuracy: 0.8023 - val_loss: 0.0097 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6235 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.0095 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6374 - sparse_categorical_accuracy: 0.8011 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6301 - sparse_categorical_accuracy: 0.8054 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6300 - sparse_categorical_accuracy: 0.8048 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6324 - sparse_categorical_accuracy: 0.8041 - val_loss: 0.0090 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6368 - sparse_categorical_accuracy: 0.8023 - val_loss: 0.0088 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6352 - sparse_categorical_accuracy: 0.8041 - val_loss: 0.0086 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6293 - sparse_categorical_accuracy: 0.8027 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6123 - sparse_categorical_accuracy: 0.8080 - val_loss: 0.0084 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6183 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.0083 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6191 - sparse_categorical_accuracy: 0.8062 - val_loss: 0.0081 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6198 - sparse_categorical_accuracy: 0.8071 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6303 - sparse_categorical_accuracy: 0.8018 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6331 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0078 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6103 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.8064 - val_loss: 0.0076 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6247 - sparse_categorical_accuracy: 0.8033 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6214 - sparse_categorical_accuracy: 0.8069 - val_loss: 0.0073 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6196 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6293 - sparse_categorical_accuracy: 0.8026 - val_loss: 0.0071 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6214 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6253 - sparse_categorical_accuracy: 0.8026 - val_loss: 0.0069 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6073 - sparse_categorical_accuracy: 0.8108 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6097 - sparse_categorical_accuracy: 0.8109 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.8081 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6180 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6249 - sparse_categorical_accuracy: 0.8024 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6139 - sparse_categorical_accuracy: 0.8074 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6263 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6243 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6096 - sparse_categorical_accuracy: 0.8076 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6038 - sparse_categorical_accuracy: 0.8109 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6132 - sparse_categorical_accuracy: 0.8061 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.8056 - val_loss: 0.0060 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6217 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6143 - sparse_categorical_accuracy: 0.8098 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6173 - sparse_categorical_accuracy: 0.8083 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6079 - sparse_categorical_accuracy: 0.8093 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6118 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6123 - sparse_categorical_accuracy: 0.8084 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6018 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6128 - sparse_categorical_accuracy: 0.8062 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6006 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6084 - sparse_categorical_accuracy: 0.8091 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5991 - sparse_categorical_accuracy: 0.8127 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6229 - sparse_categorical_accuracy: 0.8027 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6040 - sparse_categorical_accuracy: 0.8124 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6024 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6076 - sparse_categorical_accuracy: 0.8104 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6102 - sparse_categorical_accuracy: 0.8091 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6018 - sparse_categorical_accuracy: 0.8118 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6191 - sparse_categorical_accuracy: 0.8059 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5837 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6053 - sparse_categorical_accuracy: 0.8123 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6061 - sparse_categorical_accuracy: 0.8074 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6077 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5995 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6129 - sparse_categorical_accuracy: 0.8083 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6090 - sparse_categorical_accuracy: 0.8098 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5980 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5855 - sparse_categorical_accuracy: 0.8166 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6085 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5983 - sparse_categorical_accuracy: 0.8138 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6055 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5908 - sparse_categorical_accuracy: 0.8138 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6004 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5927 - sparse_categorical_accuracy: 0.8131 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6054 - sparse_categorical_accuracy: 0.8099 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5969 - sparse_categorical_accuracy: 0.8141 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5973 - sparse_categorical_accuracy: 0.8131 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6139 - sparse_categorical_accuracy: 0.8091 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5955 - sparse_categorical_accuracy: 0.8109 - val_loss: 0.0041 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6063 - sparse_categorical_accuracy: 0.8086 - val_loss: 0.0041 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6012 - sparse_categorical_accuracy: 0.8085 - val_loss: 0.0041 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6063 - sparse_categorical_accuracy: 0.8080 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5993 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5924 - sparse_categorical_accuracy: 0.8156 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5988 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5944 - sparse_categorical_accuracy: 0.8142 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5993 - sparse_categorical_accuracy: 0.8135 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5734 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5974 - sparse_categorical_accuracy: 0.8148 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5992 - sparse_categorical_accuracy: 0.8110 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5964 - sparse_categorical_accuracy: 0.8123 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6001 - sparse_categorical_accuracy: 0.8128 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5940 - sparse_categorical_accuracy: 0.8133 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5797 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5919 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5956 - sparse_categorical_accuracy: 0.8148 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5999 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5853 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5927 - sparse_categorical_accuracy: 0.8156 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5837 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5732 - sparse_categorical_accuracy: 0.8207 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5984 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5827 - sparse_categorical_accuracy: 0.8186 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5926 - sparse_categorical_accuracy: 0.8158 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5846 - sparse_categorical_accuracy: 0.8144 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5893 - sparse_categorical_accuracy: 0.8132 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5851 - sparse_categorical_accuracy: 0.8155 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5806 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6042 - sparse_categorical_accuracy: 0.8104 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5801 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5924 - sparse_categorical_accuracy: 0.8146 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5719 - sparse_categorical_accuracy: 0.8212 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5682 - sparse_categorical_accuracy: 0.8227 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5908 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5830 - sparse_categorical_accuracy: 0.8134 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5883 - sparse_categorical_accuracy: 0.8167 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5771 - sparse_categorical_accuracy: 0.8178 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5760 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5894 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5913 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5892 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5823 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5808 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5740 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5747 - sparse_categorical_accuracy: 0.8199 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5796 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.5744 - sparse_categorical_accuracy: 0.8198 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5855 - sparse_categorical_accuracy: 0.8138 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5769 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5750 - sparse_categorical_accuracy: 0.8206 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5782 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5740 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5751 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5706 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5716 - sparse_categorical_accuracy: 0.8231 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5762 - sparse_categorical_accuracy: 0.8204 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5786 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5722 - sparse_categorical_accuracy: 0.8216 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5794 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5747 - sparse_categorical_accuracy: 0.8215 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5680 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5740 - sparse_categorical_accuracy: 0.8201 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5720 - sparse_categorical_accuracy: 0.8224 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5655 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5713 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5654 - sparse_categorical_accuracy: 0.8242 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5793 - sparse_categorical_accuracy: 0.8181 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# ...
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5329 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5440 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5304 - sparse_categorical_accuracy: 0.8343 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5426 - sparse_categorical_accuracy: 0.8291 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5272 - sparse_categorical_accuracy: 0.8324 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5322 - sparse_categorical_accuracy: 0.8318 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5266 - sparse_categorical_accuracy: 0.8342 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5255 - sparse_categorical_accuracy: 0.8353 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5311 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5385 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5556 - sparse_categorical_accuracy: 0.8233 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5358 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5302 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8268 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5360 - sparse_categorical_accuracy: 0.8316 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5537 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5375 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5409 - sparse_categorical_accuracy: 0.8313 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5397 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5427 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5286 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5273 - sparse_categorical_accuracy: 0.8328 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5327 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5511 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5378 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5415 - sparse_categorical_accuracy: 0.8291 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5513 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5427 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5329 - sparse_categorical_accuracy: 0.8336 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5262 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5312 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5265 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5399 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5334 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5341 - sparse_categorical_accuracy: 0.8264 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5268 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5290 - sparse_categorical_accuracy: 0.8317 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5373 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5331 - sparse_categorical_accuracy: 0.8322 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5428 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5234 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5391 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5340 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5288 - sparse_categorical_accuracy: 0.8324 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5394 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5326 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5477 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5282 - sparse_categorical_accuracy: 0.8338 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5416 - sparse_categorical_accuracy: 0.8304 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5422 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5316 - sparse_categorical_accuracy: 0.8296 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5307 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5359 - sparse_categorical_accuracy: 0.8302 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5346 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5339 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5294 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5239 - sparse_categorical_accuracy: 0.8334 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5209 - sparse_categorical_accuracy: 0.8348 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5345 - sparse_categorical_accuracy: 0.8332 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5531 - sparse_categorical_accuracy: 0.8239 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5212 - sparse_categorical_accuracy: 0.8364 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5341 - sparse_categorical_accuracy: 0.8317 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5404 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5371 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5392 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5331 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5382 - sparse_categorical_accuracy: 0.8301 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5502 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5271 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5336 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5420 - sparse_categorical_accuracy: 0.8314 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5462 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5405 - sparse_categorical_accuracy: 0.8301 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5341 - sparse_categorical_accuracy: 0.8321 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5294 - sparse_categorical_accuracy: 0.8329 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5444 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5525 - sparse_categorical_accuracy: 0.8249 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5390 - sparse_categorical_accuracy: 0.8302 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5319 - sparse_categorical_accuracy: 0.8337 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5340 - sparse_categorical_accuracy: 0.8319 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5348 - sparse_categorical_accuracy: 0.8299 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.5249 - sparse_categorical_accuracy: 0.8332 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.37430  BER: 0.10675
# total: 10675
# SNR: 0.500:
#  ->BLER: 0.30170  BER: 0.08329
# total: 8329
# SNR: 1.000:
#  ->BLER: 0.24140  BER: 0.06566
# total: 6566
# SNR: 1.500:
#  ->BLER: 0.18320  BER: 0.04786
# total: 4786
# SNR: 2.000:
#  ->BLER: 0.13500  BER: 0.03562
# total: 3562
# SNR: 2.500:
#  ->BLER: 0.09160  BER: 0.02408
# total: 2408
# SNR: 3.000:
#  ->BLER: 0.06530  BER: 0.01638
# total: 1638
# SNR: 3.500:
#  ->BLER: 0.04110  BER: 0.01053
# total: 1053
# SNR: 4.000:
#  ->BLER: 0.02200  BER: 0.00564
# total: 564
# SNR: 4.500:
#  ->BLER: 0.01310  BER: 0.00320
# total: 320
# SNR: 5.000:
#  ->BLER: 0.00670  BER: 0.00165
# total: 165
# SNR: 5.500:
#  ->BLER: 0.00370  BER: 0.00101
# total: 101
# SNR: 6.000:
#  ->BLER: 0.00120  BER: 0.00028
# total: 28
# SNR: 6.500:
#  ->BLER: 0.00070  BER: 0.00019
# total: 19
# SNR: 7.000:
#  ->BLER: 0.00010  BER: 0.00003
# total: 3
# SNR: 7.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (10000, 2, 32)
# SNR: 0.000:-> BLER: 0.37000 BER: 0.10437
# total_bit_error: 10437
# total_msg_error: 3700
# SNR: 0.500:-> BLER: 0.30810 BER: 0.08443
# total_bit_error: 8443
# total_msg_error: 3081
# SNR: 1.000:-> BLER: 0.24160 BER: 0.06477
# total_bit_error: 6477
# total_msg_error: 2416
# SNR: 1.500:-> BLER: 0.18820 BER: 0.05038
# total_bit_error: 5038
# total_msg_error: 1882
# SNR: 2.000:-> BLER: 0.13680 BER: 0.03562
# total_bit_error: 3562
# total_msg_error: 1368
# SNR: 2.500:-> BLER: 0.09290 BER: 0.02383
# total_bit_error: 2383
# total_msg_error: 929
# SNR: 3.000:-> BLER: 0.06290 BER: 0.01654
# total_bit_error: 1654
# total_msg_error: 629
# SNR: 3.500:-> BLER: 0.03910 BER: 0.01021
# total_bit_error: 1021
# total_msg_error: 391
# SNR: 4.000:-> BLER: 0.02300 BER: 0.00550
# total_bit_error: 550
# total_msg_error: 230
# SNR: 4.500:-> BLER: 0.01340 BER: 0.00334
# total_bit_error: 334
# total_msg_error: 134
# SNR: 5.000:-> BLER: 0.00730 BER: 0.00183
# total_bit_error: 183
# total_msg_error: 73
# SNR: 5.500:-> BLER: 0.00220 BER: 0.00056
# total_bit_error: 56
# total_msg_error: 22
# SNR: 6.000:-> BLER: 0.00140 BER: 0.00038
# total_bit_error: 38
# total_msg_error: 14
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00010 BER: 0.00003
# total_bit_error: 3
# total_msg_error: 1
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [1.0675e-01 8.3290e-02 6.5660e-02 4.7860e-02 3.5620e-02 2.4080e-02
#  1.6380e-02 1.0530e-02 5.6400e-03 3.2000e-03 1.6500e-03 1.0100e-03
#  2.8000e-04 1.9000e-04 3.0000e-05 0.0000e+00 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00]
# [3.743e-01 3.017e-01 2.414e-01 1.832e-01 1.350e-01 9.160e-02 6.530e-02
#  4.110e-02 2.200e-02 1.310e-02 6.700e-03 3.700e-03 1.200e-03 7.000e-04
#  1.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)(train)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(validation)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (10000, 2, 32)
# SNR: 0.000:-> BLER: 0.37320 BER: 0.10478
# total_bit_error: 10478
# total_msg_error: 3732
# SNR: 0.500:-> BLER: 0.30310 BER: 0.08333
# total_bit_error: 8333
# total_msg_error: 3031
# SNR: 1.000:-> BLER: 0.24750 BER: 0.06615
# total_bit_error: 6615
# total_msg_error: 2475
# SNR: 1.500:-> BLER: 0.19330 BER: 0.05048
# total_bit_error: 5048
# total_msg_error: 1933
# SNR: 2.000:-> BLER: 0.14070 BER: 0.03731
# total_bit_error: 3731
# total_msg_error: 1407
# SNR: 2.500:-> BLER: 0.09410 BER: 0.02445
# total_bit_error: 2445
# total_msg_error: 941
# SNR: 3.000:-> BLER: 0.06480 BER: 0.01648
# total_bit_error: 1648
# total_msg_error: 648
# SNR: 3.500:-> BLER: 0.04080 BER: 0.01039
# total_bit_error: 1039
# total_msg_error: 408
# SNR: 4.000:-> BLER: 0.02220 BER: 0.00574
# total_bit_error: 574
# total_msg_error: 222
# SNR: 4.500:-> BLER: 0.01250 BER: 0.00318
# total_bit_error: 318
# total_msg_error: 125
# SNR: 5.000:-> BLER: 0.00540 BER: 0.00131
# total_bit_error: 131
# total_msg_error: 54
# SNR: 5.500:-> BLER: 0.00360 BER: 0.00088
# total_bit_error: 88
# total_msg_error: 36
# SNR: 6.000:-> BLER: 0.00140 BER: 0.00042
# total_bit_error: 42
# total_msg_error: 14
# SNR: 6.500:-> BLER: 0.00020 BER: 0.00006
# total_bit_error: 6
# total_msg_error: 2
# SNR: 7.000:-> BLER: 0.00010 BER: 0.00002
# total_bit_error: 2
# total_msg_error: 1
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [1.0478e-01 8.3330e-02 6.6150e-02 5.0480e-02 3.7310e-02 2.4450e-02
#  1.6480e-02 1.0390e-02 5.7400e-03 3.1800e-03 1.3100e-03 8.8000e-04
#  4.2000e-04 6.0000e-05 2.0000e-05 0.0000e+00 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00]
# [3.732e-01 3.031e-01 2.475e-01 1.933e-01 1.407e-01 9.410e-02 6.480e-02
#  4.080e-02 2.220e-02 1.250e-02 5.400e-03 3.600e-03 1.400e-03 2.000e-04
#  1.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 4.4716973

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)
train_batch_size = 500
input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
#enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))

x = tf.sqrt(tf.reduce_sum(tf.square(enc_layer2), axis=1))
x = tf.reshape (x, (-1,1))
enc_layer3 = enc_layer2 / x


encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 32)]      0
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 64)           0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 30)           1950        tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 20)           620         enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_5 (TFOpLambda)   (None, 20)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None,)              0           tf.math.square_5[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_5 (TFOpLambda)     (None,)              0           tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_12 (TFOpLambda)      (None, 1)            0           tf.math.sqrt_5[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_5 (TFOpLambda)  (None, 20)           0           enc_layer2[0][0]
#                                                                  tf.reshape_12[0][0]
# ==================================================================================================
# Total params: 2,570
# Trainable params: 2,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 64)                1344
# _________________________________________________________________
# tf.reshape_13 (TFOpLambda)   (None, 2, 32)             0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 32)             1056
# =================================================================
# Total params: 2,400
# Trainable params: 2,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_15 (Functional)        (None, 20)                2570
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_16 (Functional)        (None, 2, 32)             2400
# =================================================================
# Total params: 4,970
# Trainable params: 4,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history2 = dict ()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history2 [snr] = history
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 20/20 [==============================] - 1s 15ms/step - loss: 3.6063 - sparse_categorical_accuracy: 0.0283 - val_loss: 3.4985 - val_sparse_categorical_accuracy: 0.0303
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4961 - sparse_categorical_accuracy: 0.0295 - val_loss: 3.4355 - val_sparse_categorical_accuracy: 0.0303
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4451 - sparse_categorical_accuracy: 0.0363 - val_loss: 3.3980 - val_sparse_categorical_accuracy: 0.0303
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4126 - sparse_categorical_accuracy: 0.0536 - val_loss: 3.3712 - val_sparse_categorical_accuracy: 0.0466
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3873 - sparse_categorical_accuracy: 0.0742 - val_loss: 3.3491 - val_sparse_categorical_accuracy: 0.3199
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3689 - sparse_categorical_accuracy: 0.0858 - val_loss: 3.3296 - val_sparse_categorical_accuracy: 0.5131
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3541 - sparse_categorical_accuracy: 0.0955 - val_loss: 3.3116 - val_sparse_categorical_accuracy: 0.5421
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3437 - sparse_categorical_accuracy: 0.0996 - val_loss: 3.2946 - val_sparse_categorical_accuracy: 0.5648
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3357 - sparse_categorical_accuracy: 0.1013 - val_loss: 3.2780 - val_sparse_categorical_accuracy: 0.5849
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3254 - sparse_categorical_accuracy: 0.0943 - val_loss: 3.2613 - val_sparse_categorical_accuracy: 0.6039
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3140 - sparse_categorical_accuracy: 0.1049 - val_loss: 3.2444 - val_sparse_categorical_accuracy: 0.6264
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3073 - sparse_categorical_accuracy: 0.1043 - val_loss: 3.2274 - val_sparse_categorical_accuracy: 0.6398
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3017 - sparse_categorical_accuracy: 0.1015 - val_loss: 3.2103 - val_sparse_categorical_accuracy: 0.6628
# Epoch 14/50
# 20/20 [==============================] - 0s 17ms/step - loss: 3.2936 - sparse_categorical_accuracy: 0.1006 - val_loss: 3.1930 - val_sparse_categorical_accuracy: 0.6734
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2866 - sparse_categorical_accuracy: 0.1028 - val_loss: 3.1757 - val_sparse_categorical_accuracy: 0.6897
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2763 - sparse_categorical_accuracy: 0.0987 - val_loss: 3.1584 - val_sparse_categorical_accuracy: 0.6993
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2656 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.1409 - val_sparse_categorical_accuracy: 0.7043
# Epoch 18/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2683 - sparse_categorical_accuracy: 0.1038 - val_loss: 3.1242 - val_sparse_categorical_accuracy: 0.7143
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2518 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.1070 - val_sparse_categorical_accuracy: 0.7221
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2556 - sparse_categorical_accuracy: 0.1011 - val_loss: 3.0908 - val_sparse_categorical_accuracy: 0.7269
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2494 - sparse_categorical_accuracy: 0.0967 - val_loss: 3.0749 - val_sparse_categorical_accuracy: 0.7373
# Epoch 22/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2452 - sparse_categorical_accuracy: 0.0959 - val_loss: 3.0594 - val_sparse_categorical_accuracy: 0.7489
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2346 - sparse_categorical_accuracy: 0.1019 - val_loss: 3.0442 - val_sparse_categorical_accuracy: 0.7565
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2361 - sparse_categorical_accuracy: 0.0983 - val_loss: 3.0301 - val_sparse_categorical_accuracy: 0.7657
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2261 - sparse_categorical_accuracy: 0.1020 - val_loss: 3.0163 - val_sparse_categorical_accuracy: 0.7675
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2396 - sparse_categorical_accuracy: 0.0983 - val_loss: 3.0045 - val_sparse_categorical_accuracy: 0.7746
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2292 - sparse_categorical_accuracy: 0.0989 - val_loss: 2.9929 - val_sparse_categorical_accuracy: 0.7746
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2279 - sparse_categorical_accuracy: 0.0969 - val_loss: 2.9816 - val_sparse_categorical_accuracy: 0.7871
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2263 - sparse_categorical_accuracy: 0.1022 - val_loss: 2.9712 - val_sparse_categorical_accuracy: 0.7905
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2228 - sparse_categorical_accuracy: 0.1004 - val_loss: 2.9616 - val_sparse_categorical_accuracy: 0.7895
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2280 - sparse_categorical_accuracy: 0.1011 - val_loss: 2.9526 - val_sparse_categorical_accuracy: 0.8055
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2261 - sparse_categorical_accuracy: 0.0955 - val_loss: 2.9449 - val_sparse_categorical_accuracy: 0.8104
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2207 - sparse_categorical_accuracy: 0.1044 - val_loss: 2.9367 - val_sparse_categorical_accuracy: 0.8098
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2200 - sparse_categorical_accuracy: 0.0981 - val_loss: 2.9291 - val_sparse_categorical_accuracy: 0.8210
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2192 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.9222 - val_sparse_categorical_accuracy: 0.8199
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2193 - sparse_categorical_accuracy: 0.0958 - val_loss: 2.9155 - val_sparse_categorical_accuracy: 0.8236
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2106 - sparse_categorical_accuracy: 0.1021 - val_loss: 2.9086 - val_sparse_categorical_accuracy: 0.8306
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2220 - sparse_categorical_accuracy: 0.0970 - val_loss: 2.9030 - val_sparse_categorical_accuracy: 0.8322
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2157 - sparse_categorical_accuracy: 0.1011 - val_loss: 2.8987 - val_sparse_categorical_accuracy: 0.8335
# Epoch 40/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2171 - sparse_categorical_accuracy: 0.1020 - val_loss: 2.8935 - val_sparse_categorical_accuracy: 0.8442
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2264 - sparse_categorical_accuracy: 0.0942 - val_loss: 2.8901 - val_sparse_categorical_accuracy: 0.8512
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2228 - sparse_categorical_accuracy: 0.0995 - val_loss: 2.8865 - val_sparse_categorical_accuracy: 0.8557
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2142 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8827 - val_sparse_categorical_accuracy: 0.8601
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2162 - sparse_categorical_accuracy: 0.0982 - val_loss: 2.8792 - val_sparse_categorical_accuracy: 0.8629
# Epoch 45/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2198 - sparse_categorical_accuracy: 0.0977 - val_loss: 2.8757 - val_sparse_categorical_accuracy: 0.8655
# Epoch 46/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2189 - sparse_categorical_accuracy: 0.0977 - val_loss: 2.8731 - val_sparse_categorical_accuracy: 0.8687
# Epoch 47/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2197 - sparse_categorical_accuracy: 0.0977 - val_loss: 2.8703 - val_sparse_categorical_accuracy: 0.8688
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2156 - sparse_categorical_accuracy: 0.1015 - val_loss: 2.8675 - val_sparse_categorical_accuracy: 0.8757
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2116 - sparse_categorical_accuracy: 0.1036 - val_loss: 2.8642 - val_sparse_categorical_accuracy: 0.8748
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2074 - sparse_categorical_accuracy: 0.0999 - val_loss: 2.8613 - val_sparse_categorical_accuracy: 0.8775
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2136 - sparse_categorical_accuracy: 0.0975 - val_loss: 2.8592 - val_sparse_categorical_accuracy: 0.8787
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2144 - sparse_categorical_accuracy: 0.0988 - val_loss: 2.8572 - val_sparse_categorical_accuracy: 0.8859
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2112 - sparse_categorical_accuracy: 0.1013 - val_loss: 2.8548 - val_sparse_categorical_accuracy: 0.8874
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8525 - val_sparse_categorical_accuracy: 0.8898
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2168 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8509 - val_sparse_categorical_accuracy: 0.8900
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2086 - sparse_categorical_accuracy: 0.1019 - val_loss: 2.8494 - val_sparse_categorical_accuracy: 0.8863
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2169 - sparse_categorical_accuracy: 0.0960 - val_loss: 2.8483 - val_sparse_categorical_accuracy: 0.8917
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2152 - sparse_categorical_accuracy: 0.0980 - val_loss: 2.8472 - val_sparse_categorical_accuracy: 0.8903
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2056 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8451 - val_sparse_categorical_accuracy: 0.8924
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2078 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.8436 - val_sparse_categorical_accuracy: 0.8931
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2006 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.8414 - val_sparse_categorical_accuracy: 0.8960
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2167 - sparse_categorical_accuracy: 0.1003 - val_loss: 2.8402 - val_sparse_categorical_accuracy: 0.8960
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2115 - sparse_categorical_accuracy: 0.1014 - val_loss: 2.8402 - val_sparse_categorical_accuracy: 0.8988
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2073 - sparse_categorical_accuracy: 0.0988 - val_loss: 2.8390 - val_sparse_categorical_accuracy: 0.9049
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2053 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.8373 - val_sparse_categorical_accuracy: 0.9036
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2101 - sparse_categorical_accuracy: 0.0975 - val_loss: 2.8363 - val_sparse_categorical_accuracy: 0.9000
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2085 - sparse_categorical_accuracy: 0.1011 - val_loss: 2.8358 - val_sparse_categorical_accuracy: 0.9029
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2077 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9008
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2051 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8337 - val_sparse_categorical_accuracy: 0.9057
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1998 - sparse_categorical_accuracy: 0.1053 - val_loss: 2.8320 - val_sparse_categorical_accuracy: 0.9086
# Epoch 21/50
# 20/20 [==============================] - 0s 14ms/step - loss: 3.2094 - sparse_categorical_accuracy: 0.1008 - val_loss: 2.8309 - val_sparse_categorical_accuracy: 0.9111
# Epoch 22/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2077 - sparse_categorical_accuracy: 0.1006 - val_loss: 2.8302 - val_sparse_categorical_accuracy: 0.9135
# Epoch 23/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2162 - sparse_categorical_accuracy: 0.0981 - val_loss: 2.8305 - val_sparse_categorical_accuracy: 0.9099
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2196 - sparse_categorical_accuracy: 0.0993 - val_loss: 2.8314 - val_sparse_categorical_accuracy: 0.9121
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2111 - sparse_categorical_accuracy: 0.0985 - val_loss: 2.8316 - val_sparse_categorical_accuracy: 0.9161
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2104 - sparse_categorical_accuracy: 0.0997 - val_loss: 2.8309 - val_sparse_categorical_accuracy: 0.9229
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1999 - sparse_categorical_accuracy: 0.1038 - val_loss: 2.8302 - val_sparse_categorical_accuracy: 0.9171
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2098 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8291 - val_sparse_categorical_accuracy: 0.9191
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1961 - sparse_categorical_accuracy: 0.1018 - val_loss: 2.8277 - val_sparse_categorical_accuracy: 0.9234
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2066 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.8263 - val_sparse_categorical_accuracy: 0.9262
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2075 - sparse_categorical_accuracy: 0.1031 - val_loss: 2.8259 - val_sparse_categorical_accuracy: 0.9244
# Epoch 32/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2067 - sparse_categorical_accuracy: 0.1013 - val_loss: 2.8253 - val_sparse_categorical_accuracy: 0.9327
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2109 - sparse_categorical_accuracy: 0.0993 - val_loss: 2.8253 - val_sparse_categorical_accuracy: 0.9303
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2067 - sparse_categorical_accuracy: 0.1021 - val_loss: 2.8252 - val_sparse_categorical_accuracy: 0.9320
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2051 - sparse_categorical_accuracy: 0.1006 - val_loss: 2.8241 - val_sparse_categorical_accuracy: 0.9347
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2105 - sparse_categorical_accuracy: 0.0990 - val_loss: 2.8238 - val_sparse_categorical_accuracy: 0.9322
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1957 - sparse_categorical_accuracy: 0.1032 - val_loss: 2.8229 - val_sparse_categorical_accuracy: 0.9379
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2035 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8216 - val_sparse_categorical_accuracy: 0.9414
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2058 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8207 - val_sparse_categorical_accuracy: 0.9424
# Epoch 40/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2032 - sparse_categorical_accuracy: 0.1052 - val_loss: 2.8204 - val_sparse_categorical_accuracy: 0.9417
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2086 - sparse_categorical_accuracy: 0.1003 - val_loss: 2.8195 - val_sparse_categorical_accuracy: 0.9392
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2052 - sparse_categorical_accuracy: 0.0999 - val_loss: 2.8195 - val_sparse_categorical_accuracy: 0.9446
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2058 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8191 - val_sparse_categorical_accuracy: 0.9450
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2153 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8193 - val_sparse_categorical_accuracy: 0.9481
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2029 - sparse_categorical_accuracy: 0.1067 - val_loss: 2.8193 - val_sparse_categorical_accuracy: 0.9485
# Epoch 46/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2012 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.8187 - val_sparse_categorical_accuracy: 0.9457
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2018 - sparse_categorical_accuracy: 0.1039 - val_loss: 2.8175 - val_sparse_categorical_accuracy: 0.9501
# Epoch 48/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2023 - sparse_categorical_accuracy: 0.1056 - val_loss: 2.8172 - val_sparse_categorical_accuracy: 0.9488
# Epoch 49/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2115 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8173 - val_sparse_categorical_accuracy: 0.9517
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2055 - sparse_categorical_accuracy: 0.1038 - val_loss: 2.8178 - val_sparse_categorical_accuracy: 0.9512
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2109 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.8179 - val_sparse_categorical_accuracy: 0.9528
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2027 - sparse_categorical_accuracy: 0.1059 - val_loss: 2.8180 - val_sparse_categorical_accuracy: 0.9541
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1963 - sparse_categorical_accuracy: 0.1042 - val_loss: 2.8167 - val_sparse_categorical_accuracy: 0.9531
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2102 - sparse_categorical_accuracy: 0.1007 - val_loss: 2.8166 - val_sparse_categorical_accuracy: 0.9513
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2072 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8163 - val_sparse_categorical_accuracy: 0.9564
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2064 - sparse_categorical_accuracy: 0.1013 - val_loss: 2.8166 - val_sparse_categorical_accuracy: 0.9537
# Epoch 7/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2052 - sparse_categorical_accuracy: 0.1044 - val_loss: 2.8166 - val_sparse_categorical_accuracy: 0.9593
# Epoch 8/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1977 - sparse_categorical_accuracy: 0.1033 - val_loss: 2.8154 - val_sparse_categorical_accuracy: 0.9556
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1926 - sparse_categorical_accuracy: 0.1085 - val_loss: 2.8138 - val_sparse_categorical_accuracy: 0.9581
# Epoch 10/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2168 - sparse_categorical_accuracy: 0.0987 - val_loss: 2.8142 - val_sparse_categorical_accuracy: 0.9585
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2070 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8145 - val_sparse_categorical_accuracy: 0.9589
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2027 - sparse_categorical_accuracy: 0.1006 - val_loss: 2.8143 - val_sparse_categorical_accuracy: 0.9617
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2018 - sparse_categorical_accuracy: 0.1056 - val_loss: 2.8137 - val_sparse_categorical_accuracy: 0.9610
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2020 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8135 - val_sparse_categorical_accuracy: 0.9615
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2123 - sparse_categorical_accuracy: 0.1034 - val_loss: 2.8142 - val_sparse_categorical_accuracy: 0.9636
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2023 - sparse_categorical_accuracy: 0.1044 - val_loss: 2.8141 - val_sparse_categorical_accuracy: 0.9634
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2047 - sparse_categorical_accuracy: 0.1023 - val_loss: 2.8138 - val_sparse_categorical_accuracy: 0.9634
# Epoch 18/50
# 20/20 [==============================] - 0s 15ms/step - loss: 3.1993 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8135 - val_sparse_categorical_accuracy: 0.9633
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2097 - sparse_categorical_accuracy: 0.1039 - val_loss: 2.8138 - val_sparse_categorical_accuracy: 0.9654
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2018 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8135 - val_sparse_categorical_accuracy: 0.9664
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2064 - sparse_categorical_accuracy: 0.0994 - val_loss: 2.8132 - val_sparse_categorical_accuracy: 0.9659
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1979 - sparse_categorical_accuracy: 0.1043 - val_loss: 2.8129 - val_sparse_categorical_accuracy: 0.9677
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2043 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.8127 - val_sparse_categorical_accuracy: 0.9653
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2079 - sparse_categorical_accuracy: 0.1009 - val_loss: 2.8131 - val_sparse_categorical_accuracy: 0.9684
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2064 - sparse_categorical_accuracy: 0.1029 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9677
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2028 - sparse_categorical_accuracy: 0.1042 - val_loss: 2.8130 - val_sparse_categorical_accuracy: 0.9680
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2000 - sparse_categorical_accuracy: 0.1040 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9711
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2036 - sparse_categorical_accuracy: 0.1061 - val_loss: 2.8130 - val_sparse_categorical_accuracy: 0.9678
# Epoch 29/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.8124 - val_sparse_categorical_accuracy: 0.9706
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1048 - val_loss: 2.8127 - val_sparse_categorical_accuracy: 0.9713
# Epoch 31/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2023 - sparse_categorical_accuracy: 0.1054 - val_loss: 2.8126 - val_sparse_categorical_accuracy: 0.9714
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1996 - sparse_categorical_accuracy: 0.1036 - val_loss: 2.8122 - val_sparse_categorical_accuracy: 0.9696
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2027 - sparse_categorical_accuracy: 0.1041 - val_loss: 2.8120 - val_sparse_categorical_accuracy: 0.9696
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2037 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8118 - val_sparse_categorical_accuracy: 0.9688
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1954 - sparse_categorical_accuracy: 0.1067 - val_loss: 2.8112 - val_sparse_categorical_accuracy: 0.9664
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1986 - sparse_categorical_accuracy: 0.1051 - val_loss: 2.8106 - val_sparse_categorical_accuracy: 0.9667
# Epoch 37/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2090 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8109 - val_sparse_categorical_accuracy: 0.9716
# Epoch 38/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2106 - sparse_categorical_accuracy: 0.1019 - val_loss: 2.8115 - val_sparse_categorical_accuracy: 0.9700
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2044 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8120 - val_sparse_categorical_accuracy: 0.9683
# Epoch 40/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2022 - sparse_categorical_accuracy: 0.1049 - val_loss: 2.8115 - val_sparse_categorical_accuracy: 0.9699
# Epoch 41/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1035 - val_loss: 2.8114 - val_sparse_categorical_accuracy: 0.9686
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2146 - sparse_categorical_accuracy: 0.0984 - val_loss: 2.8125 - val_sparse_categorical_accuracy: 0.9676
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2117 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.8136 - val_sparse_categorical_accuracy: 0.9706
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9683
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1982 - sparse_categorical_accuracy: 0.1039 - val_loss: 2.8127 - val_sparse_categorical_accuracy: 0.9691
# Epoch 46/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1916 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8117 - val_sparse_categorical_accuracy: 0.9688
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2022 - sparse_categorical_accuracy: 0.1006 - val_loss: 2.8115 - val_sparse_categorical_accuracy: 0.9689
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2078 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8122 - val_sparse_categorical_accuracy: 0.9676
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2086 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8123 - val_sparse_categorical_accuracy: 0.9668
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1033 - val_loss: 2.8129 - val_sparse_categorical_accuracy: 0.9728
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2034 - sparse_categorical_accuracy: 0.1003 - val_loss: 2.8129 - val_sparse_categorical_accuracy: 0.9725
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2115 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8137 - val_sparse_categorical_accuracy: 0.9707
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2024 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8137 - val_sparse_categorical_accuracy: 0.9700
# Epoch 4/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2051 - sparse_categorical_accuracy: 0.1057 - val_loss: 2.8135 - val_sparse_categorical_accuracy: 0.9688
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2016 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8135 - val_sparse_categorical_accuracy: 0.9703
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1996 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8131 - val_sparse_categorical_accuracy: 0.9719
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1972 - sparse_categorical_accuracy: 0.1059 - val_loss: 2.8125 - val_sparse_categorical_accuracy: 0.9712
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1947 - sparse_categorical_accuracy: 0.1041 - val_loss: 2.8117 - val_sparse_categorical_accuracy: 0.9714
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2106 - sparse_categorical_accuracy: 0.1054 - val_loss: 2.8118 - val_sparse_categorical_accuracy: 0.9733
# Epoch 10/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1939 - sparse_categorical_accuracy: 0.1052 - val_loss: 2.8113 - val_sparse_categorical_accuracy: 0.9749
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2042 - sparse_categorical_accuracy: 0.1068 - val_loss: 2.8111 - val_sparse_categorical_accuracy: 0.9700
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2005 - sparse_categorical_accuracy: 0.1061 - val_loss: 2.8110 - val_sparse_categorical_accuracy: 0.9712
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.1047 - val_loss: 2.8112 - val_sparse_categorical_accuracy: 0.9742
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1949 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.8105 - val_sparse_categorical_accuracy: 0.9744
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2085 - sparse_categorical_accuracy: 0.1028 - val_loss: 2.8112 - val_sparse_categorical_accuracy: 0.9716
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2007 - sparse_categorical_accuracy: 0.1025 - val_loss: 2.8109 - val_sparse_categorical_accuracy: 0.9718
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2045 - sparse_categorical_accuracy: 0.1010 - val_loss: 2.8111 - val_sparse_categorical_accuracy: 0.9742
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2070 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8116 - val_sparse_categorical_accuracy: 0.9774
# Epoch 19/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1985 - sparse_categorical_accuracy: 0.1053 - val_loss: 2.8115 - val_sparse_categorical_accuracy: 0.9731
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1960 - sparse_categorical_accuracy: 0.1079 - val_loss: 2.8110 - val_sparse_categorical_accuracy: 0.9746
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2017 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8106 - val_sparse_categorical_accuracy: 0.9740
# Epoch 22/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.1062 - val_loss: 2.8100 - val_sparse_categorical_accuracy: 0.9747
# Epoch 23/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1968 - sparse_categorical_accuracy: 0.1078 - val_loss: 2.8098 - val_sparse_categorical_accuracy: 0.9747
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1935 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.9761
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2015 - sparse_categorical_accuracy: 0.1056 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.9765
# Epoch 26/50
# 20/20 [==============================] - 0s 15ms/step - loss: 3.1989 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.9760
# Epoch 27/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1989 - sparse_categorical_accuracy: 0.1074 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.9739
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2029 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8086 - val_sparse_categorical_accuracy: 0.9768
# Epoch 29/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1973 - sparse_categorical_accuracy: 0.1057 - val_loss: 2.8086 - val_sparse_categorical_accuracy: 0.9757
# Epoch 30/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2062 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.8088 - val_sparse_categorical_accuracy: 0.9743
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1974 - sparse_categorical_accuracy: 0.1041 - val_loss: 2.8086 - val_sparse_categorical_accuracy: 0.9775
# Epoch 32/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2019 - sparse_categorical_accuracy: 0.1040 - val_loss: 2.8086 - val_sparse_categorical_accuracy: 0.9747
# Epoch 33/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2086 - sparse_categorical_accuracy: 0.1078 - val_loss: 2.8095 - val_sparse_categorical_accuracy: 0.9768
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2048 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8102 - val_sparse_categorical_accuracy: 0.9776
# Epoch 35/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1921 - sparse_categorical_accuracy: 0.1080 - val_loss: 2.8100 - val_sparse_categorical_accuracy: 0.9750
# Epoch 36/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2042 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8101 - val_sparse_categorical_accuracy: 0.9736
# Epoch 37/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2009 - sparse_categorical_accuracy: 0.1073 - val_loss: 2.8102 - val_sparse_categorical_accuracy: 0.9742
# Epoch 38/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2004 - sparse_categorical_accuracy: 0.1024 - val_loss: 2.8102 - val_sparse_categorical_accuracy: 0.9765
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2057 - sparse_categorical_accuracy: 0.1074 - val_loss: 2.8107 - val_sparse_categorical_accuracy: 0.9756
# Epoch 40/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.1090 - val_loss: 2.8110 - val_sparse_categorical_accuracy: 0.9776
# Epoch 41/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1982 - sparse_categorical_accuracy: 0.1048 - val_loss: 2.8111 - val_sparse_categorical_accuracy: 0.9764
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2077 - sparse_categorical_accuracy: 0.1052 - val_loss: 2.8115 - val_sparse_categorical_accuracy: 0.9759
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1986 - sparse_categorical_accuracy: 0.1051 - val_loss: 2.8117 - val_sparse_categorical_accuracy: 0.9755
# Epoch 44/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2045 - sparse_categorical_accuracy: 0.1074 - val_loss: 2.8120 - val_sparse_categorical_accuracy: 0.9764
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2057 - sparse_categorical_accuracy: 0.1036 - val_loss: 2.8125 - val_sparse_categorical_accuracy: 0.9761
# Epoch 46/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2102 - sparse_categorical_accuracy: 0.1056 - val_loss: 2.8134 - val_sparse_categorical_accuracy: 0.9761
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2115 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8147 - val_sparse_categorical_accuracy: 0.9765
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1974 - sparse_categorical_accuracy: 0.1071 - val_loss: 2.8144 - val_sparse_categorical_accuracy: 0.9751
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1936 - sparse_categorical_accuracy: 0.1077 - val_loss: 2.8139 - val_sparse_categorical_accuracy: 0.9751
# Epoch 50/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2030 - sparse_categorical_accuracy: 0.1059 - val_loss: 2.8136 - val_sparse_categorical_accuracy: 0.9744
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1991 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8131 - val_sparse_categorical_accuracy: 0.9775
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2039 - sparse_categorical_accuracy: 0.1036 - val_loss: 2.8132 - val_sparse_categorical_accuracy: 0.9761
# Epoch 3/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2139 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.8144 - val_sparse_categorical_accuracy: 0.9746
# Epoch 4/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2042 - sparse_categorical_accuracy: 0.1050 - val_loss: 2.8148 - val_sparse_categorical_accuracy: 0.9753
# Epoch 5/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1939 - sparse_categorical_accuracy: 0.1082 - val_loss: 2.8140 - val_sparse_categorical_accuracy: 0.9736
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2037 - sparse_categorical_accuracy: 0.1070 - val_loss: 2.8136 - val_sparse_categorical_accuracy: 0.9772
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2067 - sparse_categorical_accuracy: 0.1054 - val_loss: 2.8137 - val_sparse_categorical_accuracy: 0.9790
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1962 - sparse_categorical_accuracy: 0.1067 - val_loss: 2.8134 - val_sparse_categorical_accuracy: 0.9755
# Epoch 9/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2016 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9762
# Epoch 10/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2063 - sparse_categorical_accuracy: 0.1054 - val_loss: 2.8136 - val_sparse_categorical_accuracy: 0.9760
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1937 - sparse_categorical_accuracy: 0.1068 - val_loss: 2.8128 - val_sparse_categorical_accuracy: 0.9803
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8126 - val_sparse_categorical_accuracy: 0.9744
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2007 - sparse_categorical_accuracy: 0.1121 - val_loss: 2.8126 - val_sparse_categorical_accuracy: 0.9765
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2077 - sparse_categorical_accuracy: 0.1099 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9753
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2031 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8133 - val_sparse_categorical_accuracy: 0.9775
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1996 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8134 - val_sparse_categorical_accuracy: 0.9742
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1863 - sparse_categorical_accuracy: 0.1086 - val_loss: 2.8125 - val_sparse_categorical_accuracy: 0.9771
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2013 - sparse_categorical_accuracy: 0.1064 - val_loss: 2.8120 - val_sparse_categorical_accuracy: 0.9793
# Epoch 19/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2059 - sparse_categorical_accuracy: 0.1045 - val_loss: 2.8121 - val_sparse_categorical_accuracy: 0.9775
# Epoch 20/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2009 - sparse_categorical_accuracy: 0.1085 - val_loss: 2.8122 - val_sparse_categorical_accuracy: 0.9772
# Epoch 21/50
# 20/20 [==============================] - 0s 15ms/step - loss: 3.2019 - sparse_categorical_accuracy: 0.1036 - val_loss: 2.8121 - val_sparse_categorical_accuracy: 0.9787
# Epoch 22/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1084 - val_loss: 2.8116 - val_sparse_categorical_accuracy: 0.9779
# Epoch 23/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2068 - sparse_categorical_accuracy: 0.1019 - val_loss: 2.8124 - val_sparse_categorical_accuracy: 0.9782
# Epoch 24/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2040 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8130 - val_sparse_categorical_accuracy: 0.9757
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1947 - sparse_categorical_accuracy: 0.1094 - val_loss: 2.8128 - val_sparse_categorical_accuracy: 0.9780
# Epoch 26/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2017 - sparse_categorical_accuracy: 0.1057 - val_loss: 2.8128 - val_sparse_categorical_accuracy: 0.9795
# Epoch 27/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1993 - sparse_categorical_accuracy: 0.1077 - val_loss: 2.8123 - val_sparse_categorical_accuracy: 0.9785
# Epoch 28/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2071 - sparse_categorical_accuracy: 0.1038 - val_loss: 2.8125 - val_sparse_categorical_accuracy: 0.9787
# Epoch 29/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2035 - sparse_categorical_accuracy: 0.1059 - val_loss: 2.8130 - val_sparse_categorical_accuracy: 0.9782
# Epoch 30/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2070 - sparse_categorical_accuracy: 0.1031 - val_loss: 2.8136 - val_sparse_categorical_accuracy: 0.9793
# Epoch 31/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2031 - sparse_categorical_accuracy: 0.1019 - val_loss: 2.8140 - val_sparse_categorical_accuracy: 0.9804
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1997 - sparse_categorical_accuracy: 0.1030 - val_loss: 2.8140 - val_sparse_categorical_accuracy: 0.9822
# Epoch 33/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2021 - sparse_categorical_accuracy: 0.1048 - val_loss: 2.8141 - val_sparse_categorical_accuracy: 0.9803
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1055 - val_loss: 2.8139 - val_sparse_categorical_accuracy: 0.9798
# Epoch 35/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2083 - sparse_categorical_accuracy: 0.1027 - val_loss: 2.8146 - val_sparse_categorical_accuracy: 0.9808
# Epoch 36/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2107 - sparse_categorical_accuracy: 0.1073 - val_loss: 2.8153 - val_sparse_categorical_accuracy: 0.9794
# Epoch 37/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2024 - sparse_categorical_accuracy: 0.1072 - val_loss: 2.8157 - val_sparse_categorical_accuracy: 0.9794
# Epoch 38/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2008 - sparse_categorical_accuracy: 0.1062 - val_loss: 2.8154 - val_sparse_categorical_accuracy: 0.9789
# Epoch 39/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2004 - sparse_categorical_accuracy: 0.1042 - val_loss: 2.8154 - val_sparse_categorical_accuracy: 0.9787
# Epoch 40/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2050 - sparse_categorical_accuracy: 0.1069 - val_loss: 2.8154 - val_sparse_categorical_accuracy: 0.9786
# Epoch 41/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8155 - val_sparse_categorical_accuracy: 0.9812
# Epoch 42/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2029 - sparse_categorical_accuracy: 0.1042 - val_loss: 2.8157 - val_sparse_categorical_accuracy: 0.9822
# Epoch 43/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1990 - sparse_categorical_accuracy: 0.1037 - val_loss: 2.8156 - val_sparse_categorical_accuracy: 0.9815
# Epoch 44/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1975 - sparse_categorical_accuracy: 0.1092 - val_loss: 2.8145 - val_sparse_categorical_accuracy: 0.9785
# Epoch 45/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1985 - sparse_categorical_accuracy: 0.1065 - val_loss: 2.8141 - val_sparse_categorical_accuracy: 0.9803
# Epoch 46/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2036 - sparse_categorical_accuracy: 0.1058 - val_loss: 2.8139 - val_sparse_categorical_accuracy: 0.9789
# Epoch 47/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2012 - sparse_categorical_accuracy: 0.1038 - val_loss: 2.8144 - val_sparse_categorical_accuracy: 0.9785
# Epoch 48/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1998 - sparse_categorical_accuracy: 0.1032 - val_loss: 2.8140 - val_sparse_categorical_accuracy: 0.9807
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2065 - sparse_categorical_accuracy: 0.1093 - val_loss: 2.8145 - val_sparse_categorical_accuracy: 0.9821
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1958 - sparse_categorical_accuracy: 0.1066 - val_loss: 2.8142 - val_sparse_categorical_accuracy: 0.9833
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2071 - sparse_categorical_accuracy: 0.1044 - val_loss: 2.8149 - val_sparse_categorical_accuracy: 0.9851
# Epoch 2/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1954 - sparse_categorical_accuracy: 0.1069 - val_loss: 2.8143 - val_sparse_categorical_accuracy: 0.9821
# Epoch 3/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2001 - sparse_categorical_accuracy: 0.1081 - val_loss: 2.8138 - val_sparse_categorical_accuracy: 0.9830
# Epoch 4/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2035 - sparse_categorical_accuracy: 0.1104 - val_loss: 2.8142 - val_sparse_categorical_accuracy: 0.9850
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2016 - sparse_categorical_accuracy: 0.1063 - val_loss: 2.8145 - val_sparse_categorical_accuracy: 0.9819
# Epoch 6/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1999 - sparse_categorical_accuracy: 0.1091 - val_loss: 2.8147 - val_sparse_categorical_accuracy: 0.9801
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1970 - sparse_categorical_accuracy: 0.1073 - val_loss: 2.8142 - val_sparse_categorical_accuracy: 0.9802
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1937 - sparse_categorical_accuracy: 0.1079 - val_loss: 2.8134 - val_sparse_categorical_accuracy: 0.9834
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1971 - sparse_categorical_accuracy: 0.1072 - val_loss: 2.8128 - val_sparse_categorical_accuracy: 0.9830
# Epoch 10/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1957 - sparse_categorical_accuracy: 0.1075 - val_loss: 2.8124 - val_sparse_categorical_accuracy: 0.9819
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2078 - sparse_categorical_accuracy: 0.1053 - val_loss: 2.8128 - val_sparse_categorical_accuracy: 0.9819
# Epoch 12/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1111 - val_loss: 2.8126 - val_sparse_categorical_accuracy: 0.9826
# Epoch 13/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1917 - sparse_categorical_accuracy: 0.1076 - val_loss: 2.8118 - val_sparse_categorical_accuracy: 0.9801
# Epoch 14/50
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2033 - sparse_categorical_accuracy: 0.1068 - val_loss: 2.8119 - val_sparse_categorical_accuracy: 0.9826
# Epoch 15/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1990 - sparse_categorical_accuracy: 0.1056 - val_loss: 2.8123 - val_sparse_categorical_accuracy: 0.9827
# Epoch 16/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2020 - sparse_categorical_accuracy: 0.1069 - val_loss: 2.8126 - val_sparse_categorical_accuracy: 0.9829
# Epoch 17/50
# ...
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1896 - sparse_categorical_accuracy: 0.1156 - val_loss: 2.8323 - val_sparse_categorical_accuracy: 0.9884
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1990 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8324 - val_sparse_categorical_accuracy: 0.9870
# Epoch 14/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1972 - sparse_categorical_accuracy: 0.1091 - val_loss: 2.8330 - val_sparse_categorical_accuracy: 0.9872
# Epoch 15/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1865 - sparse_categorical_accuracy: 0.1132 - val_loss: 2.8329 - val_sparse_categorical_accuracy: 0.9894
# Epoch 16/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.1997 - sparse_categorical_accuracy: 0.1082 - val_loss: 2.8329 - val_sparse_categorical_accuracy: 0.9894
# Epoch 17/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1875 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8327 - val_sparse_categorical_accuracy: 0.9890
# Epoch 18/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1885 - sparse_categorical_accuracy: 0.1137 - val_loss: 2.8322 - val_sparse_categorical_accuracy: 0.9890
# Epoch 19/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1980 - sparse_categorical_accuracy: 0.1102 - val_loss: 2.8325 - val_sparse_categorical_accuracy: 0.9895
# Epoch 20/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1889 - sparse_categorical_accuracy: 0.1126 - val_loss: 2.8326 - val_sparse_categorical_accuracy: 0.9894
# Epoch 21/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1968 - sparse_categorical_accuracy: 0.1087 - val_loss: 2.8326 - val_sparse_categorical_accuracy: 0.9867
# Epoch 22/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1874 - sparse_categorical_accuracy: 0.1171 - val_loss: 2.8327 - val_sparse_categorical_accuracy: 0.9862
# Epoch 23/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2000 - sparse_categorical_accuracy: 0.1084 - val_loss: 2.8327 - val_sparse_categorical_accuracy: 0.9882
# Epoch 24/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1113 - val_loss: 2.8339 - val_sparse_categorical_accuracy: 0.9876
# Epoch 25/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1968 - sparse_categorical_accuracy: 0.1109 - val_loss: 2.8342 - val_sparse_categorical_accuracy: 0.9890
# Epoch 26/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1886 - sparse_categorical_accuracy: 0.1128 - val_loss: 2.8340 - val_sparse_categorical_accuracy: 0.9884
# Epoch 27/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1969 - sparse_categorical_accuracy: 0.1122 - val_loss: 2.8337 - val_sparse_categorical_accuracy: 0.9881
# Epoch 28/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1973 - sparse_categorical_accuracy: 0.1128 - val_loss: 2.8337 - val_sparse_categorical_accuracy: 0.9876
# Epoch 29/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1120 - val_loss: 2.8344 - val_sparse_categorical_accuracy: 0.9871
# Epoch 30/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1869 - sparse_categorical_accuracy: 0.1137 - val_loss: 2.8338 - val_sparse_categorical_accuracy: 0.9885
# Epoch 31/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1893 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8331 - val_sparse_categorical_accuracy: 0.9876
# Epoch 32/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1907 - sparse_categorical_accuracy: 0.1155 - val_loss: 2.8327 - val_sparse_categorical_accuracy: 0.9881
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2028 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8335 - val_sparse_categorical_accuracy: 0.9880
# Epoch 34/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1977 - sparse_categorical_accuracy: 0.1105 - val_loss: 2.8343 - val_sparse_categorical_accuracy: 0.9883
# Epoch 35/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1957 - sparse_categorical_accuracy: 0.1106 - val_loss: 2.8349 - val_sparse_categorical_accuracy: 0.9887
# Epoch 36/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1956 - sparse_categorical_accuracy: 0.1079 - val_loss: 2.8353 - val_sparse_categorical_accuracy: 0.9887
# Epoch 37/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1956 - sparse_categorical_accuracy: 0.1157 - val_loss: 2.8356 - val_sparse_categorical_accuracy: 0.9880
# Epoch 38/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1869 - sparse_categorical_accuracy: 0.1154 - val_loss: 2.8356 - val_sparse_categorical_accuracy: 0.9879
# Epoch 39/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1929 - sparse_categorical_accuracy: 0.1114 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9888
# Epoch 40/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1941 - sparse_categorical_accuracy: 0.1133 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9877
# Epoch 41/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2040 - sparse_categorical_accuracy: 0.1097 - val_loss: 2.8353 - val_sparse_categorical_accuracy: 0.9894
# Epoch 42/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1875 - sparse_categorical_accuracy: 0.1167 - val_loss: 2.8351 - val_sparse_categorical_accuracy: 0.9887
# Epoch 43/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1794 - sparse_categorical_accuracy: 0.1162 - val_loss: 2.8339 - val_sparse_categorical_accuracy: 0.9895
# Epoch 44/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2005 - sparse_categorical_accuracy: 0.1126 - val_loss: 2.8333 - val_sparse_categorical_accuracy: 0.9893
# Epoch 45/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2016 - sparse_categorical_accuracy: 0.1096 - val_loss: 2.8345 - val_sparse_categorical_accuracy: 0.9889
# Epoch 46/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1917 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8345 - val_sparse_categorical_accuracy: 0.9884
# Epoch 47/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1932 - sparse_categorical_accuracy: 0.1099 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9891
# Epoch 48/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1953 - sparse_categorical_accuracy: 0.1128 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9902
# Epoch 49/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1929 - sparse_categorical_accuracy: 0.1094 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9902
# Epoch 50/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1970 - sparse_categorical_accuracy: 0.1135 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9895
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.1969 - sparse_categorical_accuracy: 0.1121 - val_loss: 2.8352 - val_sparse_categorical_accuracy: 0.9900
# Epoch 2/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1954 - sparse_categorical_accuracy: 0.1129 - val_loss: 2.8353 - val_sparse_categorical_accuracy: 0.9895
# Epoch 3/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1909 - sparse_categorical_accuracy: 0.1122 - val_loss: 2.8349 - val_sparse_categorical_accuracy: 0.9885
# Epoch 4/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1920 - sparse_categorical_accuracy: 0.1126 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9893
# Epoch 5/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1942 - sparse_categorical_accuracy: 0.1108 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9869
# Epoch 6/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1941 - sparse_categorical_accuracy: 0.1129 - val_loss: 2.8349 - val_sparse_categorical_accuracy: 0.9882
# Epoch 7/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1948 - sparse_categorical_accuracy: 0.1107 - val_loss: 2.8351 - val_sparse_categorical_accuracy: 0.9880
# Epoch 8/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1901 - sparse_categorical_accuracy: 0.1128 - val_loss: 2.8349 - val_sparse_categorical_accuracy: 0.9894
# Epoch 9/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1946 - sparse_categorical_accuracy: 0.1085 - val_loss: 2.8345 - val_sparse_categorical_accuracy: 0.9894
# Epoch 10/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1893 - sparse_categorical_accuracy: 0.1177 - val_loss: 2.8341 - val_sparse_categorical_accuracy: 0.9873
# Epoch 11/50
# 20/20 [==============================] - 0s 16ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1133 - val_loss: 2.8345 - val_sparse_categorical_accuracy: 0.9893
# Epoch 12/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1963 - sparse_categorical_accuracy: 0.1100 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9898
# Epoch 13/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1930 - sparse_categorical_accuracy: 0.1134 - val_loss: 2.8346 - val_sparse_categorical_accuracy: 0.9882
# Epoch 14/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9877
# Epoch 15/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1927 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8349 - val_sparse_categorical_accuracy: 0.9877
# Epoch 16/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1922 - sparse_categorical_accuracy: 0.1151 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9887
# Epoch 17/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1899 - sparse_categorical_accuracy: 0.1111 - val_loss: 2.8347 - val_sparse_categorical_accuracy: 0.9881
# Epoch 18/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1971 - sparse_categorical_accuracy: 0.1110 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9894
# Epoch 19/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1813 - sparse_categorical_accuracy: 0.1176 - val_loss: 2.8343 - val_sparse_categorical_accuracy: 0.9879
# Epoch 20/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1972 - sparse_categorical_accuracy: 0.1114 - val_loss: 2.8342 - val_sparse_categorical_accuracy: 0.9882
# Epoch 21/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1922 - sparse_categorical_accuracy: 0.1134 - val_loss: 2.8337 - val_sparse_categorical_accuracy: 0.9888
# Epoch 22/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1975 - sparse_categorical_accuracy: 0.1102 - val_loss: 2.8339 - val_sparse_categorical_accuracy: 0.9884
# Epoch 23/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1923 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8341 - val_sparse_categorical_accuracy: 0.9876
# Epoch 24/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1958 - sparse_categorical_accuracy: 0.1122 - val_loss: 2.8344 - val_sparse_categorical_accuracy: 0.9873
# Epoch 25/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1968 - sparse_categorical_accuracy: 0.1107 - val_loss: 2.8346 - val_sparse_categorical_accuracy: 0.9870
# Epoch 26/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2015 - sparse_categorical_accuracy: 0.1117 - val_loss: 2.8356 - val_sparse_categorical_accuracy: 0.9874
# Epoch 27/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1903 - sparse_categorical_accuracy: 0.1147 - val_loss: 2.8354 - val_sparse_categorical_accuracy: 0.9883
# Epoch 28/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1906 - sparse_categorical_accuracy: 0.1138 - val_loss: 2.8354 - val_sparse_categorical_accuracy: 0.9867
# Epoch 29/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1956 - sparse_categorical_accuracy: 0.1099 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9894
# Epoch 30/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1974 - sparse_categorical_accuracy: 0.1088 - val_loss: 2.8352 - val_sparse_categorical_accuracy: 0.9893
# Epoch 31/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1853 - sparse_categorical_accuracy: 0.1117 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9875
# Epoch 32/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1925 - sparse_categorical_accuracy: 0.1125 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9869
# Epoch 33/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2009 - sparse_categorical_accuracy: 0.1072 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9884
# Epoch 34/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1850 - sparse_categorical_accuracy: 0.1144 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9890
# Epoch 35/50
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1933 - sparse_categorical_accuracy: 0.1156 - val_loss: 2.8345 - val_sparse_categorical_accuracy: 0.9877
# Epoch 36/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1929 - sparse_categorical_accuracy: 0.1111 - val_loss: 2.8341 - val_sparse_categorical_accuracy: 0.9877
# Epoch 37/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2011 - sparse_categorical_accuracy: 0.1102 - val_loss: 2.8346 - val_sparse_categorical_accuracy: 0.9875
# Epoch 38/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1949 - sparse_categorical_accuracy: 0.1131 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9879
# Epoch 39/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1901 - sparse_categorical_accuracy: 0.1137 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9876
# Epoch 40/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1945 - sparse_categorical_accuracy: 0.1134 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9870
# Epoch 41/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1911 - sparse_categorical_accuracy: 0.1145 - val_loss: 2.8348 - val_sparse_categorical_accuracy: 0.9896
# Epoch 42/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1964 - sparse_categorical_accuracy: 0.1107 - val_loss: 2.8350 - val_sparse_categorical_accuracy: 0.9880
# Epoch 43/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1928 - sparse_categorical_accuracy: 0.1132 - val_loss: 2.8351 - val_sparse_categorical_accuracy: 0.9877
# Epoch 44/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2049 - sparse_categorical_accuracy: 0.1115 - val_loss: 2.8359 - val_sparse_categorical_accuracy: 0.9872
# Epoch 45/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1875 - sparse_categorical_accuracy: 0.1147 - val_loss: 2.8357 - val_sparse_categorical_accuracy: 0.9876
# Epoch 46/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2013 - sparse_categorical_accuracy: 0.1104 - val_loss: 2.8361 - val_sparse_categorical_accuracy: 0.9890
# Epoch 47/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1986 - sparse_categorical_accuracy: 0.1112 - val_loss: 2.8367 - val_sparse_categorical_accuracy: 0.9866
# Epoch 48/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1979 - sparse_categorical_accuracy: 0.1089 - val_loss: 2.8371 - val_sparse_categorical_accuracy: 0.9872
# Epoch 49/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1965 - sparse_categorical_accuracy: 0.1096 - val_loss: 2.8376 - val_sparse_categorical_accuracy: 0.9894
# Epoch 50/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.1863 - sparse_categorical_accuracy: 0.1142 - val_loss: 2.8370 - val_sparse_categorical_accuracy: 0.9895

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor3, bler_per_iter_dl_tensor3, channel_out3  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (10000, 2, 32)
# SNR: 0.000:-> BLER: 0.98850 BER: 0.46197
# total_bit_error: 46197
# total_msg_error: 9885
# SNR: 0.500:-> BLER: 0.98730 BER: 0.45960
# total_bit_error: 45960
# total_msg_error: 9873
# SNR: 1.000:-> BLER: 0.98470 BER: 0.45529
# total_bit_error: 45529
# total_msg_error: 9847
# SNR: 1.500:-> BLER: 0.98440 BER: 0.44909
# total_bit_error: 44909
# total_msg_error: 9844
# SNR: 2.000:-> BLER: 0.98110 BER: 0.44695
# total_bit_error: 44695
# total_msg_error: 9811
# SNR: 2.500:-> BLER: 0.98090 BER: 0.44346
# total_bit_error: 44346
# total_msg_error: 9809
# SNR: 3.000:-> BLER: 0.97340 BER: 0.43440
# total_bit_error: 43440
# total_msg_error: 9734
# SNR: 3.500:-> BLER: 0.97100 BER: 0.43133
# total_bit_error: 43133
# total_msg_error: 9710
# SNR: 4.000:-> BLER: 0.96670 BER: 0.41788
# total_bit_error: 41788
# total_msg_error: 9667
# SNR: 4.500:-> BLER: 0.96160 BER: 0.41800
# total_bit_error: 41800
# total_msg_error: 9616
# SNR: 5.000:-> BLER: 0.95350 BER: 0.40444
# total_bit_error: 40444
# total_msg_error: 9535
# SNR: 5.500:-> BLER: 0.94610 BER: 0.39670
# total_bit_error: 39670
# total_msg_error: 9461
# SNR: 6.000:-> BLER: 0.93770 BER: 0.38672
# total_bit_error: 38672
# total_msg_error: 9377
# SNR: 6.500:-> BLER: 0.92940 BER: 0.37839
# total_bit_error: 37839
# total_msg_error: 9294
# SNR: 7.000:-> BLER: 0.91690 BER: 0.36240
# total_bit_error: 36240
# total_msg_error: 9169
# SNR: 7.500:-> BLER: 0.89660 BER: 0.34763
# total_bit_error: 34763
# total_msg_error: 8966
# SNR: 8.000:-> BLER: 0.88220 BER: 0.33641
# total_bit_error: 33641
# total_msg_error: 8822
# SNR: 8.500:-> BLER: 0.85940 BER: 0.32057
# total_bit_error: 32057
# total_msg_error: 8594
# SNR: 9.000:-> BLER: 0.83870 BER: 0.30516
# total_bit_error: 30516
# total_msg_error: 8387
# SNR: 9.500:-> BLER: 0.81370 BER: 0.28850
# total_bit_error: 28850
# total_msg_error: 8137
# [1.0478e-01 8.3330e-02 6.6150e-02 5.0480e-02 3.7310e-02 2.4450e-02
#  1.6480e-02 1.0390e-02 5.7400e-03 3.1800e-03 1.3100e-03 8.8000e-04
#  4.2000e-04 6.0000e-05 2.0000e-05 0.0000e+00 0.0000e+00 0.0000e+00
#  0.0000e+00 0.0000e+00]
# [3.732e-01 3.031e-01 2.475e-01 1.933e-01 1.407e-01 9.410e-02 6.480e-02
#  4.080e-02 2.220e-02 1.250e-02 5.400e-03 3.600e-03 1.400e-03 2.000e-04
#  1.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor3,'', label="ai-dl(5x2_30_10)(3)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor3,'', label="ai-dl(5x2_30_10)(3)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 1.0
