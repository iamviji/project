# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Final/CNNAE_5x2_8_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise, BatchNormalization, Conv1D, Activation, Lambda, Flatten

from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 5
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 8
channel_size = 5 


NUM_OF_INPUT_MESSAGE = 1000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    #for i in range (num_of_input):
    #  noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
    #  channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
def PowerNormLayer(x):
    nx =  x / tf.sqrt(tf.reduce_mean(tf.square(x)))
    return nx

# %%
snr_std = Snr2Sigma(7.0)
num_filters = 2**encoder_output_length
print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)

input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_1')(input_message_x)
enc = BatchNormalization(name='enc_2')(enc)
enc = Activation('elu', name='enc_3')(enc)

enc = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='enc_4')(enc)
enc = BatchNormalization(name='enc_5')(enc)
enc = Activation('elu', name='ecn_6')(enc)

enc = Conv1D(filters=2 * channel_size, strides=1, kernel_size=1, name='ch_1')(enc)
enc = BatchNormalization(name='ch_2')(enc)
enc = Activation('linear', name='ch_3')(enc)
enc = Flatten()(enc)
encoder_out = Lambda(PowerNormLayer, name='PowerNorm')(enc)

encoder = Model(input_message_x, encoder_out)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

encoded_input = Input(shape=(num_of_input_block*2*channel_size,))

reshaped_input = tf.reshape (encoded_input, (-1,num_of_input_block,2*channel_size))


dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_1')(reshaped_input)
dec = BatchNormalization(name='dec_2')(dec)
dec = Activation('elu', name='dec_3')(dec)

dec = Conv1D(filters=num_filters, strides=1, kernel_size=1, name='dec_4')(dec)
dec = BatchNormalization(name='dec_5')(dec)
dec = Activation('elu', name='dec_6')(dec)

model_output = Conv1D(filters=2 ** input_block_length, strides=1, kernel_size=1, name='d_10', activation='softmax')(dec)


decoder = Model(encoded_input, model_output)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# enc_1 (Conv1D)               (None, 2, 256)            8448
# _________________________________________________________________
# enc_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# enc_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# enc_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# enc_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# ecn_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# ch_1 (Conv1D)                (None, 2, 10)             2570
# _________________________________________________________________
# ch_2 (BatchNormalization)    (None, 2, 10)             40
# _________________________________________________________________
# ch_3 (Activation)            (None, 2, 10)             0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 20)                0
# _________________________________________________________________
# PowerNorm (Lambda)           (None, 20)                0
# =================================================================
# Total params: 78,898
# Trainable params: 77,854
# Non-trainable params: 1,044
# _________________________________________________________________
# None
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# tf.reshape_3 (TFOpLambda)    (None, 2, 10)             0
# _________________________________________________________________
# dec_1 (Conv1D)               (None, 2, 256)            2816
# _________________________________________________________________
# dec_2 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_3 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# dec_4 (Conv1D)               (None, 2, 256)            65792
# _________________________________________________________________
# dec_5 (BatchNormalization)   (None, 2, 256)            1024
# _________________________________________________________________
# dec_6 (Activation)           (None, 2, 256)            0
# _________________________________________________________________
# d_10 (Conv1D)                (None, 2, 32)             8224
# =================================================================
# Total params: 78,880
# Trainable params: 77,856
# Non-trainable params: 1,024
# _________________________________________________________________
# None
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_9 (Functional)         (None, 20)                78898
# _________________________________________________________________
# gaussian_noise_3 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_10 (Functional)        (None, 2, 32)             78880
# =================================================================
# Total params: 157,778
# Trainable params: 155,710
# Non-trainable params: 2,068
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
training_history1 = dict ()
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  history = autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=500,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
  training_history1 [snr] = history
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 2/2 [==============================] - 2s 436ms/step - loss: 0.5016 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 142ms/step - loss: 0.4960 - sparse_categorical_accuracy: 0.8377 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 138ms/step - loss: 0.4980 - sparse_categorical_accuracy: 0.8357 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.5115 - sparse_categorical_accuracy: 0.8317 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4698 - sparse_categorical_accuracy: 0.8383 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 138ms/step - loss: 0.5091 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 145ms/step - loss: 0.5551 - sparse_categorical_accuracy: 0.8240 - val_loss: 9.8887e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5065 - sparse_categorical_accuracy: 0.8343 - val_loss: 9.8661e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.4596 - sparse_categorical_accuracy: 0.8513 - val_loss: 9.8924e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5013 - sparse_categorical_accuracy: 0.8393 - val_loss: 9.8405e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 140ms/step - loss: 0.5368 - sparse_categorical_accuracy: 0.8213 - val_loss: 9.6157e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5069 - sparse_categorical_accuracy: 0.8390 - val_loss: 9.4087e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 140ms/step - loss: 0.5004 - sparse_categorical_accuracy: 0.8360 - val_loss: 9.2333e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 140ms/step - loss: 0.5597 - sparse_categorical_accuracy: 0.8183 - val_loss: 9.0878e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 138ms/step - loss: 0.5268 - sparse_categorical_accuracy: 0.8427 - val_loss: 8.9754e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 144ms/step - loss: 0.5237 - sparse_categorical_accuracy: 0.8277 - val_loss: 8.9719e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5027 - sparse_categorical_accuracy: 0.8463 - val_loss: 9.0348e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch
-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# ...
# Epoch 12/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.4820 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 156ms/step - loss: 0.4996 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4885 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.4821 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 167ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.8440 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.4763 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 164ms/step - loss: 0.5210 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 156ms/step - loss: 0.4809 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 170ms/step - loss: 0.4913 - sparse_categorical_accuracy: 0.8560 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4792 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5034 - sparse_categorical_accuracy: 0.8365 - val_loss: 9.9783e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5176 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 182ms/step - loss: 0.4895 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.5155 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5011 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 166ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 165ms/step - loss: 0.4666 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.4917 - sparse_categorical_accuracy: 0.8405 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.5326 - sparse_categorical_accuracy: 0.8235 - val_loss: 9.9003e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4907 - sparse_categorical_accuracy: 0.8470 - val_loss: 9.8569e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.5004 - sparse_categorical_accuracy: 0.8440 - val_loss: 9.9178e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5626 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.5007 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 142ms/step - loss: 0.4656 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.4845 - sparse_categorical_accuracy: 0.8440 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4940 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5412 - sparse_categorical_accuracy: 0.8260 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4963 - sparse_categorical_accuracy: 0.8530 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 176ms/step - loss: 0.4912 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.4974 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.4928 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.4910 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5020 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 163ms/step - loss: 0.5015 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 167ms/step - loss: 0.5213 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 177ms/step - loss: 0.5030 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 168ms/step - loss: 0.5112 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4841 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.5238 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.5062 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.5050 - sparse_categorical_accuracy: 0.8485 - val_loss: 9.9185e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 167ms/step - loss: 0.5025 - sparse_categorical_accuracy: 0.8375 - val_loss: 9.9197e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 171ms/step - loss: 0.4660 - sparse_categorical_accuracy: 0.8520 - val_loss: 9.9862e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5020 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 162ms/step - loss: 0.4733 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 172ms/step - loss: 0.5440 - sparse_categorical_accuracy: 0.8280 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5130 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 185ms/step - loss: 0.5022 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 176ms/step - loss: 0.5068 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 162ms/step - loss: 0.4983 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 181ms/step - loss: 0.5101 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 171ms/step - loss: 0.5106 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 176ms/step - loss: 0.5201 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 163ms/step - loss: 0.4986 - sparse_categorical_accuracy: 0.8480 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.4432 - sparse_categorical_accuracy: 0.8580 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 172ms/step - loss: 0.4657 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 179ms/step - loss: 0.5221 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4946 - sparse_categorical_accuracy: 0.8440 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 168ms/step - loss: 0.5398 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 169ms/step - loss: 0.5155 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 171ms/step - loss: 0.4883 - sparse_categorical_accuracy: 0.8530 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5169 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 165ms/step - loss: 0.5182 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 179ms/step - loss: 0.5206 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 163ms/step - loss: 0.4806 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 168ms/step - loss: 0.5004 - sparse_categorical_accuracy: 0.8395 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 171ms/step - loss: 0.4597 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 174ms/step - loss: 0.4843 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.5124 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5041 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.4657 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 179ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4508 - sparse_categorical_accuracy: 0.8570 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5016 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 162ms/step - loss: 0.4458 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 174ms/step - loss: 0.5034 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 180ms/step - loss: 0.4904 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.5360 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 168ms/step - loss: 0.5594 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 163ms/step - loss: 0.4809 - sparse_categorical_accuracy: 0.8490 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 157ms/step - loss: 0.4758 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 179ms/step - loss: 0.5200 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5088 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.4786 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 314ms/step - loss: 0.5328 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4753 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 156ms/step - loss: 0.4932 - sparse_categorical_accuracy: 0.8440 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4607 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.32900  BER: 0.09510
# total: 951
# SNR: 0.500:
#  ->BLER: 0.30500  BER: 0.08620
# total: 862
# SNR: 1.000:
#  ->BLER: 0.24400  BER: 0.06800
# total: 680
# SNR: 1.500:
#  ->BLER: 0.15300  BER: 0.04350
# total: 435
# SNR: 2.000:
#  ->BLER: 0.12000  BER: 0.03170
# total: 317
# SNR: 2.500:
#  ->BLER: 0.07500  BER: 0.02100
# total: 210
# SNR: 3.000:
#  ->BLER: 0.05400  BER: 0.01480
# total: 148
# SNR: 3.500:
#  ->BLER: 0.02700  BER: 0.00740
# total: 74
# SNR: 4.000:
#  ->BLER: 0.01900  BER: 0.00470
# total: 47
# SNR: 4.500:
#  ->BLER: 0.01700  BER: 0.00480
# total: 48
# SNR: 5.000:
#  ->BLER: 0.00200  BER: 0.00050
# total: 5
# SNR: 5.500:
#  ->BLER: 0.00200  BER: 0.00040
# total: 4
# SNR: 6.000:
#  ->BLER: 0.00100  BER: 0.00010
# total: 1
# SNR: 6.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 7.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 7.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.35700 BER: 0.10290
# total_bit_error: 1029
# total_msg_error: 357
# SNR: 0.500:-> BLER: 0.29000 BER: 0.08420
# total_bit_error: 842
# total_msg_error: 290
# SNR: 1.000:-> BLER: 0.19700 BER: 0.05260
# total_bit_error: 526
# total_msg_error: 197
# SNR: 1.500:-> BLER: 0.15000 BER: 0.04150
# total_bit_error: 415
# total_msg_error: 150
# SNR: 2.000:-> BLER: 0.11800 BER: 0.03300
# total_bit_error: 330
# total_msg_error: 118
# SNR: 2.500:-> BLER: 0.08700 BER: 0.02470
# total_bit_error: 247
# total_msg_error: 87
# SNR: 3.000:-> BLER: 0.04900 BER: 0.01450
# total_bit_error: 145
# total_msg_error: 49
# SNR: 3.500:-> BLER: 0.02800 BER: 0.00720
# total_bit_error: 72
# total_msg_error: 28
# SNR: 4.000:-> BLER: 0.02300 BER: 0.00590
# total_bit_error: 59
# total_msg_error: 23
# SNR: 4.500:-> BLER: 0.00600 BER: 0.00110
# total_bit_error: 11
# total_msg_error: 6
# SNR: 5.000:-> BLER: 0.00700 BER: 0.00240
# total_bit_error: 24
# total_msg_error: 7
# SNR: 5.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.000:-> BLER: 0.00200 BER: 0.00030
# total_bit_error: 3
# total_msg_error: 2
# SNR: 6.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.0951 0.0862 0.068  0.0435 0.0317 0.021  0.0148 0.0074 0.0047 0.0048
#  0.0005 0.0004 0.0001 0.     0.     0.     0.     0.     0.     0.    ]
# [0.329 0.305 0.244 0.153 0.12  0.075 0.054 0.027 0.019 0.017 0.002 0.002
#  0.001 0.    0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_8_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
encoded_message = encoder.predict(training_input_message_one_hot)
x = numpy.sqrt(numpy.sum (numpy.square(encoded_message), axis=1))
plt.plot(x)
print (numpy.mean(x))
# Out:
# 4.471089

# %%
import matplotlib.pyplot as plt
encoded_message = encoder.predict(training_input_message_one_hot)
channel_in_array = numpy.transpose(encoded_message)
for i in range (int(channel_size)):
  plt.scatter(channel_in_array[i*2], channel_in_array[i*2+1])
  plt.show()
  plt.hist2d(channel_in_array[i*2], channel_in_array[i*2+1], cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()

# %%
channel_out_array = numpy.transpose(channel_out1)

for i in range (int(channel_size)):
  plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
  plt.colorbar()
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-36118ffb2772> in <module>()
#       2
#       3 for i in range (int(channel_size)):
# ----> 4   plt.hist2d(channel_out_array[2*i], channel_out_array[2*i+1], (50, 50), cmap=plt.cm.jet)
#       5   plt.colorbar()
#       6   plt.show()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
  plt.plot(training_history1[snr].history['loss'], label=snr)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-8e9f3d110dd2> in <module>()
#       1 for snr in (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)):
# ----> 2   plt.plot(training_history1[snr].history['loss'], label=snr)
#       3 plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#
# NameError: name 'training_history1' is not defined

# %%
print (test_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.37200 BER: 0.11050
# total_bit_error: 1105
# total_msg_error: 372
# SNR: 0.500:-> BLER: 0.29000 BER: 0.08660
# total_bit_error: 866
# total_msg_error: 290
# SNR: 1.000:-> BLER: 0.21100 BER: 0.05610
# total_bit_error: 561
# total_msg_error: 211
# SNR: 1.500:-> BLER: 0.15800 BER: 0.04150
# total_bit_error: 415
# total_msg_error: 158
# SNR: 2.000:-> BLER: 0.11900 BER: 0.03270
# total_bit_error: 327
# total_msg_error: 119
# SNR: 2.500:-> BLER: 0.09000 BER: 0.02430
# total_bit_error: 243
# total_msg_error: 90
# SNR: 3.000:-> BLER: 0.05200 BER: 0.01490
# total_bit_error: 149
# total_msg_error: 52
# SNR: 3.500:-> BLER: 0.03100 BER: 0.00880
# total_bit_error: 88
# total_msg_error: 31
# SNR: 4.000:-> BLER: 0.02500 BER: 0.00640
# total_bit_error: 64
# total_msg_error: 25
# SNR: 4.500:-> BLER: 0.01600 BER: 0.00390
# total_bit_error: 39
# total_msg_error: 16
# SNR: 5.000:-> BLER: 0.00800 BER: 0.00200
# total_bit_error: 20
# total_msg_error: 8
# SNR: 5.500:-> BLER: 0.00400 BER: 0.00080
# total_bit_error: 8
# total_msg_error: 4
# SNR: 6.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 6.500:-> BLER: 0.00100 BER: 0.00020
# total_bit_error: 2
# total_msg_error: 1
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.1105 0.0866 0.0561 0.0415 0.0327 0.0243 0.0149 0.0088 0.0064 0.0039
#  0.002  0.0008 0.     0.0002 0.     0.     0.     0.     0.     0.    ]
# [0.372 0.29  0.211 0.158 0.119 0.09  0.052 0.031 0.025 0.016 0.008 0.004
#  0.    0.001 0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(5x2_8_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_8_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_8_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()
