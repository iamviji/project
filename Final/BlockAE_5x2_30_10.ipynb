# %% [markdown]
# <a href="https://colab.research.google.com/github/iamviji/project/blob/master/Final/BlockAE_5x2_30_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,  Reshape, GaussianNoise
from tensorflow.keras import Model
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical





input_block_length = 5
num_of_input_block = 2
input_message_length = input_block_length * num_of_input_block 
encoder_output_length = 30
channel_size = 10


NUM_OF_INPUT_MESSAGE = 1000
SNR_STEP_SIZE = .5

SNR_BEGIN = 0
SNR_END = 10

bler_per_iter_uncoded_commpy_psk_2 = [0.521, 0.473, 0.436, 0.37,  0.304, 0.259, 0.187, 0.138, 0.098, 0.098, 0.052, 0.028, 0.012, 0.011, 0.009, 0.002, 0.0,  0.001, 0.,    0.0]
bler_per_iter_uncoded_itpp_psk_2 = [0.518, 0.478, 0.415, 0.355, 0.305, 0.227, 0.177, 0.149, 0.11,  0.075, 0.055, 0.023, 0.014, 0.014, 0.015, 0.001, 0.003, 0.001, 0.,    0. ]
bler_per_iter_uncoded_commpy_psk_4 = [0.815, 0.793, 0.75,  0.714, 0.64,  0.639, 0.526, 0.49,  0.433, 0.371, 0.335, 0.236, 0.204, 0.154, 0.129, 0.08,  0.063, 0.046, 0.023, 0.018]
bler_per_iter_uncoded_itpp_psk_4 = [0.814, 0.767, 0.729, 0.702, 0.66,  0.616, 0.563, 0.511, 0.442, 0.4,   0.294, 0.277, 0.228, 0.17,  0.114, 0.087, 0.05,  0.037, 0.022, 0.017]
bler_per_iter_ldpc_itpp_psk_4 = [0.584, 0.488, 0.404, 0.332, 0.218, 0.151, 0.097, 0.058, 0.041, 0.024, 0.007, 0.004, 0.002, 0.001, 0.001, 0.,    0.,    0.,    0.,    0.,   ]
bler_per_iter_ham_itpp_psk_4 = [0.51, 0.479, 0.419, 0.333, 0.313, 0.247, 0.212, 0.132, 0.114, 0.093, 0.042, 0.027, 0.024, 0.016, 0.006, 0.005, 0.003, 0.002, 0.,    0.  ]
bler_per_iter_uncoded_itpp_psk_8 = [0.921, 0.917, 0.912, 0.867, 0.86,  0.857, 0.826, 0.808, 0.77,  0.737, 0.704, 0.657, 0.608, 0.6,   0.547, 0.487, 0.426, 0.361, 0.323, 0.293]
bler_per_iter_uncoded_commpy_psk_8 = [0.923, 0.912, 0.891, 0.888, 0.874, 0.851, 0.804, 0.779, 0.758, 0.736, 0.715, 0.643, 0.614, 0.557, 0.542, 0.503, 0.431, 0.386, 0.331, 0.289]

ber_per_iter_uncoded_itpp_psk_2 = [0.07933333, 0.067, 0.058, 0.04811111, 0.039, 0.02911111, 0.02211111, 0.01833333, 0.01266667, 0.00866667, 0.00622222, 0.00255556, 0.00166667, 0.00155556, 0.00166667, 0.00011111, 0.00033333, 0.00011111, 0., 0.]
ber_per_iter_uncoded_commpy_psk_2 = [0.07955556, 0.07055556, 0.05344444, 0.04477778, 0.03644444, 0.02888889, 0.02055556, 0.01955556, 0.01033333, 0.00855556, 0.00522222, 0.004, 0.00188889, 0.00155556, 0.00055556, 0.00066667, 0.00022222, 0.00011111, 0., 0.]
ber_per_iter_uncoded_itpp_psk_4 = [0.1559, 0.1421, 0.1248, 0.1137, 0.1031, 0.0924, 0.0802, 0.0684, 0.055,  0.0499, 0.0348, 0.0336, 0.0257, 0.0185, 0.0121, 0.0092, 0.0054, 0.0037, 0.0022, 0.0017]
ber_per_iter_uncoded_commpy_psk_4 = [0.2137, 0.1943, 0.1773, 0.1624, 0.1473, 0.1355, 0.1105, 0.0984, 0.0873, 0.0686, 0.0573, 0.0454, 0.0356, 0.024,  0.0214, 0.0142, 0.0111, 0.0055, 0.0038, 0.002]
ber_per_iter_uncoded_itpp_psk_8 = [0.24566667, 0.23411111, 0.21455556, 0.19888889, 0.188, 0.184, 0.16355556, 0.15655556, 0.13777778, 0.12966667, 0.115, 0.10622222, 0.09211111, 0.088, 0.07622222, 0.06855556, 0.05677778, 0.04755556, 0.04188889, 0.03577778]
ber_per_iter_uncoded_commpy_psk_8 = [0.32577778, 0.31533333, 0.30455556, 0.29644444, 0.27955556, 0.266, 0.24677778, 0.23411111, 0.22088889, 0.209,      0.19577778, 0.17544444, 0.15844444, 0.13966667, 0.13533333, 0.12077778, 0.10211111, 0.09066667, 0.07544444, 0.06355556]
ber_per_iter_ldpc_itpp_psk_4 = [1.25444444e-01, 1.19111111e-01, 9.48888889e-02, 7.54444444e-02, 5.50000000e-02, 3.86666667e-02, 2.51111111e-02, 1.53333333e-02, 1.04444444e-02, 1.22222222e-03, 2.88888889e-03, 0.00000000e+00, 1.11111111e-04, 3.33333333e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]


import numpy as np #for numerical computing
import matplotlib.pyplot as plt #for plotting functions
from scipy.special import erfc
import math
#ref : https://core.ac.uk/download/pdf/235049678.pdf
EbN0dBs = np.arange(start=0,stop = 10.5, step = .5)
PSK_2_BER_theory = 0.5*erfc(np.sqrt(10**(EbN0dBs/10)))
M=4
#QAM_BER_theory = 2*(1-np.sqrt(1/M))*erfc(np.sqrt(10**(EbN0dBs/10)))
QAM_BER_theory = erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
PSK_4_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
M=8
PSK_8_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
QAM_8_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
M=16
PSK_16_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))
#QAM_16_BER_theory = 2*erfc(np.sqrt(math.log2(M)*3/(2*(M-1)))*np.sqrt(10**(EbN0dBs/10)))
QAM_16_BER_theory = (3.0/2)*erfc(np.sqrt((4.0/10))*np.sqrt(10**(EbN0dBs/10)))
                     #(3.0/2)*special.erfc(np.sqrt((4.0/10)*10.**(ebno/10)))
M=32
PSK_32_BER_theory = erfc(math.sin(math.pi/M)*np.sqrt(10**(EbN0dBs/10)))


def Snr2Sigma(snr):
  sigma = (10 ** (- snr / 20))  #*(numpy.sqrt(2))
  return sigma


def timer_update(i,current,time_tot,tic_incr=500):
    last = current
    current = time.time()
    t_diff = current-last
    print('SNR: {:04.3f} - Iter: {} - Last {} iterations took {:03.2f}s'.format(snr,i+1,tic_incr,t_diff))
    return time_tot + t_diff

# %%
def conv_to_binary_from_decimal (decimal,input_message_size, input_message_length):
  binary = numpy.random.randint(1, size=(input_message_size,input_message_length))
  for i in range (input_message_size):
    bin = [int(x) for x in list('{0:0b}'.format(decimal[0][i]))]
    #print(bin)
    for j in range (len(bin)):
      offset = input_message_length - len(bin)
      #print ("x",offset)
      binary [i][j+offset] = bin [j]
  return binary

def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
  binary = numpy.random.randint(1, size=(num_of_input,num_of_block, block_size))
  for i in range (num_of_input):
      for j in range (num_of_block):
        #print ("xxx", input[i][j])
        bin = [int(x) for x in list('{0:0b}'.format(input[i][j][0]))]
        #print(bin)
        for k in range (len(bin)):
          offset = block_size - len(bin)
          #print ("x",offset)
          binary [i][j][k+offset] = bin [k]
  return binary

def GetBerBler (input_message_binary1, input_message_binary2):
  diff = abs(input_message_binary1 - input_message_binary2)
  field_sum = numpy.sum (diff, axis=1)
  field_sum = numpy.reshape (field_sum, (-1,1))
  ber = numpy.sum(field_sum)/(input_message_binary1.shape[0]*input_message_binary1.shape[1])
  field_non_zero_count = numpy.count_nonzero(field_sum != 0, axis=1)
  bler = numpy.sum(field_non_zero_count)/field_non_zero_count.shape[0]
  return ber, bler

def get_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_binary, num_of_input_msg, input_message_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:
    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    for i in range (num_of_input_msg):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])
    decoded_message = decoder.predict(noised_message)
    decoded_message_decimal = []
    decoded_message_decimal.append(numpy.argmax(decoded_message, axis=1))
    decoded_message_binary = conv_to_binary_from_decimal (decoded_message_decimal, num_of_input_msg,  input_message_length)
    ber,bler = GetBerBler (input_binary, decoded_message_binary)
    print('SNR: {:04.3f}:-> BLER: {:03.3f} BER: {:03.3f}'.format(snr,bler,ber))
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

def get_block_onehot_ber_bler_of_model (snr_list, encoder, decoder, input_onehot, input_decimal, num_of_input,num_of_input_block, input_block_length, channel_size, verbose=1):
  bler_per_iter_dl_tensor  = numpy.array(())
  ber_per_iter_dl_tensor  = numpy.array(())
  channel_out = []
  encoded_message = encoder.predict(input_onehot)
  for snr in snr_list:

    total_bit_error = 0
    total_msg_error = 0    
    sigma = Snr2Sigma (snr)

    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)

    for i in range (num_of_input):
      noised_message[i] = encoded_message[i] + numpy.random.normal(0, sigma, [1,2*channel_size])
      channel_out.append(noised_message[i])

    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))

    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, num_of_input, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (input_decimal, num_of_input, num_of_input_block, input_block_length)   
    diff = abs(decoded_message_binary - input_message_binary)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    block_error = numpy.count_nonzero(diff_sum!=0)
    bit_error = numpy.sum(diff_sum)
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    bler = float(total_msg_error)/(num_of_input)
    ber = float(total_bit_error)/(num_of_input*num_of_input_block*input_block_length)
    print('SNR: {:04.3f}:-> BLER: {:03.5f} BER: {:03.5f} '.format(snr,bler,ber))
    print ("total_bit_error:", total_bit_error)
    print ("total_msg_error:", total_msg_error)
    bler_per_iter_dl_tensor = numpy.append(bler_per_iter_dl_tensor, bler)
    ber_per_iter_dl_tensor = numpy.append(ber_per_iter_dl_tensor, ber)
  return ber_per_iter_dl_tensor, bler_per_iter_dl_tensor, channel_out

# %%
snr_std = Snr2Sigma(7.0)

print ("num_of_input_block", num_of_input_block)
print ("input_block_length", input_block_length)
train_batch_size = 500
input_message_x = Input(shape=(num_of_input_block, 2**input_block_length), name="inputs")
# "encoded" is the encoded representation of the input
#reshaped_input = tf.reshape (input_message_x, (tf.shape(input_message_x)[0],tf.shape(input_message_x)[1]*tf.shape(input_message_x)[2]))
reshaped_input = tf.reshape (input_message_x, (-1,num_of_input_block*2**input_block_length))
#reshaped_input =  Reshape((1,num_of_input_block*2**input_block_length))

enc_layer1 = Dense(encoder_output_length, activation='tanh', name="enc_layer1")(reshaped_input)
enc_layer2 = Dense(2*channel_size, activation='tanh', name="enc_layer2")(enc_layer1)
enc_layer3 =  enc_layer2 / tf.sqrt(tf.reduce_mean(tf.square(enc_layer2)))
encoder = Model(input_message_x, enc_layer3)

awgn_channel = GaussianNoise(Snr2Sigma(snr_std),input_shape=(2*channel_size,))

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(2*channel_size,))
dec_layer1 = Dense(num_of_input_block*2**input_block_length, activation='sigmoid', name="dec_layer1")(encoded_input)
#dec_layer2 = Dense(num_of_input_block*2**input_block_length, activation="sigmoid")(dec_layer1)
reshaped_output = tf.reshape (dec_layer1, (-1,num_of_input_block,2**input_block_length))
dec_layer2 = Dense((2**input_block_length), activation="softmax", name="dec_layer2")(reshaped_output)
# this model maps an encoded input to its decoder representation
decoder = Model(encoded_input, dec_layer2)

# this model maps an input to its reconstruction
autoencoder = Model(input_message_x, decoder(awgn_channel(encoder(input_message_x))))


print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# num_of_input_block 2
# input_block_length 5
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 2, 32)]      0
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 64)           0           inputs[0][0]
# __________________________________________________________________________________________________
# enc_layer1 (Dense)              (None, 30)           1950        tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# enc_layer2 (Dense)              (None, 20)           620         enc_layer1[0][0]
# __________________________________________________________________________________________________
# tf.math.square_2 (TFOpLambda)   (None, 20)           0           enc_layer2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_2 (TFOpLamb ()                   0           tf.math.square_2[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt_2 (TFOpLambda)     ()                   0           tf.math.reduce_mean_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_2 (TFOpLambda)  (None, 20)           0           enc_layer2[0][0]
#                                                                  tf.math.sqrt_2[0][0]
# ==================================================================================================
# Total params: 2,570
# Trainable params: 2,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dec_layer1 (Dense)           (None, 64)                1344
# _________________________________________________________________
# tf.reshape_5 (TFOpLambda)    (None, 2, 32)             0
# _________________________________________________________________
# dec_layer2 (Dense)           (None, 2, 32)             1056
# =================================================================
# Total params: 2,400
# Trainable params: 2,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 2, 32)]           0
# _________________________________________________________________
# model_6 (Functional)         (None, 20)                2570
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 20)                0
# _________________________________________________________________
# model_7 (Functional)         (None, 2, 32)             2400
# =================================================================
# Total params: 4,970
# Trainable params: 4,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
training_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(training_input_message)
training_input_message_one_hot = to_categorical(y=training_input_message, num_classes=2**input_block_length)
#print(training_input_message_one_hot)

test_input_message = numpy.random.randint(2**input_block_length, size=(NUM_OF_INPUT_MESSAGE,num_of_input_block,1))
#print(test_input_message)
test_input_message_one_hot = to_categorical(y=test_input_message, num_classes=2**input_block_length)
#print(test_input_message_one_hot)

# %%
import keras
autoencoder.compile(optimizer=keras.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
for snr in (numpy.arange (0, 10, SNR_STEP_SIZE)):
  sigma = 1.0*Snr2Sigma (snr)
  snr_std = sigma
  print ("Training for SNR=", snr, " sigma=", sigma) 
  autoencoder.fit(training_input_message_one_hot, training_input_message,
                epochs=50,
                batch_size=train_batch_size,
                shuffle=False,
                validation_data=(test_input_message_one_hot, test_input_message))
# Out:
# Training for SNR= 0.0  sigma= 1.0
# Epoch 1/50
# 2/2 [==============================] - 1s 180ms/step - loss: 3.6591 - sparse_categorical_accuracy: 0.0283 - val_loss: 3.6444 - val_sparse_categorical_accuracy: 0.0320
# Epoch 2/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.6268 - sparse_categorical_accuracy: 0.0277 - val_loss: 3.6121 - val_sparse_categorical_accuracy: 0.0365
# Epoch 3/50
# 2/2 [==============================] - 0s 34ms/step - loss: 3.5930 - sparse_categorical_accuracy: 0.0320 - val_loss: 3.5814 - val_sparse_categorical_accuracy: 0.0365
# Epoch 4/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.5663 - sparse_categorical_accuracy: 0.0307 - val_loss: 3.5524 - val_sparse_categorical_accuracy: 0.0390
# Epoch 5/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.5438 - sparse_categorical_accuracy: 0.0310 - val_loss: 3.5250 - val_sparse_categorical_accuracy: 0.0420
# Epoch 6/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.5141 - sparse_categorical_accuracy: 0.0317 - val_loss: 3.4992 - val_sparse_categorical_accuracy: 0.0435
# Epoch 7/50
# 2/2 [==============================] - 0s 40ms/step - loss: 3.4843 - sparse_categorical_accuracy: 0.0467 - val_loss: 3.4749 - val_sparse_categorical_accuracy: 0.0480
# Epoch 8/50
# 2/2 [==============================] - 0s 39ms/step - loss: 3.4664 - sparse_categorical_accuracy: 0.0367 - val_loss: 3.4520 - val_sparse_categorical_accuracy: 0.0500
# Epoch 9/50
# 2/2 [==============================] - 0s 37ms/step - loss: 3.4487 - sparse_categorical_accuracy: 0.0397 - val_loss: 3.4305 - val_sparse_categorical_accuracy: 0.0555
# Epoch 10/50
# 2/2 [==============================] - 0s 38ms/step - loss: 3.4273 - sparse_categorical_accuracy: 0.0403 - val_loss: 3.4103 - val_sparse_categorical_accuracy: 0.0575
# Epoch 11/50
# 2/2 [==============================] - 0s 46ms/step - loss: 3.3970 - sparse_categorical_accuracy: 0.0583 - val_loss: 3.3911 - val_sparse_categorical_accuracy: 0.0605
# Epoch 12/50
# 2/2 [==============================] - 0s 218ms/step - loss: 3.3833 - sparse_categorical_accuracy: 0.0587 - val_loss: 3.3729 - val_sparse_categorical_accuracy: 0.0655
# Epoch 13/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.3678 - sparse_categorical_accuracy: 0.0623 - val_loss: 3.3556 - val_sparse_categorical_accuracy: 0.0755
# Epoch 14/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.3532 - sparse_categorical_accuracy: 0.0630 - val_loss: 3.3389 - val_sparse_categorical_accuracy: 0.0860
# Epoch 15/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.3338 - sparse_categorical_accuracy: 0.0783 - val_loss: 3.3228 - val_sparse_categorical_accuracy: 0.0955
# Epoch 16/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.3227 - sparse_categorical_accuracy: 0.0867 - val_loss: 3.3071 - val_sparse_categorical_accuracy: 0.1100
# Epoch 17/50
# 2/2 [==============================] - 0s 40ms/step - loss: 3.3054 - sparse_categorical_accuracy: 0.1013 - val_loss: 3.2918 - val_sparse_categorical_accuracy: 0.1285
# Epoch 18/50
# 2/2 [==============================] - 0s 38ms/step - loss: 3.2863 - sparse_categorical_accuracy: 0.1067 - val_loss: 3.2767 - val_sparse_categorical_accuracy: 0.1465
# Epoch 19/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.2780 - sparse_categorical_accuracy: 0.1083 - val_loss: 3.2619 - val_sparse_categorical_accuracy: 0.1620
# Epoch 20/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.2665 - sparse_categorical_accuracy: 0.1237 - val_loss: 3.2472 - val_sparse_categorical_accuracy: 0.1805
# Epoch 21/50
# 2/2 [==============================] - 0s 43ms/step - loss: 3.2480 - sparse_categorical_accuracy: 0.1503 - val_loss: 3.2328 - val_sparse_categorical_accuracy: 0.1955
# Epoch 22/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.2250 - sparse_categorical_accuracy: 0.1560 - val_loss: 3.2184 - val_sparse_categorical_accuracy: 0.2110
# Epoch 23/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.2243 - sparse_categorical_accuracy: 0.1713 - val_loss: 3.2042 - val_sparse_categorical_accuracy: 0.2195
# Epoch 24/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.2080 - sparse_categorical_accuracy: 0.1727 - val_loss: 3.1901 - val_sparse_categorical_accuracy: 0.2345
# Epoch 25/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.1929 - sparse_categorical_accuracy: 0.1947 - val_loss: 3.1762 - val_sparse_categorical_accuracy: 0.2525
# Epoch 26/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.1819 - sparse_categorical_accuracy: 0.2047 - val_loss: 3.1625 - val_sparse_categorical_accuracy: 0.2710
# Epoch 27/50
# 2/2 [==============================] - 0s 34ms/step - loss: 3.1595 - sparse_categorical_accuracy: 0.2267 - val_loss: 3.1488 - val_sparse_categorical_accuracy: 0.2830
# Epoch 28/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.1600 - sparse_categorical_accuracy: 0.2233 - val_loss: 3.1352 - val_sparse_categorical_accuracy: 0.3080
# Epoch 29/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.1376 - sparse_categorical_accuracy: 0.2463 - val_loss: 3.1217 - val_sparse_categorical_accuracy: 0.3360
# Epoch 30/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.1278 - sparse_categorical_accuracy: 0.2520 - val_loss: 3.1083 - val_sparse_categorical_accuracy: 0.3480
# Epoch 31/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.1121 - sparse_categorical_accuracy: 0.2607 - val_loss: 3.0949 - val_sparse_categorical_accuracy: 0.3590
# Epoch 32/50
# 2/2 [==============================] - 0s 41ms/step - loss: 3.1024 - sparse_categorical_accuracy: 0.2727 - val_loss: 3.0815 - val_sparse_categorical_accuracy: 0.3685
# Epoch 33/50
# 2/2 [==============================] - 0s 40ms/step - loss: 3.0884 - sparse_categorical_accuracy: 0.2907 - val_loss: 3.0682 - val_sparse_categorical_accuracy: 0.3725
# Epoch 34/50
# 2/2 [==============================] - 0s 46ms/step - loss: 3.0836 - sparse_categorical_accuracy: 0.2853 - val_loss: 3.0548 - val_sparse_categorical_accuracy: 0.3810
# Epoch 35/50
# 2/2 [==============================] - 0s 39ms/step - loss: 3.0640 - sparse_categorical_accuracy: 0.2853 - val_loss: 3.0414 - val_sparse_categorical_accuracy: 0.3795
# Epoch 36/50
# 2/2 [==============================] - 0s 37ms/step - loss: 3.0590 - sparse_categorical_accuracy: 0.2903 - val_loss: 3.0280 - val_sparse_categorical_accuracy: 0.3915
# Epoch 37/50
# 2/2 [==============================] - 0s 34ms/step - loss: 3.0375 - sparse_categorical_accuracy: 0.3070 - val_loss: 3.0146 - val_sparse_categorical_accuracy: 0.4000
# Epoch 38/50
# 2/2 [==============================] - 0s 37ms/step - loss: 3.0309 - sparse_categorical_accuracy: 0.3260 - val_loss: 3.0012 - val_sparse_categorical_accuracy: 0.4050
# Epoch 39/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.0245 - sparse_categorical_accuracy: 0.3080 - val_loss: 2.9877 - val_sparse_categorical_accuracy: 0.4090
# Epoch 40/50
# 2/2 [==============================] - 0s 37ms/step - loss: 3.0069 - sparse_categorical_accuracy: 0.3340 - val_loss: 2.9742 - val_sparse_categorical_accuracy: 0.4135
# Epoch 41/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.9863 - sparse_categorical_accuracy: 0.3280 - val_loss: 2.9607 - val_sparse_categorical_accuracy: 0.4240
# Epoch 42/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.9888 - sparse_categorical_accuracy: 0.3383 - val_loss: 2.9471 - val_sparse_categorical_accuracy: 0.4295
# Epoch 43/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.9640 - sparse_categorical_accuracy: 0.3497 - val_loss: 2.9335 - val_sparse_categorical_accuracy: 0.4385
# Epoch 44/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.9592 - sparse_categorical_accuracy: 0.3633 - val_loss: 2.9199 - val_sparse_categorical_accuracy: 0.4460
# Epoch 45/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.9435 - sparse_categorical_accuracy: 0.3557 - val_loss: 2.9063 - val_sparse_categorical_accuracy: 0.4520
# Epoch 46/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.9373 - sparse_categorical_accuracy: 0.3477 - val_loss: 2.8926 - val_sparse_categorical_accuracy: 0.4590
# Epoch 47/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.9270 - sparse_categorical_accuracy: 0.3580 - val_loss: 2.8790 - val_sparse_categorical_accuracy: 0.4660
# Epoch 48/50
# 2/2 [==============================] - 0s 43ms/step - loss: 2.9061 - sparse_categorical_accuracy: 0.3630 - val_loss: 2.8653 - val_sparse_categorical_accuracy: 0.4845
# Epoch 49/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.8981 - sparse_categorical_accuracy: 0.3680 - val_loss: 2.8516 - val_sparse_categorical_accuracy: 0.4935
# Epoch 50/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.8953 - sparse_categorical_accuracy: 0.3823 - val_loss: 2.8379 - val_sparse_categorical_accuracy: 0.5025
# Training for SNR= 0.5  sigma= 0.9440608762859234
# Epoch 1/50
# 2/2 [==============================] - 0s 68ms/step - loss: 2.8728 - sparse_categorical_accuracy: 0.3870 - val_loss: 2.8242 - val_sparse_categorical_accuracy: 0.5110
# Epoch 2/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.8603 - sparse_categorical_accuracy: 0.3860 - val_loss: 2.8105 - val_sparse_categorical_accuracy: 0.5140
# Epoch 3/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.8519 - sparse_categorical_accuracy: 0.3955 - val_loss: 2.7968 - val_sparse_categorical_accuracy: 0.5200
# Epoch 4/50
# 2/2 [==============================] - 0s 42ms/step - loss: 2.8308 - sparse_categorical_accuracy: 0.4005 - val_loss: 2.7830 - val_sparse_categorical_accuracy: 0.5280
# Epoch 5/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.8257 - sparse_categorical_accuracy: 0.3925 - val_loss: 2.7692 - val_sparse_categorical_accuracy: 0.5325
# Epoch 6/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.8159 - sparse_categorical_accuracy: 0.4110 - val_loss: 2.7554 - val_sparse_categorical_accuracy: 0.5350
# Epoch 7/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.8033 - sparse_categorical_accuracy: 0.4150 - val_loss: 2.7416 - val_sparse_categorical_accuracy: 0.5435
# Epoch 8/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.7875 - sparse_categorical_accuracy: 0.4170 - val_loss: 2.7278 - val_sparse_categorical_accuracy: 0.5530
# Epoch 9/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.7841 - sparse_categorical_accuracy: 0.4175 - val_loss: 2.7140 - val_sparse_categorical_accuracy: 0.5580
# Epoch 10/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.7649 - sparse_categorical_accuracy: 0.4300 - val_loss: 2.7001 - val_sparse_categorical_accuracy: 0.5680
# Epoch 11/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.7514 - sparse_categorical_accuracy: 0.4375 - val_loss: 2.6863 - val_sparse_categorical_accuracy: 0.5750
# Epoch 12/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.7394 - sparse_categorical_accuracy: 0.4480 - val_loss: 2.6724 - val_sparse_categorical_accuracy: 0.5795
# Epoch 13/50
# 2/2 [==============================] - 0s 140ms/step - loss: 2.7301 - sparse_categorical_accuracy: 0.4370 - val_loss: 2.6585 - val_sparse_categorical_accuracy: 0.5885
# Epoch 14/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.7192 - sparse_categorical_accuracy: 0.4550 - val_loss: 2.6446 - val_sparse_categorical_accuracy: 0.5950
# Epoch 15/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.7171 - sparse_categorical_accuracy: 0.4450 - val_loss: 2.6307 - val_sparse_categorical_accuracy: 0.5990
# Epoch 16/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.6922 - sparse_categorical_accuracy: 0.4530 - val_loss: 2.6168 - val_sparse_categorical_accuracy: 0.5985
# Epoch 17/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.6860 - sparse_categorical_accuracy: 0.4605 - val_loss: 2.6030 - val_sparse_categorical_accuracy: 0.6035
# Epoch 18/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.6681 - sparse_categorical_accuracy: 0.4790 - val_loss: 2.5891 - val_sparse_categorical_accuracy: 0.6050
# Epoch 19/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.6570 - sparse_categorical_accuracy: 0.4710 - val_loss: 2.5752 - val_sparse_categorical_accuracy: 0.6140
# Epoch 20/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.6540 - sparse_categorical_accuracy: 0.4685 - val_loss: 2.5613 - val_sparse_categorical_accuracy: 0.6205
# Epoch 21/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.6316 - sparse_categorical_accuracy: 0.4755 - val_loss: 2.5474 - val_sparse_categorical_accuracy: 0.6250
# Epoch 22/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.6247 - sparse_categorical_accuracy: 0.4685 - val_loss: 2.5335 - val_sparse_categorical_accuracy: 0.6325
# Epoch 23/50
# 2/2 [==============================] - 0s 42ms/step - loss: 2.6104 - sparse_categorical_accuracy: 0.4800 - val_loss: 2.5196 - val_sparse_categorical_accuracy: 0.6425
# Epoch 24/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.5920 - sparse_categorical_accuracy: 0.4805 - val_loss: 2.5056 - val_sparse_categorical_accuracy: 0.6540
# Epoch 25/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.5888 - sparse_categorical_accuracy: 0.5010 - val_loss: 2.4917 - val_sparse_categorical_accuracy: 0.6580
# Epoch 26/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.5745 - sparse_categorical_accuracy: 0.5065 - val_loss: 2.4778 - val_sparse_categorical_accuracy: 0.6635
# Epoch 27/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.5641 - sparse_categorical_accuracy: 0.4950 - val_loss: 2.4639 - val_sparse_categorical_accuracy: 0.6700
# Epoch 28/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.5580 - sparse_categorical_accuracy: 0.4860 - val_loss: 2.4499 - val_sparse_categorical_accuracy: 0.6775
# Epoch 29/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.5287 - sparse_categorical_accuracy: 0.5080 - val_loss: 2.4360 - val_sparse_categorical_accuracy: 0.6840
# Epoch 30/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.5368 - sparse_categorical_accuracy: 0.5140 - val_loss: 2.4221 - val_sparse_categorical_accuracy: 0.6920
# Epoch 31/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.5160 - sparse_categorical_accuracy: 0.5060 - val_loss: 2.4082 - val_sparse_categorical_accuracy: 0.7010
# Epoch 32/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.5020 - sparse_categorical_accuracy: 0.5285 - val_loss: 2.3944 - val_sparse_categorical_accuracy: 0.7030
# Epoch 33/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.4968 - sparse_categorical_accuracy: 0.5225 - val_loss: 2.3805 - val_sparse_categorical_accuracy: 0.7070
# Epoch 34/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4887 - sparse_categorical_accuracy: 0.5225 - val_loss: 2.3667 - val_sparse_categorical_accuracy: 0.7130
# Epoch 35/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4661 - sparse_categorical_accuracy: 0.5490 - val_loss: 2.3528 - val_sparse_categorical_accuracy: 0.7200
# Epoch 36/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.4643 - sparse_categorical_accuracy: 0.5200 - val_loss: 2.3389 - val_sparse_categorical_accuracy: 0.7255
# Epoch 37/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.4549 - sparse_categorical_accuracy: 0.5215 - val_loss: 2.3251 - val_sparse_categorical_accuracy: 0.7350
# Epoch 38/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.4525 - sparse_categorical_accuracy: 0.5345 - val_loss: 2.3113 - val_sparse_categorical_accuracy: 0.7455
# Epoch 39/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.4307 - sparse_categorical_accuracy: 0.5370 - val_loss: 2.2974 - val_sparse_categorical_accuracy: 0.7445
# Epoch 40/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.4215 - sparse_categorical_accuracy: 0.5245 - val_loss: 2.2837 - val_sparse_categorical_accuracy: 0.7505
# Epoch 41/50
# 2/2 [==============================] - 0s 42ms/step - loss: 2.4070 - sparse_categorical_accuracy: 0.5560 - val_loss: 2.2700 - val_sparse_categorical_accuracy: 0.7560
# Epoch 42/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.4027 - sparse_categorical_accuracy: 0.5440 - val_loss: 2.2563 - val_sparse_categorical_accuracy: 0.7605
# Epoch 43/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.3876 - sparse_categorical_accuracy: 0.5495 - val_loss: 2.2427 - val_sparse_categorical_accuracy: 0.7665
# Epoch 44/50
# 2/2 [==============================] - 0s 48ms/step - loss: 2.3667 - sparse_categorical_accuracy: 0.5520 - val_loss: 2.2290 - val_sparse_categorical_accuracy: 0.7740
# Epoch 45/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.3715 - sparse_categorical_accuracy: 0.5555 - val_loss: 2.2154 - val_sparse_categorical_accuracy: 0.7795
# Epoch 46/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.3525 - sparse_categorical_accuracy: 0.5560 - val_loss: 2.2019 - val_sparse_categorical_accuracy: 0.7830
# Epoch 47/50
# 2/2 [==============================] - 0s 56ms/step - loss: 2.3486 - sparse_categorical_accuracy: 0.5530 - val_loss: 2.1882 - val_sparse_categorical_accuracy: 0.7870
# Epoch 48/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.3352 - sparse_categorical_accuracy: 0.5490 - val_loss: 2.1746 - val_sparse_categorical_accuracy: 0.7960
# Epoch 49/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.3274 - sparse_categorical_accuracy: 0.5640 - val_loss: 2.1610 - val_sparse_categorical_accuracy: 0.8020
# Epoch 50/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.3061 - sparse_categorical_accuracy: 0.5820 - val_loss: 2.1476 - val_sparse_categorical_accuracy: 0.8070
# Training for SNR= 1.0  sigma= 0.8912509381337456
# Epoch 1/50
# 2/2 [==============================] - 0s 68ms/step - loss: 2.3187 - sparse_categorical_accuracy: 0.5600 - val_loss: 2.1342 - val_sparse_categorical_accuracy: 0.8100
# Epoch 2/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.2898 - sparse_categorical_accuracy: 0.5830 - val_loss: 2.1207 - val_sparse_categorical_accuracy: 0.8165
# Epoch 3/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.2798 - sparse_categorical_accuracy: 0.5905 - val_loss: 2.1074 - val_sparse_categorical_accuracy: 0.8205
# Epoch 4/50
# 2/2 [==============================] - 0s 148ms/step - loss: 2.2814 - sparse_categorical_accuracy: 0.5760 - val_loss: 2.0942 - val_sparse_categorical_accuracy: 0.8190
# Epoch 5/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.2639 - sparse_categorical_accuracy: 0.5890 - val_loss: 2.0810 - val_sparse_categorical_accuracy: 0.8215
# Epoch 6/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.2573 - sparse_categorical_accuracy: 0.5720 - val_loss: 2.0676 - val_sparse_categorical_accuracy: 0.8240
# Epoch 7/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.2323 - sparse_categorical_accuracy: 0.5915 - val_loss: 2.0542 - val_sparse_categorical_accuracy: 0.8295
# Epoch 8/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.2215 - sparse_categorical_accuracy: 0.5960 - val_loss: 2.0410 - val_sparse_categorical_accuracy: 0.8330
# Epoch 9/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.2280 - sparse_categorical_accuracy: 0.5740 - val_loss: 2.0278 - val_sparse_categorical_accuracy: 0.8395
# Epoch 10/50
# 2/2 [==============================] - 0s 52ms/step - loss: 2.2125 - sparse_categorical_accuracy: 0.5985 - val_loss: 2.0147 - val_sparse_categorical_accuracy: 0.8445
# Epoch 11/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.2036 - sparse_categorical_accuracy: 0.6030 - val_loss: 2.0016 - val_sparse_categorical_accuracy: 0.8490
# Epoch 12/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.1953 - sparse_categorical_accuracy: 0.5860 - val_loss: 1.9886 - val_sparse_categorical_accuracy: 0.8525
# Epoch 13/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.1792 - sparse_categorical_accuracy: 0.5985 - val_loss: 1.9757 - val_sparse_categorical_accuracy: 0.8550
# Epoch 14/50
# 2/2 [==============================] - 0s 39ms/step - loss: 2.1517 - sparse_categorical_accuracy: 0.6050 - val_loss: 1.9626 - val_sparse_categorical_accuracy: 0.8570
# Epoch 15/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.1512 - sparse_categorical_accuracy: 0.6155 - val_loss: 1.9496 - val_sparse_categorical_accuracy: 0.8585
# Epoch 16/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.1525 - sparse_categorical_accuracy: 0.6135 - val_loss: 1.9367 - val_sparse_categorical_accuracy: 0.8625
# Epoch 17/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.1528 - sparse_categorical_accuracy: 0.5905 - val_loss: 1.9239 - val_sparse_categorical_accuracy: 0.8640
# Epoch 18/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.1134 - sparse_categorical_accuracy: 0.6090 - val_loss: 1.9109 - val_sparse_categorical_accuracy: 0.8665
# Epoch 19/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.1162 - sparse_categorical_accuracy: 0.6220 - val_loss: 1.8979 - val_sparse_categorical_accuracy: 0.8715
# Epoch 20/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.1123 - sparse_categorical_accuracy: 0.6210 - val_loss: 1.8851 - val_sparse_categorical_accuracy: 0.8775
# Epoch 21/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.0960 - sparse_categorical_accuracy: 0.6215 - val_loss: 1.8724 - val_sparse_categorical_accuracy: 0.8800
# Epoch 22/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.0966 - sparse_categorical_accuracy: 0.6050 - val_loss: 1.8598 - val_sparse_categorical_accuracy: 0.8800
# Epoch 23/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.0753 - sparse_categorical_accuracy: 0.6280 - val_loss: 1.8471 - val_sparse_categorical_accuracy: 0.8860
# Epoch 24/50
# 2/2 [==============================] - 0s 35ms/step - loss: 2.0732 - sparse_categorical_accuracy: 0.6225 - val_loss: 1.8345 - val_sparse_categorical_accuracy: 0.8880
# Epoch 25/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.0615 - sparse_categorical_accuracy: 0.6205 - val_loss: 1.8221 - val_sparse_categorical_accuracy: 0.8895
# Epoch 26/50
# 2/2 [==============================] - 0s 43ms/step - loss: 2.0562 - sparse_categorical_accuracy: 0.6240 - val_loss: 1.8096 - val_sparse_categorical_accuracy: 0.8905
# Epoch 27/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.0522 - sparse_categorical_accuracy: 0.6310 - val_loss: 1.7971 - val_sparse_categorical_accuracy: 0.8945
# Epoch 28/50
# 2/2 [==============================] - 0s 38ms/step - loss: 2.0417 - sparse_categorical_accuracy: 0.6320 - val_loss: 1.7846 - val_sparse_categorical_accuracy: 0.8960
# Epoch 29/50
# 2/2 [==============================] - 0s 40ms/step - loss: 2.0213 - sparse_categorical_accuracy: 0.6275 - val_loss: 1.7722 - val_sparse_categorical_accuracy: 0.9000
# Epoch 30/50
# 2/2 [==============================] - 0s 46ms/step - loss: 2.0216 - sparse_categorical_accuracy: 0.6275 - val_loss: 1.7598 - val_sparse_categorical_accuracy: 0.9030
# Epoch 31/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.0024 - sparse_categorical_accuracy: 0.6440 - val_loss: 1.7475 - val_sparse_categorical_accuracy: 0.9085
# Epoch 32/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.9998 - sparse_categorical_accuracy: 0.6485 - val_loss: 1.7353 - val_sparse_categorical_accuracy: 0.9110
# Epoch 33/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.9962 - sparse_categorical_accuracy: 0.6275 - val_loss: 1.7232 - val_sparse_categorical_accuracy: 0.9150
# Epoch 34/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.9864 - sparse_categorical_accuracy: 0.6370 - val_loss: 1.7110 - val_sparse_categorical_accuracy: 0.9160
# Epoch 35/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.9779 - sparse_categorical_accuracy: 0.6480 - val_loss: 1.6991 - val_sparse_categorical_accuracy: 0.9155
# Epoch 36/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.9722 - sparse_categorical_accuracy: 0.6385 - val_loss: 1.6873 - val_sparse_categorical_accuracy: 0.9190
# Epoch 37/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.9593 - sparse_categorical_accuracy: 0.6460 - val_loss: 1.6756 - val_sparse_categorical_accuracy: 0.9200
# Epoch 38/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.9438 - sparse_categorical_accuracy: 0.6525 - val_loss: 1.6637 - val_sparse_categorical_accuracy: 0.9235
# Epoch 39/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.9395 - sparse_categorical_accuracy: 0.6505 - val_loss: 1.6519 - val_sparse_categorical_accuracy: 0.9265
# Epoch 40/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.9428 - sparse_categorical_accuracy: 0.6380 - val_loss: 1.6402 - val_sparse_categorical_accuracy: 0.9270
# Epoch 41/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.9196 - sparse_categorical_accuracy: 0.6420 - val_loss: 1.6282 - val_sparse_categorical_accuracy: 0.9290
# Epoch 42/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.9042 - sparse_categorical_accuracy: 0.6690 - val_loss: 1.6164 - val_sparse_categorical_accuracy: 0.9300
# Epoch 43/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.9183 - sparse_categorical_accuracy: 0.6580 - val_loss: 1.6050 - val_sparse_categorical_accuracy: 0.9305
# Epoch 44/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.8960 - sparse_categorical_accuracy: 0.6505 - val_loss: 1.5937 - val_sparse_categorical_accuracy: 0.9315
# Epoch 45/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.8904 - sparse_categorical_accuracy: 0.6630 - val_loss: 1.5823 - val_sparse_categorical_accuracy: 0.9315
# Epoch 46/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8856 - sparse_categorical_accuracy: 0.6495 - val_loss: 1.5709 - val_sparse_categorical_accuracy: 0.9340
# Epoch 47/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.6645 - val_loss: 1.5594 - val_sparse_categorical_accuracy: 0.9355
# Epoch 48/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.8598 - sparse_categorical_accuracy: 0.6665 - val_loss: 1.5482 - val_sparse_categorical_accuracy: 0.9340
# Epoch 49/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8405 - sparse_categorical_accuracy: 0.6760 - val_loss: 1.5368 - val_sparse_categorical_accuracy: 0.9340
# Epoch 50/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8456 - sparse_categorical_accuracy: 0.6615 - val_loss: 1.5255 - val_sparse_categorical_accuracy: 0.9385
# Training for SNR= 1.5  sigma= 0.8413951416451951
# Epoch 1/50
# 2/2 [==============================] - 0s 71ms/step - loss: 1.8394 - sparse_categorical_accuracy: 0.6755 - val_loss: 1.5141 - val_sparse_categorical_accuracy: 0.9380
# Epoch 2/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8295 - sparse_categorical_accuracy: 0.6815 - val_loss: 1.5029 - val_sparse_categorical_accuracy: 0.9390
# Epoch 3/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.8225 - sparse_categorical_accuracy: 0.6655 - val_loss: 1.4920 - val_sparse_categorical_accuracy: 0.9405
# Epoch 4/50
# 2/2 [==============================] - 0s 51ms/step - loss: 1.8244 - sparse_categorical_accuracy: 0.6640 - val_loss: 1.4809 - val_sparse_categorical_accuracy: 0.9420
# Epoch 5/50
# 2/2 [==============================] - 0s 144ms/step - loss: 1.8062 - sparse_categorical_accuracy: 0.6675 - val_loss: 1.4697 - val_sparse_categorical_accuracy: 0.9465
# Epoch 6/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.8164 - sparse_categorical_accuracy: 0.6660 - val_loss: 1.4589 - val_sparse_categorical_accuracy: 0.9500
# Epoch 7/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.8048 - sparse_categorical_accuracy: 0.6685 - val_loss: 1.4483 - val_sparse_categorical_accuracy: 0.9515
# Epoch 8/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.7829 - sparse_categorical_accuracy: 0.6790 - val_loss: 1.4376 - val_sparse_categorical_accuracy: 0.9525
# Epoch 9/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.7725 - sparse_categorical_accuracy: 0.6850 - val_loss: 1.4268 - val_sparse_categorical_accuracy: 0.9520
# Epoch 10/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.7666 - sparse_categorical_accuracy: 0.6845 - val_loss: 1.4159 - val_sparse_categorical_accuracy: 0.9500
# Epoch 11/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.7724 - sparse_categorical_accuracy: 0.6635 - val_loss: 1.4052 - val_sparse_categorical_accuracy: 0.9515
# Epoch 12/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.7577 - sparse_categorical_accuracy: 0.6645 - val_loss: 1.3946 - val_sparse_categorical_accuracy: 0.9545
# Epoch 13/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.7468 - sparse_categorical_accuracy: 0.6720 - val_loss: 1.3842 - val_sparse_categorical_accuracy: 0.9560
# Epoch 14/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.7505 - sparse_categorical_accuracy: 0.6695 - val_loss: 1.3737 - val_sparse_categorical_accuracy: 0.9580
# Epoch 15/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.7289 - sparse_categorical_accuracy: 0.6895 - val_loss: 1.3631 - val_sparse_categorical_accuracy: 0.9580
# Epoch 16/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.7126 - sparse_categorical_accuracy: 0.7005 - val_loss: 1.3526 - val_sparse_categorical_accuracy: 0.9580
# Epoch 17/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.7090 - sparse_categorical_accuracy: 0.6910 - val_loss: 1.3423 - val_sparse_categorical_accuracy: 0.9595
# Epoch 18/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.7177 - sparse_categorical_accuracy: 0.6880 - val_loss: 1.3321 - val_sparse_categorical_accuracy: 0.9615
# Epoch 19/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6987 - sparse_categorical_accuracy: 0.6930 - val_loss: 1.3221 - val_sparse_categorical_accuracy: 0.9620
# Epoch 20/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.7122 - sparse_categorical_accuracy: 0.6835 - val_loss: 1.3119 - val_sparse_categorical_accuracy: 0.9635
# Epoch 21/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6701 - sparse_categorical_accuracy: 0.7005 - val_loss: 1.3016 - val_sparse_categorical_accuracy: 0.9665
# Epoch 22/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.6875 - sparse_categorical_accuracy: 0.6845 - val_loss: 1.2915 - val_sparse_categorical_accuracy: 0.9665
# Epoch 23/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6820 - sparse_categorical_accuracy: 0.6820 - val_loss: 1.2814 - val_sparse_categorical_accuracy: 0.9685
# Epoch 24/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6842 - sparse_categorical_accuracy: 0.6850 - val_loss: 1.2716 - val_sparse_categorical_accuracy: 0.9705
# Epoch 25/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6783 - sparse_categorical_accuracy: 0.6820 - val_loss: 1.2621 - val_sparse_categorical_accuracy: 0.9695
# Epoch 26/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.6488 - sparse_categorical_accuracy: 0.7045 - val_loss: 1.2526 - val_sparse_categorical_accuracy: 0.9695
# Epoch 27/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6302 - sparse_categorical_accuracy: 0.7070 - val_loss: 1.2427 - val_sparse_categorical_accuracy: 0.9700
# Epoch 28/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.6474 - sparse_categorical_accuracy: 0.6985 - val_loss: 1.2330 - val_sparse_categorical_accuracy: 0.9725
# Epoch 29/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6443 - sparse_categorical_accuracy: 0.6875 - val_loss: 1.2235 - val_sparse_categorical_accuracy: 0.9740
# Epoch 30/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.6247 - sparse_categorical_accuracy: 0.6905 - val_loss: 1.2140 - val_sparse_categorical_accuracy: 0.9750
# Epoch 31/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.6265 - sparse_categorical_accuracy: 0.6870 - val_loss: 1.2044 - val_sparse_categorical_accuracy: 0.9770
# Epoch 32/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.6081 - sparse_categorical_accuracy: 0.7065 - val_loss: 1.1948 - val_sparse_categorical_accuracy: 0.9770
# Epoch 33/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6042 - sparse_categorical_accuracy: 0.7015 - val_loss: 1.1853 - val_sparse_categorical_accuracy: 0.9780
# Epoch 34/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.6965 - val_loss: 1.1760 - val_sparse_categorical_accuracy: 0.9790
# Epoch 35/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5936 - sparse_categorical_accuracy: 0.6915 - val_loss: 1.1670 - val_sparse_categorical_accuracy: 0.9790
# Epoch 36/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5845 - sparse_categorical_accuracy: 0.7125 - val_loss: 1.1579 - val_sparse_categorical_accuracy: 0.9780
# Epoch 37/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5753 - sparse_categorical_accuracy: 0.7090 - val_loss: 1.1486 - val_sparse_categorical_accuracy: 0.9785
# Epoch 38/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5880 - sparse_categorical_accuracy: 0.7045 - val_loss: 1.1390 - val_sparse_categorical_accuracy: 0.9845
# Epoch 39/50
# 2/2 [==============================] - 0s 47ms/step - loss: 1.5651 - sparse_categorical_accuracy: 0.7125 - val_loss: 1.1299 - val_sparse_categorical_accuracy: 0.9850
# Epoch 40/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5589 - sparse_categorical_accuracy: 0.7120 - val_loss: 1.1211 - val_sparse_categorical_accuracy: 0.9860
# Epoch 41/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.5562 - sparse_categorical_accuracy: 0.7100 - val_loss: 1.1123 - val_sparse_categorical_accuracy: 0.9860
# Epoch 42/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.5602 - sparse_categorical_accuracy: 0.6875 - val_loss: 1.1034 - val_sparse_categorical_accuracy: 0.9865
# Epoch 43/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5274 - sparse_categorical_accuracy: 0.7180 - val_loss: 1.0944 - val_sparse_categorical_accuracy: 0.9870
# Epoch 44/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.5478 - sparse_categorical_accuracy: 0.7055 - val_loss: 1.0857 - val_sparse_categorical_accuracy: 0.9875
# Epoch 45/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5232 - sparse_categorical_accuracy: 0.7145 - val_loss: 1.0772 - val_sparse_categorical_accuracy: 0.9885
# Epoch 46/50
# 2/2 [==============================] - 0s 51ms/step - loss: 1.5426 - sparse_categorical_accuracy: 0.7005 - val_loss: 1.0688 - val_sparse_categorical_accuracy: 0.9895
# Epoch 47/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5247 - sparse_categorical_accuracy: 0.7075 - val_loss: 1.0601 - val_sparse_categorical_accuracy: 0.9890
# Epoch 48/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.5212 - sparse_categorical_accuracy: 0.7225 - val_loss: 1.0513 - val_sparse_categorical_accuracy: 0.9890
# Epoch 49/50
# 2/2 [==============================] - 0s 138ms/step - loss: 1.4993 - sparse_categorical_accuracy: 0.7140 - val_loss: 1.0428 - val_sparse_categorical_accuracy: 0.9885
# Epoch 50/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4998 - sparse_categorical_accuracy: 0.7090 - val_loss: 1.0345 - val_sparse_categorical_accuracy: 0.9885
# Training for SNR= 2.0  sigma= 0.7943282347242815
# Epoch 1/50
# 2/2 [==============================] - 0s 71ms/step - loss: 1.4924 - sparse_categorical_accuracy: 0.7230 - val_loss: 1.0261 - val_sparse_categorical_accuracy: 0.9895
# Epoch 2/50
# 2/2 [==============================] - 0s 47ms/step - loss: 1.5089 - sparse_categorical_accuracy: 0.7010 - val_loss: 1.0176 - val_sparse_categorical_accuracy: 0.9890
# Epoch 3/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4825 - sparse_categorical_accuracy: 0.7165 - val_loss: 1.0094 - val_sparse_categorical_accuracy: 0.9895
# Epoch 4/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.4670 - sparse_categorical_accuracy: 0.7275 - val_loss: 1.0012 - val_sparse_categorical_accuracy: 0.9915
# Epoch 5/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.4726 - sparse_categorical_accuracy: 0.7305 - val_loss: 0.9931 - val_sparse_categorical_accuracy: 0.9920
# Epoch 6/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.4647 - sparse_categorical_accuracy: 0.7280 - val_loss: 0.9850 - val_sparse_categorical_accuracy: 0.9925
# Epoch 7/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.4702 - sparse_categorical_accuracy: 0.7260 - val_loss: 0.9769 - val_sparse_categorical_accuracy: 0.9925
# Epoch 8/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.4728 - sparse_categorical_accuracy: 0.7220 - val_loss: 0.9690 - val_sparse_categorical_accuracy: 0.9930
# Epoch 9/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4649 - sparse_categorical_accuracy: 0.7000 - val_loss: 0.9613 - val_sparse_categorical_accuracy: 0.9930
# Epoch 10/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4391 - sparse_categorical_accuracy: 0.7285 - val_loss: 0.9536 - val_sparse_categorical_accuracy: 0.9945
# Epoch 11/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.4350 - sparse_categorical_accuracy: 0.7290 - val_loss: 0.9461 - val_sparse_categorical_accuracy: 0.9945
# Epoch 12/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.4430 - sparse_categorical_accuracy: 0.7205 - val_loss: 0.9387 - val_sparse_categorical_accuracy: 0.9940
# Epoch 13/50
# 2/2 [==============================] - 0s 35ms/step - loss: 1.4123 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.9309 - val_sparse_categorical_accuracy: 0.9950
# Epoch 14/50
# 2/2 [==============================] - 0s 48ms/step - loss: 1.4393 - sparse_categorical_accuracy: 0.7185 - val_loss: 0.9228 - val_sparse_categorical_accuracy: 0.9955
# Epoch 15/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.4274 - sparse_categorical_accuracy: 0.7185 - val_loss: 0.9149 - val_sparse_categorical_accuracy: 0.9955
# Epoch 16/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.4016 - sparse_categorical_accuracy: 0.7230 - val_loss: 0.9073 - val_sparse_categorical_accuracy: 0.9960
# Epoch 17/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4057 - sparse_categorical_accuracy: 0.7280 - val_loss: 0.8997 - val_sparse_categorical_accuracy: 0.9965
# Epoch 18/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.4305 - sparse_categorical_accuracy: 0.7010 - val_loss: 0.8920 - val_sparse_categorical_accuracy: 0.9965
# Epoch 19/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4142 - sparse_categorical_accuracy: 0.7245 - val_loss: 0.8845 - val_sparse_categorical_accuracy: 0.9965
# Epoch 20/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.3860 - sparse_categorical_accuracy: 0.7275 - val_loss: 0.8772 - val_sparse_categorical_accuracy: 0.9965
# Epoch 21/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.4136 - sparse_categorical_accuracy: 0.7175 - val_loss: 0.8701 - val_sparse_categorical_accuracy: 0.9965
# Epoch 22/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.3918 - sparse_categorical_accuracy: 0.7230 - val_loss: 0.8630 - val_sparse_categorical_accuracy: 0.9965
# Epoch 23/50
# 2/2 [==============================] - 0s 48ms/step - loss: 1.3797 - sparse_categorical_accuracy: 0.7430 - val_loss: 0.8558 - val_sparse_categorical_accuracy: 0.9970
# Epoch 24/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3795 - sparse_categorical_accuracy: 0.7305 - val_loss: 0.8490 - val_sparse_categorical_accuracy: 0.9965
# Epoch 25/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.3846 - sparse_categorical_accuracy: 0.7160 - val_loss: 0.8423 - val_sparse_categorical_accuracy: 0.9960
# Epoch 26/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.3479 - sparse_categorical_accuracy: 0.7380 - val_loss: 0.8356 - val_sparse_categorical_accuracy: 0.9960
# Epoch 27/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.3494 - sparse_categorical_accuracy: 0.7300 - val_loss: 0.8290 - val_sparse_categorical_accuracy: 0.9960
# Epoch 28/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3783 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.8227 - val_sparse_categorical_accuracy: 0.9960
# Epoch 29/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3635 - sparse_categorical_accuracy: 0.7315 - val_loss: 0.8160 - val_sparse_categorical_accuracy: 0.9955
# Epoch 30/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.3427 - sparse_categorical_accuracy: 0.7420 - val_loss: 0.8089 - val_sparse_categorical_accuracy: 0.9960
# Epoch 31/50
# 2/2 [==============================] - 0s 47ms/step - loss: 1.3185 - sparse_categorical_accuracy: 0.7520 - val_loss: 0.8021 - val_sparse_categorical_accuracy: 0.9960
# Epoch 32/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.3438 - sparse_categorical_accuracy: 0.7410 - val_loss: 0.7954 - val_sparse_categorical_accuracy: 0.9965
# Epoch 33/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.3264 - sparse_categorical_accuracy: 0.7390 - val_loss: 0.7886 - val_sparse_categorical_accuracy: 0.9965
# Epoch 34/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3255 - sparse_categorical_accuracy: 0.7330 - val_loss: 0.7818 - val_sparse_categorical_accuracy: 0.9965
# Epoch 35/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2988 - sparse_categorical_accuracy: 0.7525 - val_loss: 0.7753 - val_sparse_categorical_accuracy: 0.9970
# Epoch 36/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.3084 - sparse_categorical_accuracy: 0.7410 - val_loss: 0.7690 - val_sparse_categorical_accuracy: 0.9970
# Epoch 37/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.3159 - sparse_categorical_accuracy: 0.7260 - val_loss: 0.7622 - val_sparse_categorical_accuracy: 0.9970
# Epoch 38/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2963 - sparse_categorical_accuracy: 0.7405 - val_loss: 0.7554 - val_sparse_categorical_accuracy: 0.9980
# Epoch 39/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.3145 - sparse_categorical_accuracy: 0.7405 - val_loss: 0.7487 - val_sparse_categorical_accuracy: 0.9980
# Epoch 40/50
# 2/2 [==============================] - 0s 49ms/step - loss: 1.3011 - sparse_categorical_accuracy: 0.7230 - val_loss: 0.7424 - val_sparse_categorical_accuracy: 0.9980
# Epoch 41/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2987 - sparse_categorical_accuracy: 0.7430 - val_loss: 0.7362 - val_sparse_categorical_accuracy: 0.9980
# Epoch 42/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.3088 - sparse_categorical_accuracy: 0.7330 - val_loss: 0.7300 - val_sparse_categorical_accuracy: 0.9995
# Epoch 43/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2983 - sparse_categorical_accuracy: 0.7380 - val_loss: 0.7242 - val_sparse_categorical_accuracy: 0.9995
# Epoch 44/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2842 - sparse_categorical_accuracy: 0.7360 - val_loss: 0.7185 - val_sparse_categorical_accuracy: 0.9995
# Epoch 45/50
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2788 - sparse_categorical_accuracy: 0.7335 - val_loss: 0.7122 - val_sparse_categorical_accuracy: 0.9995
# Epoch 46/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2758 - sparse_categorical_accuracy: 0.7405 - val_loss: 0.7061 - val_sparse_categorical_accuracy: 0.9995
# Epoch 47/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2660 - sparse_categorical_accuracy: 0.7455 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.9995
# Epoch 48/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2628 - sparse_categorical_accuracy: 0.7370 - val_loss: 0.6937 - val_sparse_categorical_accuracy: 0.9995
# Epoch 49/50
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2661 - sparse_categorical_accuracy: 0.7335 - val_loss: 0.6878 - val_sparse_categorical_accuracy: 0.9995
# Epoch 50/50
# 2/2 [==============================] - 0s 144ms/step - loss: 1.2525 - sparse_categorical_accuracy: 0.7450 - val_loss: 0.6824 - val_sparse_categorical_accuracy: 0.9995
# Training for SNR= 2.5  sigma= 0.7498942093324559
# Epoch 1/50
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2432 - sparse_categorical_accuracy: 0.7535 - val_loss: 0.6771 - val_sparse_categorical_accuracy: 0.9995
# Epoch 2/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2518 - sparse_categorical_accuracy: 0.7375 - val_loss: 0.6715 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2546 - sparse_categorical_accuracy: 0.7335 - val_loss: 0.6660 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2517 - sparse_categorical_accuracy: 0.7390 - val_loss: 0.6607 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 56ms/step - loss: 1.2668 - sparse_categorical_accuracy: 0.7240 - val_loss: 0.6552 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2331 - sparse_categorical_accuracy: 0.7365 - val_loss: 0.6496 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2300 - sparse_categorical_accuracy: 0.7490 - val_loss: 0.6442 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2114 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.6388 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2412 - sparse_categorical_accuracy: 0.7345 - val_loss: 0.6333 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2097 - sparse_categorical_accuracy: 0.7525 - val_loss: 0.6279 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2028 - sparse_categorical_accuracy: 0.7555 - val_loss: 0.6227 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2320 - sparse_categorical_accuracy: 0.7475 - val_loss: 0.6177 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.2400 - sparse_categorical_accuracy: 0.7370 - val_loss: 0.6128 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2152 - sparse_categorical_accuracy: 0.7425 - val_loss: 0.6077 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2008 - sparse_categorical_accuracy: 0.7485 - val_loss: 0.6028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.1913 - sparse_categorical_accuracy: 0.7485 - val_loss: 0.5978 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2016 - sparse_categorical_accuracy: 0.7540 - val_loss: 0.5926 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2020 - sparse_categorical_accuracy: 0.7365 - val_loss: 0.5875 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# ...
# Epoch 12/50
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6145 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6092 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6659 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6257 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6271 - sparse_categorical_accuracy: 0.8040 - val_loss: 0.0185 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6616 - sparse_categorical_accuracy: 0.7990 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6249 - sparse_categorical_accuracy: 0.8060 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6321 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6284 - sparse_categorical_accuracy: 0.8065 - val_loss: 0.0182 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.8130 - val_loss: 0.0182 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5923 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6421 - sparse_categorical_accuracy: 0.8045 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6237 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6436 - sparse_categorical_accuracy: 0.7995 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6475 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6377 - sparse_categorical_accuracy: 0.8080 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6394 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6425 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5897 - sparse_categorical_accuracy: 0.8145 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6307 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.0177 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6171 - sparse_categorical_accuracy: 0.8045 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6584 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6448 - sparse_categorical_accuracy: 0.8030 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6413 - sparse_categorical_accuracy: 0.8110 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6330 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6148 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6194 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6506 - sparse_categorical_accuracy: 0.8045 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 157ms/step - loss: 0.6433 - sparse_categorical_accuracy: 0.7975 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6182 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6248 - sparse_categorical_accuracy: 0.8135 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6297 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5919 - sparse_categorical_accuracy: 0.8190 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6266 - sparse_categorical_accuracy: 0.8060 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6162 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6279 - sparse_categorical_accuracy: 0.8155 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5887 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 1.0000
# Training for SNR= 9.5  sigma= 0.33496543915782767
# Epoch 1/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6518 - sparse_categorical_accuracy: 0.7945 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6444 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5993 - sparse_categorical_accuracy: 0.8265 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6576 - sparse_categorical_accuracy: 0.7980 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6358 - sparse_categorical_accuracy: 0.8060 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6326 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6463 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6401 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6134 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6312 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6026 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6401 - sparse_categorical_accuracy: 0.8040 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6327 - sparse_categorical_accuracy: 0.8040 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6172 - sparse_categorical_accuracy: 0.7955 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6237 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5969 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6351 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6315 - sparse_categorical_accuracy: 0.8090 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6232 - sparse_categorical_accuracy: 0.8060 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6086 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6109 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6294 - sparse_categorical_accuracy: 0.8110 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5924 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6315 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6320 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6487 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6369 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6494 - sparse_categorical_accuracy: 0.7975 - val_loss: 0.0155 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6002 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.0155 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5862 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6160 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6604 - sparse_categorical_accuracy: 0.7970 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6348 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6228 - sparse_categorical_accuracy: 0.8065 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6446 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6409 - sparse_categorical_accuracy: 0.8020 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6273 - sparse_categorical_accuracy: 0.8120 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6292 - sparse_categorical_accuracy: 0.8145 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.6224 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6044 - sparse_categorical_accuracy: 0.8135 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.8080 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6119 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6062 - sparse_categorical_accuracy: 0.8150 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6190 - sparse_categorical_accuracy: 0.8025 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6369 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6502 - sparse_categorical_accuracy: 0.7915 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6038 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6116 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6164 - sparse_categorical_accuracy: 0.8175 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 1.0000

# %%
output_display_counter = NUM_OF_INPUT_MESSAGE/4
ber_per_iter_dl_tensor  = numpy.array(())
bler_per_iter_dl_tensor  = numpy.array(())
ber_batch_size = 1000
ber_iteration = int(NUM_OF_INPUT_MESSAGE/ber_batch_size)
for snr in numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE):
  total_bit_error = 0
  total_msg_error = 0
  total_time = 0
  current_time = time.time()
  sigma = Snr2Sigma (snr)
  for i in range (ber_iteration):
    input_message_xx = training_input_message_one_hot [i:i+ber_batch_size]
    #print ("input", training_input_message[i:i+ber_batch_size])
    encoded_message = encoder.predict(training_input_message_one_hot[i:i+ber_batch_size])
    #print (encoded_message)
    noised_message = encoded_message + numpy.random.normal(0, sigma, encoded_message.shape)
    #print (noised_message)
    #awgn_channel = GaussianNoise(sigma,input_shape=(CHANEL_SIZE,))
    #noised_message = awgn_channel.predict(encoded_message)
    #noised_message = awgn_layer (encoded_message)    
    #print(noised_message)
    decoded_message = decoder.predict(noised_message)
    decoded_message = numpy.argmax(decoded_message, axis=2)
    decoded_message = numpy.reshape (decoded_message, (-1,decoded_message.shape[1],1 ))
    #print ("decoded1:", decoded_message)
    #def conv_to_binary_from_decimal_block (input,num_of_input, num_of_block, block_size):
    decoded_message_binary =  conv_to_binary_from_decimal_block (decoded_message, ber_batch_size, num_of_input_block, input_block_length)   
    input_message_binary =  conv_to_binary_from_decimal_block (training_input_message [i:i+ber_batch_size], ber_batch_size, num_of_input_block, input_block_length)   
    #print ("decoded_message_binary:", decoded_message_binary)
    #print ("input_message_binary:", input_message_binary)
    diff = abs(decoded_message_binary - input_message_binary)
    #print ("diff", diff)
    diff_sum = numpy.sum(np.sum (diff, axis=1), axis=1)
    #print ("diff_sum", diff_sum)
    block_error = numpy.count_nonzero(diff_sum!=0)
    #print ("block_error:", block_error)
    bit_error = numpy.sum(diff_sum)
    #print ("bit_error",bit_error )
    total_msg_error = total_msg_error +block_error
    total_bit_error = total_bit_error + bit_error
    #print ("total_msg_error:", total_msg_error)
    #print ("total_bit_error", total_bit_error)
    i = i + ber_batch_size
  bler = float(total_msg_error)/(ber_iteration*ber_batch_size)

  ber = float(total_bit_error)/(ber_iteration*ber_batch_size*num_of_input_block*input_block_length)
  print('SNR: {:04.3f}:\n ->BLER: {:03.5f}  BER: {:03.5f}'.format(snr,bler,ber,total_time))
  print ("total:", total_bit_error)
  ber_per_iter_dl_tensor=numpy.append(ber_per_iter_dl_tensor ,ber)  
  bler_per_iter_dl_tensor=numpy.append(bler_per_iter_dl_tensor ,bler)
# Out:
# SNR: 0.000:
#  ->BLER: 0.39500  BER: 0.11710
# total: 1171
# SNR: 0.500:
#  ->BLER: 0.31500  BER: 0.08900
# total: 890
# SNR: 1.000:
#  ->BLER: 0.26500  BER: 0.07750
# total: 775
# SNR: 1.500:
#  ->BLER: 0.24100  BER: 0.06460
# total: 646
# SNR: 2.000:
#  ->BLER: 0.15900  BER: 0.04340
# total: 434
# SNR: 2.500:
#  ->BLER: 0.12300  BER: 0.03460
# total: 346
# SNR: 3.000:
#  ->BLER: 0.08100  BER: 0.02220
# total: 222
# SNR: 3.500:
#  ->BLER: 0.06100  BER: 0.01640
# total: 164
# SNR: 4.000:
#  ->BLER: 0.02700  BER: 0.00790
# total: 79
# SNR: 4.500:
#  ->BLER: 0.02300  BER: 0.00610
# total: 61
# SNR: 5.000:
#  ->BLER: 0.00900  BER: 0.00280
# total: 28
# SNR: 5.500:
#  ->BLER: 0.00500  BER: 0.00100
# total: 10
# SNR: 6.000:
#  ->BLER: 0.00500  BER: 0.00160
# total: 16
# SNR: 6.500:
#  ->BLER: 0.00100  BER: 0.00020
# total: 2
# SNR: 7.000:
#  ->BLER: 0.00100  BER: 0.00020
# total: 2
# SNR: 7.500:
#  ->BLER: 0.00100  BER: 0.00020
# total: 2
# SNR: 8.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 8.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.000:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0
# SNR: 9.500:
#  ->BLER: 0.00000  BER: 0.00000
# total: 0

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor1, bler_per_iter_dl_tensor1, channel_out1  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          training_input_message_one_hot, 
          training_input_message, 
          training_input_message_one_hot.shape[0], training_input_message_one_hot.shape[1],
          int(numpy.math.log2(training_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor)
print (bler_per_iter_dl_tensor)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.42000 BER: 0.12640
# total_bit_error: 1264
# total_msg_error: 420
# SNR: 0.500:-> BLER: 0.35200 BER: 0.10350
# total_bit_error: 1035
# total_msg_error: 352
# SNR: 1.000:-> BLER: 0.27600 BER: 0.08060
# total_bit_error: 806
# total_msg_error: 276
# SNR: 1.500:-> BLER: 0.22100 BER: 0.06470
# total_bit_error: 647
# total_msg_error: 221
# SNR: 2.000:-> BLER: 0.12800 BER: 0.03530
# total_bit_error: 353
# total_msg_error: 128
# SNR: 2.500:-> BLER: 0.12800 BER: 0.03520
# total_bit_error: 352
# total_msg_error: 128
# SNR: 3.000:-> BLER: 0.08100 BER: 0.02130
# total_bit_error: 213
# total_msg_error: 81
# SNR: 3.500:-> BLER: 0.04500 BER: 0.01110
# total_bit_error: 111
# total_msg_error: 45
# SNR: 4.000:-> BLER: 0.03700 BER: 0.01020
# total_bit_error: 102
# total_msg_error: 37
# SNR: 4.500:-> BLER: 0.02100 BER: 0.00520
# total_bit_error: 52
# total_msg_error: 21
# SNR: 5.000:-> BLER: 0.00900 BER: 0.00190
# total_bit_error: 19
# total_msg_error: 9
# SNR: 5.500:-> BLER: 0.00800 BER: 0.00210
# total_bit_error: 21
# total_msg_error: 8
# SNR: 6.000:-> BLER: 0.00200 BER: 0.00030
# total_bit_error: 3
# total_msg_error: 2
# SNR: 6.500:-> BLER: 0.00300 BER: 0.00070
# total_bit_error: 7
# total_msg_error: 3
# SNR: 7.000:-> BLER: 0.00200 BER: 0.00050
# total_bit_error: 5
# total_msg_error: 2
# SNR: 7.500:-> BLER: 0.00100 BER: 0.00030
# total_bit_error: 3
# total_msg_error: 1
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.1171 0.089  0.0775 0.0646 0.0434 0.0346 0.0222 0.0164 0.0079 0.0061
#  0.0028 0.001  0.0016 0.0002 0.0002 0.0002 0.     0.     0.     0.    ]
# [0.395 0.315 0.265 0.241 0.159 0.123 0.081 0.061 0.027 0.023 0.009 0.005
#  0.005 0.001 0.001 0.001 0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor,'', label="ai-dl(5x2_30_10)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
print (training_input_message_one_hot.shape)
ber_per_iter_dl_tensor2, bler_per_iter_dl_tensor2, channel_out2  = get_block_onehot_ber_bler_of_model (numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE), 
          encoder, decoder, 
          test_input_message_one_hot, 
          test_input_message, 
          test_input_message_one_hot.shape[0], test_input_message_one_hot.shape[1],
          int(numpy.math.log2(test_input_message_one_hot.shape[2])),
          channel_size)
print (ber_per_iter_dl_tensor2)
print (bler_per_iter_dl_tensor2)
# Out:
# (1000, 2, 32)
# SNR: 0.000:-> BLER: 0.42300 BER: 0.12850
# total_bit_error: 1285
# total_msg_error: 423
# SNR: 0.500:-> BLER: 0.36700 BER: 0.10610
# total_bit_error: 1061
# total_msg_error: 367
# SNR: 1.000:-> BLER: 0.32200 BER: 0.09400
# total_bit_error: 940
# total_msg_error: 322
# SNR: 1.500:-> BLER: 0.24000 BER: 0.06510
# total_bit_error: 651
# total_msg_error: 240
# SNR: 2.000:-> BLER: 0.18500 BER: 0.05330
# total_bit_error: 533
# total_msg_error: 185
# SNR: 2.500:-> BLER: 0.13400 BER: 0.03630
# total_bit_error: 363
# total_msg_error: 134
# SNR: 3.000:-> BLER: 0.07900 BER: 0.02160
# total_bit_error: 216
# total_msg_error: 79
# SNR: 3.500:-> BLER: 0.07900 BER: 0.02150
# total_bit_error: 215
# total_msg_error: 79
# SNR: 4.000:-> BLER: 0.03300 BER: 0.00820
# total_bit_error: 82
# total_msg_error: 33
# SNR: 4.500:-> BLER: 0.03000 BER: 0.00740
# total_bit_error: 74
# total_msg_error: 30
# SNR: 5.000:-> BLER: 0.01600 BER: 0.00410
# total_bit_error: 41
# total_msg_error: 16
# SNR: 5.500:-> BLER: 0.00900 BER: 0.00260
# total_bit_error: 26
# total_msg_error: 9
# SNR: 6.000:-> BLER: 0.00400 BER: 0.00140
# total_bit_error: 14
# total_msg_error: 4
# SNR: 6.500:-> BLER: 0.00600 BER: 0.00160
# total_bit_error: 16
# total_msg_error: 6
# SNR: 7.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 7.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 8.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.000:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# SNR: 9.500:-> BLER: 0.00000 BER: 0.00000
# total_bit_error: 0
# total_msg_error: 0
# [0.1285 0.1061 0.094  0.0651 0.0533 0.0363 0.0216 0.0215 0.0082 0.0074
#  0.0041 0.0026 0.0014 0.0016 0.     0.     0.     0.     0.     0.    ]
# [0.423 0.367 0.322 0.24  0.185 0.134 0.079 0.079 0.033 0.03  0.016 0.009
#  0.004 0.006 0.    0.    0.    0.    0.    0.   ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,bler_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(18,9)-qpsk(channel=9)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,bler_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.set_ylabel('BLER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
#ax2.plot(snrs,times_per_iter_pyldpc,'', label="pyldpc") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_tensor,'', label="tensor") # plot decode timing for different SNRs
#ax2.plot(snrs,times_per_iter_awgn,'', label="commpy-awgn") # plot decode timing for different SNRs
#ax2.set_xlabel('$E_b/$N_0$')
#ax2.set_ylabel('Decoding Time [s]')
#ax2.annotate('Total Runtime: pyldpc:{:03.2f}s awgn:{:03.2f}s tensor:{:03.2f}s'.format(numpy.sum(times_per_iter_pyldpc), 
#            numpy.sum(times_per_iter_awgn), numpy.sum(times_per_iter_tensor)),
#            xy=(1, 0.35), xycoords='axes fraction',
#            xytext=(-20, 20), textcoords='offset pixels',
#            horizontalalignment='right',
#            verticalalignment='bottom')
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
snrs = numpy.arange (SNR_BEGIN, SNR_END, SNR_STEP_SIZE)
fig, (ax1) = plt.subplots(1,1,figsize=(8,6))
ax1.semilogy(snrs,ber_per_iter_ldpc_itpp_psk_4,'', label="itpp-ldpc(9-18-9)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor2,'', label="ai-dl(5x2_30_10)(2)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_dl_tensor1,'', label="ai-dl(5x2_30_10)(1)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_2,'', label="commpy-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_2,'', label="itpp-psk2(bpsk)-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_4,'', label="commpy-psk4-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_4,'', label="itpp-psk4-uncoded") # plot BER vs SNR
#ax1.semilogy(snrs,ber_per_iter_ham_itpp_psk_4,'', label="itpp-ham(7,4)(input=8,channel=7)") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_itpp_psk_8,'', label="itpp-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,ber_per_iter_uncoded_commpy_psk_8,'', label="commpy-psk8-uncoded") # plot BER vs SNR
ax1.semilogy(snrs,PSK_2_BER_theory[0:20],'', label="psk2-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_4_BER_theory[0:20],'', label="psk4-theory") # plot BER vs SNR
ax1.semilogy(snrs,PSK_8_BER_theory[0:20],'', label="psk8-theory") # plot BER vs SNR
ax1.set_ylabel('BER')
ax1.set_title('Arch-2 ({},{},{})'.format(input_message_length,2*input_message_length, channel_size))
plt.savefig('ldpc_ber_{}_{}.png'.format(2*channel_size,input_message_length))
plt.legend ()
plt.show()
